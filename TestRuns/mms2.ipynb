# %%
# set up matplotlib
# %matplotlib widget
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (8, 8)
plt.rcParams.update({"font.size": 14})

# %%
import numpy as np
import xarray as xr
from scipy.special import j0
from scipy.interpolate import RectBivariateSpline
from xbout import open_boutdataset

# %%
case = "2" # Case 1 is for anomalous density diffusion only.
filepath = "mms" + str(case) + "/BOUT.dmp.*.nc"
#filepath = "test" + str(case) + "/BOUT.dmp.0.nc"

ds = open_boutdataset(datapath=filepath, chunks={"t": 4})
dsn = xr.open_dataset("circle_lowres.fci.nc")

# Use squeeze() to get rid of the y-dimension, which has length 1 usually unless turbulent.
ds = ds.squeeze(drop=True)
dsn = dsn.squeeze(drop=True)

for key,val in ds.items():
    print(key)
# Out:
# Read in:
# <xbout.BoutDataset>
# Contains:
# <xarray.Dataset> Size: 172MB
# Dimensions:             (x: 132, y: 1, z: 132, t: 201)
# Coordinates:
#     dx                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     dy                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     dz                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#   * t                   (t) float64 2kB 0.0 5e+05 1e+06 ... 9.95e+07 1e+08
#   * x                   (x) int64 1kB 0 1 2 3 4 5 6 ... 126 127 128 129 130 131
#   * y                   (y) float64 8B 0.1963
#   * z                   (z) float64 1kB 0.003788 0.01136 ... 0.9886 0.9962
# Data variables: (12/52)
#     Bxy                 (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     G1                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     G2                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     G3                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     J                   (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     Nh+                 (t, x, y, z) float64 28MB dask.array<chunksize=(4, 132, 1, 132), meta=np.ndarray>
#     ...                  ...
#     wtime_invert        (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_io            (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs       (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs_e     (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs_i     (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_rhs           (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
# Attributes:
#     metadata:  {'BOUT_VERSION': 5.2, 'Bnorm': 1.0, 'Cs0': 21884.735894072473,...
#     options:   None
#     geometry:
# Metadata:
# {   'BOUT_VERSION': 5.2,
#     'Bnorm': 1.0,
#     'Cs0': 21884.735894072473,
#     'HERMES_REVISION': 'bb9053e6425e047f16ae55670f3ede40cddfc2c5',
#     'HERMES_SLOPE_LIMITER': 'MC',
#     'MXG': 2,
#     'MXSUB': 128,
#     'MYG': 1,
#     'MYPE': 0,
#     'MYSUB': 1,
#     'MZ': 132,
#     'MZG': 0,
#     'MZSUB': 132,
#     'NXPE': 1,
#     'NYPE': 1,
#     'NZPE': 1,
#     'Nnorm': 2e+18,
#     'Omega_ci': 95788333.03066081,
#     'PE_XIND': 0,
#     'PE_YIND': 0,
#     'Tnorm': 5.0,
#     'ZMAX': 1.0,
#     'ZMIN': 0.0,
#     'bout_tdim': 't',
#     'bout_xdim': 'x',
#     'bout_ydim': 'y',
#     'bout_zdim': 'z',
#     'fine_interpolation_factor': 8,
#     'has_adios2': 0,
#     'has_caliper': 0,
#     'has_cuda': 0,
#     'has_fftw': 1,
#     'has_gettext': 0,
#     'has_hypre': 0,
#     'has_lapack': 0,
#     'has_netcdf': 1,
#     'has_petsc': 1,
#     'has_pretty_function': 1,
#     'has_pvode': 1,
#     'has_raja': 0,
#     'has_scorep': 0,
#     'has_slepc': 0,
#     'has_sundials': 1,
#     'has_umpire': 0,
#     'hist_hi': 200,
#     'is_restart': 0,
#     'ixseps1': 133,
#     'ixseps2': 133,
#     'jyseps1_1': -1,
#     'jyseps1_2': 0,
#     'jyseps2_1': 0,
#     'jyseps2_2': 0,
#     'keep_xboundaries': 1,
#     'keep_yboundaries': 0,
#     'nx': 132,
#     'ny': 1,
#     'ny_inner': 0,
#     'nz': 132,
#     'openmp_threads': 1,
#     'rho_s0': 0.0002284697436697996,
#     'run_id': 'bc3703a5-7bb4-46c6-8a5d-89318644c00e',
#     'run_restart_from': 'zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz',
#     'tt': 100000000.0,
#     'use_backtrace': 1,
#     'use_check_level': 2,
#     'use_color': 1,
#     'use_metric_3d': 1,
#     'use_msgstack': 1,
#     'use_openmp': 0,
#     'use_openmp_schedule': 'static',
#     'use_output_debug': 0,
#     'use_sigfpe': 0,
#     'use_signal': 1,
#     'use_track': 1,
#     'zperiod': 1}
#
# Bxy
# G1
# G2
# G3
# J
# Nh+
# R
# SNh+
# Sh+_anom
# Sh+_src
# Z
# anomalous_Chi_h+
# anomalous_D_h+
# anomalous_nu_h+
# cvode_last_order
# cvode_last_step
# cvode_nfevals
# cvode_nliters
# cvode_nniters
# cvode_nonlin_fails
# cvode_npevals
# cvode_nsteps
# cvode_num_fails
# cvode_stab_lims
# ddt(Nh+)
# g11
# g12
# g13
# g22
# g23
# g33
# g_11
# g_12
# g_13
# g_22
# g_23
# g_33
# iteration
# pfh+_tot_xlow
# t_array
# ncalls
# ncalls_e
# ncalls_i
# wall_time
# wtime
# wtime_comms
# wtime_invert
# wtime_io
# wtime_per_rhs
# wtime_per_rhs_e
# wtime_per_rhs_i
# wtime_rhs
# /home/tirkas1/miniconda3/lib/python3.13/site-packages/xbout/load.py:341: UserWarning: No geometry type found, no physical coordinates will be added
#   warn("No geometry type found, no physical coordinates will be added")

# %%
dx = ds["dx"].isel(z=0).values

# Get rid of existing "x" coordinate, which is just the index values.
#ds = ds.drop("x")

# Create a new coordinate, which is length in units of rho_s
ds = ds.assign_coords(x=np.arange(ds.sizes["x"])*dx)

#Store just initial values as well.
ds_initial = ds.isel(t=0)

# %%
dens = ds["Nh+"][:,2:-2,:]
dens_true = dens.copy()

mask = dsn["in_mask"][2:-2,:]
ghost_id = dsn["ghost_id"].values
gst_pts = dsn["ghost_pts"].values
bdy_pts = dsn["bndry_pts"].values
img_pts = dsn["image_pts"].values
normals = dsn["normals"].values
is_plasma = dsn["is_plasma"].values
Rarr = dsn["R"].values[2:-2,:]
Zarr = dsn["Z"].values

timestep_for_errs_early = 10
timestep_for_errs_late = 100
spl_e = RectBivariateSpline(Rarr[:,0], Zarr[0,:], dens.values[timestep_for_errs_early,:,:], kx=1, ky=1)
spl_l = RectBivariateSpline(Rarr[:,0], Zarr[0,:], dens.values[timestep_for_errs_late,:,:], kx=1, ky=1)

# %%
alpha0 = 2.404825557693792
xc, zc = 1.5, 0.0

x_unit = 0.00022846974366979959 #rho_s0
w_unit = 95788333.030660808    #Omega_ci
t_unit = 1/w_unit

nx = 64*int(case)
nz = nx + 4
dx = np.float64(1.0) / np.float64(nx)
dz = np.float64(1.0) / np.float64(nz)

# Centers in x; faces/nodes in z if that's your convention
x = (np.arange(nx, dtype=np.float64) + 0.5) * dx     # centered x
z = (np.arange(nz, dtype=np.float64)) * dz           # unshifted z

xhalf  = np.float64(x[len(x)//2])
zhalf  = np.float64(z[len(z)//2])

print(xhalf)

xx, zz = np.meshgrid(x,z,indexing='ij',copy=False)
a      = np.float64(0.333333333333333)
D      = np.float64(0.2) #/(x_unit*x_unit*w_unit)
t64 = np.asarray(ds["t_array"].values, dtype=np.float64) # 1D time
t_norm = t64*t_unit
#spatial = ((xx - xhalf)**2 + (zz-zhalf)**2)
spatial = j0(alpha0*np.hypot(xx - xhalf, zz - zhalf)/a)
#temp = 4.0*D*t_norm #t64/t64[-1]
a_norm = a/x_unit
temp = np.exp(-D * (alpha0 / a)**2 * (t_norm))

#dens_true[:,:,:] = np.asarray(spatial)[np.newaxis,:,:] + np.asarray(temp)[:,np.newaxis,np.newaxis]
dens_true[:,:,:] = np.asarray(spatial)[np.newaxis,:,:]*np.asarray(temp)[:,np.newaxis,np.newaxis]

bdy_pts_xz_e = spl_e.ev(bdy_pts[:,0], bdy_pts[:,1])
bdy_pts_xz_l = spl_l.ev(bdy_pts[:,0], bdy_pts[:,1])
print("Linf bdy err if dirichlet: " + str(np.max(np.abs(bdy_pts_xz_e))))
print("L2 bdy err (early) if dirichlet?: "  + str(np.mean(np.abs(bdy_pts_xz_e))))
print("L2 bdy err (late) if dirichlet?: "  + str(np.mean(np.abs(bdy_pts_xz_l))))

#dndR = spl.ev(bdy_pts[:,0], bdy_pts[:,1], dx=1, dy=0) # ∂n/∂R at boundary points
#dndZ = spl.ev(bdy_pts[:,0], bdy_pts[:,1], dx=0, dy=1) # ∂n/∂Z at boundary points
#dn_dn = dndR * normals[:,0] + dndZ * normals[:,1]     # normal derivative
dP = np.einsum('ij,ij->i', (bdy_pts - img_pts), -normals)
dG = np.einsum('ij,ij->i', (gst_pts - bdy_pts), -normals)
dn_dn_e = (spl_e.ev(img_pts[:,0], img_pts[:,1]) - spl_e.ev(gst_pts[:,0], gst_pts[:,1])) / (dP + dG)
dn_dn_l = (spl_l.ev(img_pts[:,0], img_pts[:,1]) - spl_l.ev(gst_pts[:,0], gst_pts[:,1])) / (dP + dG)

Linf = np.max(np.abs(dn_dn_e))
L2   = np.sqrt(np.mean(dn_dn_e**2))
L2   = np.sqrt(np.mean(dn_dn_l**2))
print("Linf bdy err if neumann: " + str(np.max(np.abs(dn_dn_e))))
print("L2 bdy err (early) if neumann: " + str(np.sqrt(np.mean(dn_dn_e**2))))
print("L2 bdy err (late) if neumann: " + str(np.sqrt(np.mean(dn_dn_l**2))))
# Out:
# 0.50390625
# Linf bdy err if dirichlet: 0.0001341446755724785
# L2 bdy err (early) if dirichlet?: 4.220876730234053e-05
# L2 bdy err (late) if dirichlet?: 3.174179626824589e-07
# Linf bdy err if neumann: 2.202839936276377
# L2 bdy err (early) if neumann: 2.184082119436231
# L2 bdy err (late) if neumann: 0.016424707591210598

# %%
img_pts_xz = spl_e.ev(img_pts[:,0], img_pts[:,1])

i = 0
for idx in range(nx+4):
    for idz in range(nz):
        gid = int(ghost_id[idx,idz])
        if gid >= 0:
            print(gid)
            if (not (is_plasma[gid,0] and is_plasma[gid,1] and is_plasma[gid,2] and is_plasma[gid,3])):
               print("Contains multiple ghost cell corners.")
            print(img_pts[gid])
            print(img_pts_xz[gid])
# Out:
# 0
# [ 1.1798759  -0.05776212]
# 0.017596503724188577
# 1
# [ 1.17744074 -0.05096186]
# 0.014796166163022057
# 2
# [ 1.17530107 -0.04399834]
# 0.012356687918509076
# 3
# [ 1.17347038 -0.036777  ]
# 0.010309664264111524
# 4
# [ 1.17197622 -0.0295726 ]
# 0.00862939480375392
# 5
# Contains multiple ghost cell corners.
# [ 1.17080382 -0.02227157]
# 0.007353470829378087
# 6
# Contains multiple ghost cell corners.
# [ 1.16995945 -0.01489808]
# 0.006434313430352281
# 7
# Contains multiple ghost cell corners.
# [ 1.16944753 -0.00747662]
# 0.005876593667905876
# 8
# Contains multiple ghost cell corners.
# [1.16927083e+00 8.16431199e-17]
# 0.005683349527598698
# 9
# Contains multiple ghost cell corners.
# [1.16944753 0.00747662]
# 0.005876593667904768
# 10
# Contains multiple ghost cell corners.
# [1.16995945 0.01489808]
# 0.006434313430351436
# 11
# Contains multiple ghost cell corners.
# [1.17080382 0.02227157]
# 0.007353470829378532
# 12
# [1.17197622 0.0295726 ]
# 0.008629394803754001
# 13
# [1.17347038 0.036777  ]
# 0.01030966426411124
# 14
# [1.17530107 0.04399834]
# 0.01235668791850805
# 15
# [1.17744074 0.05096186]
# 0.014796166163021433
# 16
# [1.1798759  0.05776212]
# 0.01759650372418726
# 17
# [ 1.18962511 -0.09321913]
# 0.02034468035091584
# 18
# [ 1.1856387  -0.08700909]
# 0.015630433639413133
# 19
# [ 1.18197324 -0.0807379 ]
# 0.011356317915722615
# 20
# Contains multiple ghost cell corners.
# [ 1.1785587  -0.07421356]
# 0.0074496963553684235
# 21
# Contains multiple ghost cell corners.
# [ 1.17541311 -0.06745545]
# 0.003939430009564029
# 22
# Contains multiple ghost cell corners.
# [ 1.17255294 -0.06048414]
# 0.0007524986247069611
# 23
# Contains multiple ghost cell corners.
# [1.17255294 0.06048414]
# 0.0007524986247072139
# 24
# Contains multiple ghost cell corners.
# [1.17541311 0.06745545]
# 0.003939430009564298
# 25
# Contains multiple ghost cell corners.
# [1.1785587  0.07421356]
# 0.007449696355370843
# 26
# [1.18197324 0.0807379 ]
# 0.011356317915723774
# 27
# [1.1856387  0.08700909]
# 0.01563043363941492
# 28
# [1.18962511 0.09321913]
# 0.020344680350916692
# 29
# [ 1.19680664 -0.11472893]
# 0.020131377738292284
# 30
# [ 1.19203619 -0.10930322]
# 0.014312228606738937
# 31
# Contains multiple ghost cell corners.
# [ 1.18742554 -0.10345153]
# 0.00884867013563305
# 32
# Contains multiple ghost cell corners.
# [ 1.18309348 -0.09742879]
# 0.0038763544413415374
# 33
# Contains multiple ghost cell corners.
# [1.18309348 0.09742879]
# 0.003876354441342481
# 34
# Contains multiple ghost cell corners.
# [1.18742554 0.10345153]
# 0.008848670135632144
# 35
# [1.19203619 0.10930322]
# 0.01431222860673903
# 36
# [1.19680664 0.11472893]
# 0.02013137773829285
# 37
# Contains multiple ghost cell corners.
# [ 1.20148734 -0.13026589]
# 0.01674894348385414
# 38
# [ 1.19614641 -0.12526842]
# 0.010161571395192538
# 39
# Contains multiple ghost cell corners.
# [ 1.19095192 -0.11985618]
# 0.004027888427518288
# 40
# Contains multiple ghost cell corners.
# [1.19095192 0.11985618]
# 0.004027888427518118
# 41
# [1.19614641 0.12526842]
# 0.010161571395191617
# 42
# Contains multiple ghost cell corners.
# [1.20148734 0.13026589]
# 0.01674894348385684
# 43
# [ 1.21370244 -0.14940588]
# 0.022892313154363245
# 44
# [ 1.20777341 -0.1453384 ]
# 0.015239226927796024
# 45
# Contains multiple ghost cell corners.
# [ 1.20191938 -0.14086404]
# 0.00790779151969408
# 46
# Contains multiple ghost cell corners.
# [ 1.19619219 -0.13596722]
# 0.001049787959100856
# 47
# Contains multiple ghost cell corners.
# [1.19619219 0.13596722]
# 0.001049787959101064
# 48
# Contains multiple ghost cell corners.
# [1.20191938 0.14086404]
# 0.007907791519694583
# 49
# [1.20777341 0.1453384 ]
# 0.01523922692779778
# 50
# [1.21370244 0.14940588]
# 0.02289231315436282
# 51
# Contains multiple ghost cell corners.
# [ 1.21557773 -0.15971286]
# 0.015660766272958024
# 52
# Contains multiple ghost cell corners.
# [ 1.20925017 -0.15576846]
# 0.00756027728282509
# 53
# Contains multiple ghost cell corners.
# [1.20925017 0.15576846]
# 0.007560277282824554
# 54
# Contains multiple ghost cell corners.
# [1.21557773 0.15971286]
# 0.0156607662729566
# 55
# [ 1.22477994 -0.17317109]
# 0.017929509782143867
# 56
# Contains multiple ghost cell corners.
# [ 1.21809435 -0.16989286]
# 0.009119028566036557
# 57
# Contains multiple ghost cell corners.
# [ 1.21152959 -0.16632644]
# 0.0007423149818568675
# 58
# Contains multiple ghost cell corners.
# [1.21152959 0.16632644]
# 0.0007423149818568497
# 59
# Contains multiple ghost cell corners.
# [1.21809435 0.16989286]
# 0.009119028566035971
# 60
# [1.22477994 0.17317109]
# 0.01792950978214395
# 61
# [ 1.23522876 -0.18551466]
# 0.022085816980171247
# 62
# [ 1.22826675 -0.18295024]
# 0.012564318414517675
# 63
# Contains multiple ghost cell corners.
# [ 1.22139799 -0.18011851]
# 0.003412382223198133
# 64
# Contains multiple ghost cell corners.
# [1.22139799 0.18011851]
# 0.003412382223196678
# 65
# [1.22826675 0.18295024]
# 0.0125643184145131
# 66
# [1.23522876 0.18551466]
# 0.022085816980166668
# 67
# [ 1.23959461 -0.19475566]
# 0.017902102152951745
# 68
# Contains multiple ghost cell corners.
# [ 1.23252735 -0.19271378]
# 0.007958851273939522
# 69
# Contains multiple ghost cell corners.
# [1.23252735 0.19271378]
# 0.007958851273939733
# 70
# [1.23959461 0.19475566]
# 0.017902102152951682
# 71
# [ 1.24472813 -0.20393884]
# 0.01446401568495631
# 72
# Contains multiple ghost cell corners.
# [ 1.23742822 -0.2021927 ]
# 0.004185025600893891
# 73
# Contains multiple ghost cell corners.
# [1.23742822 0.2021927 ]
# 0.004185025600895216
# 74
# [1.24472813 0.20393884]
# 0.014464015684957313
# 75
# [ 1.25778665 -0.21364898]
# 0.02280379505697243
# 76
# [ 1.25040404 -0.2126968 ]
# 0.01179427913430059
# 77
# Contains multiple ghost cell corners.
# [ 1.24300159 -0.2114447 ]
# 0.001147063718272159
# 78
# Contains multiple ghost cell corners.
# [1.24300159 0.2114447 ]
# 0.001147063718272928
# 79
# [1.25040404 0.2126968 ]
# 0.011794279134301549
# 80
# [1.25778665 0.21364898]
# 0.022803795056975214
# 81
# [ 1.26410293 -0.2215854 ]
# 0.02129678095560026
# 82
# Contains multiple ghost cell corners.
# [ 1.25668221 -0.22114122]
# 0.00986238352381444
# 83
# Contains multiple ghost cell corners.
# [1.25668221 0.22114122]
# 0.009862383523816591
# 84
# [1.26410293 0.2215854 ]
# 0.02129678095560386
# 85
# [ 1.27093963 -0.22913502]
# 0.02052506279018651
# 86
# Contains multiple ghost cell corners.
# [ 1.26361096 -0.22925966]
# 0.008754120051780157
# 87
# Contains multiple ghost cell corners.
# [1.26361096 0.22925966]
# 0.008754120051779994
# 88
# [1.27093963 0.22913502]
# 0.020525062790186052
# 89
# [ 1.27844363 -0.23636967]
# 0.020572263095369595
# 90
# Contains multiple ghost cell corners.
# [ 1.27099435 -0.23685349]
# 0.008411186100936632
# 91
# Contains multiple ghost cell corners.
# [1.27099435 0.23685349]
# 0.008411186100936052
# 92
# [1.27844363 0.23636967]
# 0.020572263095369248
# 93
# [ 1.28621202 -0.24294897]
# 0.021356102850666556
# 94
# Contains multiple ghost cell corners.
# [ 1.27885653 -0.24396742]
# 0.00880716947149407
# 95
# Contains multiple ghost cell corners.
# [1.27885653 0.24396742]
# 0.008807169471495067
# 96
# [1.28621202 0.24294897]
# 0.021356102850668232
# 97
# [ 1.29455699 -0.24913828]
# 0.022924443477028312
# 98
# Contains multiple ghost cell corners.
# [ 1.2872199  -0.25056851]
# 0.010016675217554305
# 99
# Contains multiple ghost cell corners.
# [1.2872199  0.25056851]
# 0.010016675217555795
# 100
# [1.29455699 0.24913828]
# 0.022924443477027392
# 101
# [ 1.29587399 -0.25653296]
# 0.011996347959710373
# 102
# [1.29587399 0.25653296]
# 0.011996347959709934
# 103
# [ 1.30495784 -0.26196745]
# 0.01475908788049846
# 104
# Contains multiple ghost cell corners.
# [ 1.29771148 -0.264066  ]
# 0.0014854928904994963
# 105
# Contains multiple ghost cell corners.
# [1.29771148 0.264066  ]
# 0.0014854928904994322
# 106
# [1.30495784 0.26196745]
# 0.01475908788049723
# 107
# [ 1.31417511 -0.26665453]
# 0.01826062389948683
# 108
# Contains multiple ghost cell corners.
# [ 1.30715372 -0.26927075]
# 0.00461004869768497
# 109
# Contains multiple ghost cell corners.
# [1.30715372 0.26927075]
# 0.004610048697683698
# 110
# [1.31417511 0.26665453]
# 0.018260623899487093
# 111
# [ 1.3237548  -0.27080897]
# 0.022499902864948573
# 112
# Contains multiple ghost cell corners.
# [ 1.31687375 -0.27384341]
# 0.008468710951517914
# 113
# Contains multiple ghost cell corners.
# [1.31687375 0.27384341]
# 0.008468710951513895
# 114
# [1.3237548  0.27080897]
# 0.02249990286494809
# 115
# [ 1.32669969 -0.27765404]
# 0.013187819984955631
# 116
# [1.32669969 0.27765404]
# 0.013187819984955097
# 117
# [ 1.33657352 -0.28075191]
# 0.018622593794398245
# 118
# Contains multiple ghost cell corners.
# [ 1.33011295 -0.28451546]
# 0.004235267983037027
# 119
# Contains multiple ghost cell corners.
# [1.33011295 0.28451546]
# 0.004235267983036957
# 120
# [1.33657352 0.28075191]
# 0.018622593794398533
# 121
# [ 1.34044395 -0.28738449]
# 0.01006966546919928
# 122
# [1.34044395 0.28738449]
# 0.010069665469198012
# 123
# Contains multiple ghost cell corners.
# [ 1.35067883 -0.28947287]
# 0.016720091008302657
# 124
# Contains multiple ghost cell corners.
# [ 1.34458791 -0.29386351]
# 0.001954383090671616
# 125
# Contains multiple ghost cell corners.
# [1.34458791 0.29386351]
# 0.0019543830906707444
# 126
# Contains multiple ghost cell corners.
# [1.35067883 0.28947287]
# 0.01672009100830005
# 127
# Contains multiple ghost cell corners.
# [ 1.3552063  -0.29567935]
# 0.008920192812618846
# 128
# Contains multiple ghost cell corners.
# [1.3552063  0.29567935]
# 0.008920192812618188
# 129
# Contains multiple ghost cell corners.
# [ 1.36564379 -0.29669492]
# 0.01674981957657441
# 130
# Contains multiple ghost cell corners.
# [ 1.36000184 -0.30168364]
# 0.0016162639841326275
# 131
# Contains multiple ghost cell corners.
# [1.36000184 0.30168364]
# 0.0016162639841318257
# 132
# Contains multiple ghost cell corners.
# [1.36564379 0.29669492]
# 0.01674981957657631
# 133
# [ 1.37066541 -0.30235323]
# 0.009743193778533273
# 134
# [1.37066541 0.30235323]
# 0.009743193778535015
# 135
# [ 1.38123567 -0.30230723]
# 0.018732347502094515
# 136
# Contains multiple ghost cell corners.
# [ 1.37612    -0.30785451]
# 0.003228514105067525
# 137
# Contains multiple ghost cell corners.
# [1.37612    0.30785451]
# 0.0032285141050676746
# 138
# [1.38123567 0.30230723]
# 0.018732347502099834
# 139
# [ 1.38675127 -0.30738304]
# 0.012555993892033438
# 140
# [1.38675127 0.30738304]
# 0.012555993892036474
# 141
# Contains multiple ghost cell corners.
# [ 1.3926206  -0.31226323]
# 0.00678119219185656
# 142
# Contains multiple ghost cell corners.
# [1.3926206  0.31226323]
# 0.006781192191859017
# 143
# Contains multiple ghost cell corners.
# [ 1.40311386 -0.31067544]
# 0.017298907065455303
# 144
# Contains multiple ghost cell corners.
# [ 1.39884894 -0.31691023]
# 0.0014559889196238606
# 145
# Contains multiple ghost cell corners.
# [1.39884894 0.31691023]
# 0.0014559889196237275
# 146
# Contains multiple ghost cell corners.
# [1.40311386 0.31067544]
# 0.01729890706545867
# 147
# [ 1.40933036 -0.31488651]
# 0.012336578843497807
# 148
# [1.40933036 0.31488651]
# 0.012336578843500165
# 149
# Contains multiple ghost cell corners.
# [ 1.4159243  -0.31886565]
# 0.007742078465458135
# 150
# Contains multiple ghost cell corners.
# [1.4159243  0.31886565]
# 0.0077420784654601785
# 151
# [ 1.42594335 -0.31572231]
# 0.0198504706227278
# 152
# Contains multiple ghost cell corners.
# [ 1.42266437 -0.32252215]
# 0.0036233936039568627
# 153
# Contains multiple ghost cell corners.
# [1.42266437 0.32252215]
# 0.003623393603957148
# 154
# [1.42594335 0.31572231]
# 0.019850470622728204
# 155
# [ 1.43263825 -0.31896037]
# 0.01602210236775989
# 156
# [1.43263825 0.31896037]
# 0.016022102367761294
# 157
# [ 1.43969736 -0.3219209 ]
# 0.012670114379643847
# 158
# [1.43969736 0.3219209 ]
# 0.012670114379644961
# 159
# [ 1.44678385 -0.32453351]
# 0.009700818453776352
# 160
# [1.44678385 0.32453351]
# 0.009700818453776933
# 161
# Contains multiple ghost cell corners.
# [ 1.45404932 -0.32682726]
# 0.00714317535603516
# 162
# Contains multiple ghost cell corners.
# [1.45404932 0.32682726]
# 0.00714317535603551
# 163
# Contains multiple ghost cell corners.
# [ 1.46146961 -0.32878981]
# 0.004990320399310788
# 164
# Contains multiple ghost cell corners.
# [1.46146961 0.32878981]
# 0.00499032039931115
# 165
# Contains multiple ghost cell corners.
# [ 1.46901977 -0.33041062]
# 0.003210095723556352
# 166
# Contains multiple ghost cell corners.
# [1.46901977 0.33041062]
# 0.0032100957235558954
# 167
# Contains multiple ghost cell corners.
# [ 1.47667419 -0.33168108]
# 0.0018145996428308678
# 168
# Contains multiple ghost cell corners.
# [1.47667419 0.33168108]
# 0.0018145996428311252
# 169
# Contains multiple ghost cell corners.
# [ 1.48440675 -0.33259449]
# 0.0008113485018072738
# 170
# Contains multiple ghost cell corners.
# [1.48440675 0.33259449]
# 0.0008113485018072197
# 171
# [ 1.49246979 -0.32557553]
# 0.016839041954517513
# 172
# Contains multiple ghost cell corners.
# [ 1.49219095 -0.33314616]
# 0.0002054594620842348
# 173
# Contains multiple ghost cell corners.
# [1.49219095 0.33314616]
# 0.00020545946208423935
# 174
# [1.49246979 0.32557553]
# 0.016839041954517468
# 175
# [ 1.5        -0.32575758]
# 0.016611520115482347
# 176
# Contains multiple ghost cell corners.
# [1.5        0.32575758]
# 0.016611520115484807
# 177
# [ 1.50753021 -0.32557553]
# 0.016839041954517502
# 178
# Contains multiple ghost cell corners.
# [ 1.50780905 -0.33314616]
# 0.00020545946208423731
# 179
# Contains multiple ghost cell corners.
# [1.50780905 0.33314616]
# 0.0002054594620842006
# 180
# [1.50753021 0.32557553]
# 0.01683904195451616
# 181
# Contains multiple ghost cell corners.
# [ 1.51559325 -0.33259449]
# 0.0008113485018072256
# 182
# Contains multiple ghost cell corners.
# [1.51559325 0.33259449]
# 0.0008113485018074203
# 183
# Contains multiple ghost cell corners.
# [ 1.52332581 -0.33168108]
# 0.0018145996428311096
# 184
# Contains multiple ghost cell corners.
# [1.52332581 0.33168108]
# 0.001814599642830995
# 185
# Contains multiple ghost cell corners.
# [ 1.53098023 -0.33041062]
# 0.0032100957235558477
# 186
# Contains multiple ghost cell corners.
# [1.53098023 0.33041062]
# 0.003210095723556524
# 187
# Contains multiple ghost cell corners.
# [ 1.53853039 -0.32878981]
# 0.004990320399311037
# 188
# Contains multiple ghost cell corners.
# [1.53853039 0.32878981]
# 0.00499032039931137
# 189
# Contains multiple ghost cell corners.
# [ 1.54595068 -0.32682726]
# 0.007143175356035231
# 190
# Contains multiple ghost cell corners.
# [1.54595068 0.32682726]
# 0.00714317535603613
# 191
# [ 1.55321615 -0.32453351]
# 0.009700818453776305
# 192
# [1.55321615 0.32453351]
# 0.009700818453776747
# 193
# [ 1.56030264 -0.3219209 ]
# 0.012670114379643129
# 194
# [1.56030264 0.3219209 ]
# 0.01267011437964434
# 195
# [ 1.56736175 -0.31896037]
# 0.016022102367760045
# 196
# [1.56736175 0.31896037]
# 0.01602210236776023
# 197
# [ 1.57405665 -0.31572231]
# 0.019850470622728614
# 198
# Contains multiple ghost cell corners.
# [ 1.57733563 -0.32252215]
# 0.0036233936039585736
# 199
# Contains multiple ghost cell corners.
# [1.57733563 0.32252215]
# 0.0036233936039571004
# 200
# [1.57405665 0.31572231]
# 0.01985047062272838
# 201
# Contains multiple ghost cell corners.
# [ 1.5840757  -0.31886565]
# 0.007742078465460638
# 202
# Contains multiple ghost cell corners.
# [1.5840757  0.31886565]
# 0.007742078465459089
# 203
# [ 1.59066964 -0.31488651]
# 0.012336578843497833
# 204
# [1.59066964 0.31488651]
# 0.012336578843499452
# 205
# Contains multiple ghost cell corners.
# [ 1.59688614 -0.31067544]
# 0.017298907065455543
# 206
# Contains multiple ghost cell corners.
# [ 1.60115106 -0.31691023]
# 0.001455988919623756
# 207
# Contains multiple ghost cell corners.
# [1.60115106 0.31691023]
# 0.0014559889196243386
# 208
# Contains multiple ghost cell corners.
# [1.59688614 0.31067544]
# 0.017298907065457426
# 209
# Contains multiple ghost cell corners.
# [ 1.6073794  -0.31226323]
# 0.006781192191855573
# 210
# Contains multiple ghost cell corners.
# [1.6073794  0.31226323]
# 0.00678119219185842
# 211
# [ 1.61324873 -0.30738304]
# 0.012555993892032463
# 212
# [1.61324873 0.30738304]
# 0.012555993892035006
# 213
# [ 1.61876433 -0.30230723]
# 0.018732347502096222
# 214
# Contains multiple ghost cell corners.
# [ 1.62388    -0.30785451]
# 0.0032285141050675237
# 215
# Contains multiple ghost cell corners.
# [1.62388    0.30785451]
# 0.003228514105068884
# 216
# [1.61876433 0.30230723]
# 0.018732347502097187
# 217
# [ 1.62933459 -0.30235323]
# 0.009743193778533549
# 218
# [1.62933459 0.30235323]
# 0.00974319377853545
# 219
# Contains multiple ghost cell corners.
# [ 1.63435621 -0.29669492]
# 0.01674981957657652
# 220
# Contains multiple ghost cell corners.
# [ 1.63999816 -0.30168364]
# 0.001616263984132879
# 221
# Contains multiple ghost cell corners.
# [1.63999816 0.30168364]
# 0.0016162639841322643
# 222
# Contains multiple ghost cell corners.
# [1.63435621 0.29669492]
# 0.016749819576574287
# 223
# Contains multiple ghost cell corners.
# [ 1.6447937  -0.29567935]
# 0.008920192812621233
# 224
# Contains multiple ghost cell corners.
# [1.6447937  0.29567935]
# 0.008920192812622183
# 225
# Contains multiple ghost cell corners.
# [ 1.64932117 -0.28947287]
# 0.016720091008300384
# 226
# Contains multiple ghost cell corners.
# [ 1.65541209 -0.29386351]
# 0.001954383090670586
# 227
# Contains multiple ghost cell corners.
# [1.65541209 0.29386351]
# 0.001954383090670299
# 228
# Contains multiple ghost cell corners.
# [1.64932117 0.28947287]
# 0.01672009100829859
# 229
# [ 1.65955605 -0.28738449]
# 0.010069665469197228
# 230
# [1.65955605 0.28738449]
# 0.010069665469200469
# 231
# [ 1.66342648 -0.28075191]
# 0.018622593794402995
# 232
# Contains multiple ghost cell corners.
# [ 1.66988705 -0.28451546]
# 0.004235267983038859
# 233
# Contains multiple ghost cell corners.
# [1.66988705 0.28451546]
# 0.004235267983036879
# 234
# [1.66342648 0.28075191]
# 0.01862259379439705
# 235
# [ 1.67330031 -0.27765404]
# 0.013187819984959295
# 236
# [1.67330031 0.27765404]
# 0.013187819984955005
# 237
# [ 1.6762452  -0.27080897]
# 0.022499902864952917
# 238
# Contains multiple ghost cell corners.
# [ 1.68312625 -0.27384341]
# 0.008468710951518342
# 239
# Contains multiple ghost cell corners.
# [1.68312625 0.27384341]
# 0.008468710951515012
# 240
# [1.6762452  0.27080897]
# 0.022499902864947543
# 241
# [ 1.68582489 -0.26665453]
# 0.018260623899493074
# 242
# Contains multiple ghost cell corners.
# [ 1.69284628 -0.26927075]
# 0.004610048697684469
# 243
# Contains multiple ghost cell corners.
# [1.69284628 0.26927075]
# 0.004610048697683483
# 244
# [1.68582489 0.26665453]
# 0.018260623899489084
# 245
# [ 1.69504216 -0.26196745]
# 0.01475908788049396
# 246
# Contains multiple ghost cell corners.
# [ 1.70228852 -0.264066  ]
# 0.0014854928904998361
# 247
# Contains multiple ghost cell corners.
# [1.70228852 0.264066  ]
# 0.0014854928904989352
# 248
# [1.69504216 0.26196745]
# 0.014759087880493554
# 249
# [ 1.70412601 -0.25653296]
# 0.01199634795971121
# 250
# [1.70412601 0.25653296]
# 0.011996347959701602
# 251
# [ 1.70544301 -0.24913828]
# 0.022924443477024596
# 252
# Contains multiple ghost cell corners.
# [ 1.7127801  -0.25056851]
# 0.010016675217551157
# 253
# Contains multiple ghost cell corners.
# [1.7127801  0.25056851]
# 0.010016675217541354
# 254
# [1.70544301 0.24913828]
# 0.02292444347702352
# 255
# [ 1.71378798 -0.24294897]
# 0.021356102850666876
# 256
# Contains multiple ghost cell corners.
# [ 1.72114347 -0.24396742]
# 0.00880716947149704
# 257
# Contains multiple ghost cell corners.
# [1.72114347 0.24396742]
# 0.008807169471489767
# 258
# [1.71378798 0.24294897]
# 0.021356102850666903
# 259
# [ 1.72155637 -0.23636967]
# 0.020572263095363724
# 260
# Contains multiple ghost cell corners.
# [ 1.72900565 -0.23685349]
# 0.008411186100938437
# 261
# Contains multiple ghost cell corners.
# [1.72900565 0.23685349]
# 0.008411186100938281
# 262
# [1.72155637 0.23636967]
# 0.020572263095370188
# 263
# [ 1.72906037 -0.22913502]
# 0.020525062790185972
# 264
# Contains multiple ghost cell corners.
# [ 1.73638904 -0.22925966]
# 0.008754120051774419
# 265
# Contains multiple ghost cell corners.
# [1.73638904 0.22925966]
# 0.008754120051788546
# 266
# [1.72906037 0.22913502]
# 0.020525062790193664
# 267
# [ 1.73589707 -0.2215854 ]
# 0.021296780955600333
# 268
# Contains multiple ghost cell corners.
# [ 1.74331779 -0.22114122]
# 0.00986238352381546
# 269
# Contains multiple ghost cell corners.
# [1.74331779 0.22114122]
# 0.009862383523826589
# 270
# [1.73589707 0.2215854 ]
# 0.021296780955608836
# 271
# [ 1.74221335 -0.21364898]
# 0.022803795056974354
# 272
# [ 1.74959596 -0.2126968 ]
# 0.01179427913430375
# 273
# Contains multiple ghost cell corners.
# [ 1.75699841 -0.2114447 ]
# 0.0011470637182722735
# 274
# Contains multiple ghost cell corners.
# [1.75699841 0.2114447 ]
# 0.0011470637182726686
# 275
# [1.74959596 0.2126968 ]
# 0.011794279134304551
# 276
# [1.74221335 0.21364898]
# 0.02280379505697834
# 277
# [ 1.75527187 -0.20393884]
# 0.014464015684956238
# 278
# Contains multiple ghost cell corners.
# [ 1.76257178 -0.2021927 ]
# 0.004185025600893641
# 279
# Contains multiple ghost cell corners.
# [1.76257178 0.2021927 ]
# 0.004185025600893646
# 280
# [1.75527187 0.20393884]
# 0.014464015684957057
# 281
# [ 1.76040539 -0.19475566]
# 0.01790210215294929
# 282
# Contains multiple ghost cell corners.
# [ 1.76747265 -0.19271378]
# 0.00795885127393931
# 283
# Contains multiple ghost cell corners.
# [1.76747265 0.19271378]
# 0.00795885127393973
# 284
# [1.76040539 0.19475566]
# 0.017902102152950402
# 285
# [ 1.76477124 -0.18551466]
# 0.022085816980168014
# 286
# [ 1.77173325 -0.18295024]
# 0.012564318414517484
# 287
# Contains multiple ghost cell corners.
# [ 1.77860201 -0.18011851]
# 0.0034123822231986517
# 288
# Contains multiple ghost cell corners.
# [1.77860201 0.18011851]
# 0.0034123822231967122
# 289
# [1.77173325 0.18295024]
# 0.01256431841451447
# 290
# [1.76477124 0.18551466]
# 0.022085816980169266
# 291
# [ 1.77522006 -0.17317109]
# 0.01792950978214609
# 292
# Contains multiple ghost cell corners.
# [ 1.78190565 -0.16989286]
# 0.009119028566038603
# 293
# Contains multiple ghost cell corners.
# [ 1.78847041 -0.16632644]
# 0.0007423149818568382
# 294
# Contains multiple ghost cell corners.
# [1.78847041 0.16632644]
# 0.0007423149818572185
# 295
# Contains multiple ghost cell corners.
# [1.78190565 0.16989286]
# 0.009119028566038514
# 296
# [1.77522006 0.17317109]
# 0.017929509782147357
# 297
# Contains multiple ghost cell corners.
# [ 1.78442227 -0.15971286]
# 0.015660766272955925
# 298
# Contains multiple ghost cell corners.
# [ 1.79074983 -0.15576846]
# 0.007560277282820586
# 299
# Contains multiple ghost cell corners.
# [1.79074983 0.15576846]
# 0.007560277282821882
# 300
# Contains multiple ghost cell corners.
# [1.78442227 0.15971286]
# 0.015660766272958978
# 301
# [ 1.78629756 -0.14940588]
# 0.02289231315436299
# 302
# [ 1.79222659 -0.1453384 ]
# 0.015239226927796438
# 303
# Contains multiple ghost cell corners.
# [ 1.79808062 -0.14086404]
# 0.007907791519690838
# 304
# Contains multiple ghost cell corners.
# [ 1.80380781 -0.13596722]
# 0.001049787959101716
# 305
# Contains multiple ghost cell corners.
# [1.80380781 0.13596722]
# 0.0010497879591015455
# 306
# Contains multiple ghost cell corners.
# [1.79808062 0.14086404]
# 0.00790779151969455
# 307
# [1.79222659 0.1453384 ]
# 0.015239226927797628
# 308
# [1.78629756 0.14940588]
# 0.022892313154364206
# 309
# Contains multiple ghost cell corners.
# [ 1.79851266 -0.13026589]
# 0.016748943483854004
# 310
# [ 1.80385359 -0.12526842]
# 0.010161571395191117
# 311
# Contains multiple ghost cell corners.
# [ 1.80904808 -0.11985618]
# 0.0040278884275178894
# 312
# Contains multiple ghost cell corners.
# [1.80904808 0.11985618]
# 0.00402788842751847
# 313
# [1.80385359 0.12526842]
# 0.010161571395193175
# 314
# Contains multiple ghost cell corners.
# [1.79851266 0.13026589]
# 0.01674894348385689
# 315
# [ 1.80319336 -0.11472893]
# 0.02013137773829156
# 316
# [ 1.80796381 -0.10930322]
# 0.014312228606738246
# 317
# Contains multiple ghost cell corners.
# [ 1.81257446 -0.10345153]
# 0.008848670135630197
# 318
# Contains multiple ghost cell corners.
# [ 1.81690652 -0.09742879]
# 0.003876354441340979
# 319
# Contains multiple ghost cell corners.
# [1.81690652 0.09742879]
# 0.0038763544413409038
# 320
# Contains multiple ghost cell corners.
# [1.81257446 0.10345153]
# 0.00884867013563157
# 321
# [1.80796381 0.10930322]
# 0.01431222860673824
# 322
# [1.80319336 0.11472893]
# 0.020131377738290726
# 323
# [ 1.81037489 -0.09321913]
# 0.02034468035091618
# 324
# [ 1.8143613  -0.08700909]
# 0.01563043363941479
# 325
# [ 1.81802676 -0.0807379 ]
# 0.01135631791572249
# 326
# Contains multiple ghost cell corners.
# [ 1.8214413  -0.07421356]
# 0.007449696355369089
# 327
# Contains multiple ghost cell corners.
# [ 1.82458689 -0.06745545]
# 0.003939430009564173
# 328
# Contains multiple ghost cell corners.
# [ 1.82744706 -0.06048414]
# 0.000752498624707182
# 329
# Contains multiple ghost cell corners.
# [1.82744706 0.06048414]
# 0.0007524986247057026
# 330
# Contains multiple ghost cell corners.
# [1.82458689 0.06745545]
# 0.00393943000956335
# 331
# Contains multiple ghost cell corners.
# [1.8214413  0.07421356]
# 0.007449696355367988
# 332
# [1.81802676 0.0807379 ]
# 0.011356317915722914
# 333
# [1.8143613  0.08700909]
# 0.015630433639413195
# 334
# [1.81037489 0.09321913]
# 0.020344680350913386
# 335
# [ 1.8201241  -0.05776212]
# 0.01759650372418811
# 336
# [ 1.82255926 -0.05096186]
# 0.014796166163021943
# 337
# [ 1.82469893 -0.04399834]
# 0.012356687918508226
# 338
# [ 1.82652962 -0.036777  ]
# 0.01030966426411099
# 339
# [ 1.82802378 -0.0295726 ]
# 0.0086293948037528
# 340
# Contains multiple ghost cell corners.
# [ 1.82919618 -0.02227157]
# 0.007353470829378067
# 341
# Contains multiple ghost cell corners.
# [ 1.83004055 -0.01489808]
# 0.006434313430351279
# 342
# Contains multiple ghost cell corners.
# [ 1.83055247 -0.00747662]
# 0.005876593667905498
# 343
# Contains multiple ghost cell corners.
# [1.83072917 0.        ]
# 0.00568334952759853
# 344
# Contains multiple ghost cell corners.
# [1.83055247 0.00747662]
# 0.005876593667906241
# 345
# Contains multiple ghost cell corners.
# [1.83004055 0.01489808]
# 0.006434313430351703
# 346
# Contains multiple ghost cell corners.
# [1.82919618 0.02227157]
# 0.007353470829377797
# 347
# [1.82802378 0.0295726 ]
# 0.008629394803753125
# 348
# [1.82652962 0.036777  ]
# 0.010309664264111673
# 349
# [1.82469893 0.04399834]
# 0.01235668791850767
# 350
# [1.82255926 0.05096186]
# 0.014796166163020577
# 351
# [1.8201241  0.05776212]
# 0.017596503724187647

# %%
dens0 = dens.where(mask) - np.nanmean(dens.where(mask), axis=(1,2), keepdims=True)
true0 = dens_true.where(mask) - np.nanmean(dens_true.where(mask), axis=(1,2), keepdims=True)
dens_diff0 = dens0 - true0
dens_diff = dens.where(mask) - dens_true.where(mask)

l2_err_t = np.sqrt(np.nanmean(dens_diff**2, axis=(1, 2)))
l2_err_n_t = np.sqrt(np.nanmean(dens_diff0**2, axis=(1, 2)))

print("Dirichlet Linf int err: " + str(np.max(l2_err_t)))
print("Dirichlet L2 int err (early): "   + str(l2_err_t[timestep_for_errs_early]))
print("Dirichlet L2 int err (late): "   + str(l2_err_t[timestep_for_errs_late]))

print("Neumann Linf int err: " + str(np.max(l2_err_n_t)))
print("Neumann L2 int err (early): "   + str(l2_err_n_t[timestep_for_errs_early]))
print("Neumann L2 int err (late): "   + str(l2_err_n_t[timestep_for_errs_late]))

#l2_err = np.sqrt(np.nanmean(dens_diff[100,:,:]**2))
#l2_unnorm = np.sqrt(np.nansum(dens_diff[100,:,:]**2)*dx*dz)
#l2_rel = np.sqrt(np.nansum(dens_diff[100,:,:]**2)*dx*dz) / np.sqrt(np.nansum(dens_true[100,:,:]**2)*dx*dz)
#print("L2 (RMS): "    + str(l2_err))
#print("L2 (unnorm): " + str(l2_unnorm))
#print("L2 (rel): "    + str(l2_rel))
#
true = dens_true.values[1:10, len(x)//2, len(z)//2] - dens_true.values[0, len(x)//2, len(z)//2]
sim = dens.values[1:10, len(x)//2, len(z)//2] - dens.values[0, len(x)//2, len(z)//2]
#print(*np.abs(sim-true), sep="\n")

init_dens_diff = dens_diff[0,:,:]
mask2 = init_dens_diff.notnull() & (init_dens_diff >= 1e-10)
nerrs = int(mask2.sum().compute())

ii, jj = np.where(mask2)

if nerrs > 0:
    print(init_dens_diff.values[ii[0],jj[0]])
    print(dens.values[0,ii[0],jj[0]])
    print(dens_true.values[0,ii[0],jj[0]])

print(nerrs)

plt.plot(t_norm, l2_err_t)
plt.xlabel("Time [s]")
plt.ylabel("L2 error (RMS)")
plt.title("Time evolution of L2 error")
plt.show()
# Out:
# Dirichlet Linf int err: 3.996152133707245e-05
# Dirichlet L2 int err (early): 3.419268380223026e-05
# Dirichlet L2 int err (late): 5.707397281298358e-07
# Neumann Linf int err: 3.56462697747519e-05
# Neumann L2 int err (early): 3.1866335403225704e-05
# Neumann L2 int err (late): 4.990030498176122e-07
# 0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dens_diff.bout.animate2D(aspect='equal')
# Out:
# Nh+ data passed has 3 dimensions - will use animatplot.blocks.Pcolormesh()
# warning: adding timeline slider to gridspec failed, adding in independent axes. tight_layout() will ignore the slider.
# warning: adding play/pause button to gridspec failed, adding in independent axes. tight_layout() will ignore the button.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
import matplotlib.pyplot as plt

# dens: shape (nt, nx, nz)
# time: shape (nt,)
# dx, dz: scalar cell sizes (uniform grid)
# If nonuniform, use cell area weights instead of dx*dz.

area = dx * dz
# Compute L2 amplitude (norm of dens component)
amp = np.sqrt(np.nansum(dens**2, axis=(1, 2))*dx*dz)

# Take the natural log of amplitude
logA = np.log(amp)

# Choose a time window where the decay is clean (exclude t=0 if noisy)
t_fit = t_norm[5:]       # skip a few early points if needed
logA_fit = logA[5:]

# Linear fit: log(A) = a + b * t
coeffs = np.polyfit(t_fit, logA_fit, 1)
slope, intercept = coeffs[0], coeffs[1]

print(f"Measured slope = {slope:.6e}  (expected -D*alpha1^2)")

# Example for first root of J1
from scipy.special import jn_zeros
alpha1 = jn_zeros(0, 1)[0]  # ~3.8317 for J1's first root

expected_slope = -D * alpha1**2/a**2
print(f"Expected slope = {expected_slope:.6e}")
print(f"Ratio (measured/expected) = {slope / expected_slope:.3f}")

plt.figure(figsize=(6,4))
plt.plot(t_fit, logA_fit, 'o-', label='log(L2 amplitude)')
plt.plot(t_fit, intercept + slope*t_fit, 'r--', label=f'Fit slope = {slope:.3e}')
plt.plot(t_fit, np.log(amp[0]) + expected_slope*t_fit, 'k:', 
         label=f'Expected slope = {expected_slope:.3e}')
plt.xlabel('Time')
plt.ylabel('log(L2 amplitude)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Measured slope = -1.040940e+01  (expected -D*alpha1^2)
# Expected slope = -1.040973e+01
# Ratio (measured/expected) = 1.000
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
res_true = (D/(x_unit*x_unit*w_unit))*(alpha0**2/(a/x_unit)**2)*dens_true.where(mask)[0,:,:]
res_sim = ds["SNh+"][0,2:-2,:].where(mask)

res = res_sim + res_true

res_L2 = np.sqrt(np.nansum((res**2)) * dx*dz)
print("||res||_L2 =", float(res_L2)) #, "   relative =", float(rel_res))

# %%
import numpy as np

# Inputs:
# uh, uex: arrays (time, nx, nz) or (nx, nz)
# mask: boolean (nx, nz) == True inside domain
# dx, dz: scalars; area per cell
area = dx*dz
h = min(dx, dz)

# --- simple binary erosion by 1 cell (4-neighborhood) ---
def erode1(m):
    return (m &
            np.roll(m,  1, 0) & np.roll(m, -1, 0) &
            np.roll(m,  1, 1) & np.roll(m, -1, 1))

def erode(m, k):
    out = m.copy()
    for _ in range(k):
        out = erode1(out)
    return out

# choose physical thickness delta = c*h0; set c=2 or 3
c = 2.0
k = max(1, int(np.ceil(c * h / h)))  # simplifies to int(c); keep form for clarity
mask_bool = mask > 0.5
mask_int = erode(mask_bool, k)            # interior region
mask_bnd = mask_bool & ~mask_int          # boundary band (k cells thick)

# error field at time index it
def l2_on(m, e):
    return np.sqrt(np.sum((e**2) * m) * area)

def l2_split(uh, uex, it):
    e = (uh[it] - uex[it])
    L2_full = l2_on(mask_bool, e)
    L2_int  = l2_on(mask_int, e)
    L2_bnd  = l2_on(mask_bnd, e)
    return L2_full, L2_int, L2_bnd

# example:
L2_full, L2_int, L2_bnd = l2_split(dens0.values, true0.values, it=10)
print(L2_full, L2_int, L2_bnd, L2_bnd/L2_full)

# %%
print(dens.values[0,len(x)//2, len(z)//2])
print(dens.values[1,len(x)//2, len(z)//2])
print(dens_true.values[1,len(x)//2, len(z)//2])
print((dens - dens_true).values[1,len(x)//2,len(z)//2])
# Out:
# 1.0
# 0.9471226227413696
# 0.9471127104071816
# 9.912334188011407e-06
