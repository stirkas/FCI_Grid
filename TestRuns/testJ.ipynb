# %%
# set up matplotlib
# %matplotlib widget
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (8, 8)
plt.rcParams.update({"font.size": 14})

# %%
import numpy as np
import xarray as xr
from scipy.special import j0
from scipy.interpolate import RectBivariateSpline
from xbout import open_boutdataset

# %%
case = "1" # Case 1 is for anomalous density diffusion only.
filepath = "testJ/BOUT.dmp.*.nc"
#filepath = "test" + str(case) + "/BOUT.dmp.0.nc"

ds = open_boutdataset(datapath=filepath, chunks={"t": 4})
dsn = xr.open_dataset("circle_lowestres2.fci.nc")

# Use squeeze() to get rid of the y-dimension, which has length 1 usually unless turbulent.
ds = ds.squeeze(drop=True)
dsn = dsn.squeeze(drop=True)

for key,val in ds.items():
    print(key)
# Out:
# Read in:
# <xbout.BoutDataset>
# Contains:
# <xarray.Dataset> Size: 46MB
# Dimensions:             (x: 68, y: 1, z: 68, t: 201)
# Coordinates:
#     dx                  (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#     dy                  (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#     dz                  (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#   * t                   (t) float64 2kB 0.0 5e+05 1e+06 ... 9.95e+07 1e+08
#   * x                   (x) int64 544B 0 1 2 3 4 5 6 7 ... 61 62 63 64 65 66 67
#   * y                   (y) float64 8B 0.1963
#   * z                   (z) float64 544B 0.007353 0.02206 ... 0.9779 0.9926
# Data variables: (12/52)
#     Bxy                 (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#     G1                  (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#     G2                  (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#     G3                  (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#     J                   (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#     Nh+                 (t, x, y, z) float64 7MB dask.array<chunksize=(4, 68, 1, 68), meta=np.ndarray>
#     ...                  ...
#     wtime_invert        (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_io            (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs       (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs_e     (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs_i     (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_rhs           (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
# Attributes:
#     metadata:  {'BOUT_VERSION': 5.2, 'Bnorm': 1.0, 'Cs0': 21884.735894072473,...
#     options:   None
#     geometry:
# Metadata:
# {   'BOUT_VERSION': 5.2,
#     'Bnorm': 1.0,
#     'Cs0': 21884.735894072473,
#     'HERMES_REVISION': 'bb9053e6425e047f16ae55670f3ede40cddfc2c5',
#     'HERMES_SLOPE_LIMITER': 'MC',
#     'MXG': 2,
#     'MXSUB': 64,
#     'MYG': 1,
#     'MYPE': 0,
#     'MYSUB': 1,
#     'MZ': 68,
#     'MZG': 0,
#     'MZSUB': 68,
#     'NXPE': 1,
#     'NYPE': 1,
#     'NZPE': 1,
#     'Nnorm': 2e+18,
#     'Omega_ci': 95788333.03066081,
#     'PE_XIND': 0,
#     'PE_YIND': 0,
#     'Tnorm': 5.0,
#     'ZMAX': 1.0,
#     'ZMIN': 0.0,
#     'bout_tdim': 't',
#     'bout_xdim': 'x',
#     'bout_ydim': 'y',
#     'bout_zdim': 'z',
#     'fine_interpolation_factor': 8,
#     'has_adios2': 0,
#     'has_caliper': 0,
#     'has_cuda': 0,
#     'has_fftw': 1,
#     'has_gettext': 0,
#     'has_hypre': 0,
#     'has_lapack': 0,
#     'has_netcdf': 1,
#     'has_petsc': 1,
#     'has_pretty_function': 1,
#     'has_pvode': 1,
#     'has_raja': 0,
#     'has_scorep': 0,
#     'has_slepc': 0,
#     'has_sundials': 1,
#     'has_umpire': 0,
#     'hist_hi': 200,
#     'is_restart': 0,
#     'ixseps1': 69,
#     'ixseps2': 69,
#     'jyseps1_1': -1,
#     'jyseps1_2': 0,
#     'jyseps2_1': 0,
#     'jyseps2_2': 0,
#     'keep_xboundaries': 1,
#     'keep_yboundaries': 0,
#     'nx': 68,
#     'ny': 1,
#     'ny_inner': 0,
#     'nz': 68,
#     'openmp_threads': 1,
#     'rho_s0': 0.0002284697436697996,
#     'run_id': '689ba156-68e6-4e68-8f83-504660495f18',
#     'run_restart_from': 'zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz',
#     'tt': 100000000.0,
#     'use_backtrace': 1,
#     'use_check_level': 2,
#     'use_color': 1,
#     'use_metric_3d': 1,
#     'use_msgstack': 1,
#     'use_openmp': 0,
#     'use_openmp_schedule': 'static',
#     'use_output_debug': 0,
#     'use_sigfpe': 0,
#     'use_signal': 1,
#     'use_track': 1,
#     'zperiod': 1}
#
# Bxy
# G1
# G2
# G3
# J
# Nh+
# R
# SNh+
# Sh+_anom
# Sh+_src
# Z
# anomalous_Chi_h+
# anomalous_D_h+
# anomalous_nu_h+
# cvode_last_order
# cvode_last_step
# cvode_nfevals
# cvode_nliters
# cvode_nniters
# cvode_nonlin_fails
# cvode_npevals
# cvode_nsteps
# cvode_num_fails
# cvode_stab_lims
# ddt(Nh+)
# g11
# g12
# g13
# g22
# g23
# g33
# g_11
# g_12
# g_13
# g_22
# g_23
# g_33
# iteration
# pfh+_tot_xlow
# t_array
# ncalls
# ncalls_e
# ncalls_i
# wall_time
# wtime
# wtime_comms
# wtime_invert
# wtime_io
# wtime_per_rhs
# wtime_per_rhs_e
# wtime_per_rhs_i
# wtime_rhs
# /home/tirkas1/miniconda3/lib/python3.13/site-packages/xbout/load.py:341: UserWarning: No geometry type found, no physical coordinates will be added
#   warn("No geometry type found, no physical coordinates will be added")

# %%
dx = ds["dx"].isel(z=0).values

# Get rid of existing "x" coordinate, which is just the index values.
#ds = ds.drop("x")

# Create a new coordinate, which is length in units of rho_s
ds = ds.assign_coords(x=np.arange(ds.sizes["x"])*dx)

#Store just initial values as well.
ds_initial = ds.isel(t=0)

# %%
dens = ds["Nh+"][:,2:-2,:]
dens_true = dens.copy()

mask = dsn["in_mask"][2:-2,:]
ghost_id = dsn["ghost_id"].values
gst_pts = dsn["ghost_pts"].values
bdy_pts = dsn["bndry_pts"].values
img_pts = dsn["image_pts"].values
normals = dsn["normals"].values
is_plasma = dsn["is_plasma"].values
Rarr = dsn["R"].values[2:-2,:]
Zarr = dsn["Z"].values

timestep_for_errs_early = 10
timestep_for_errs_late = 100
spl_e = RectBivariateSpline(Rarr[:,0], Zarr[0,:], dens.values[timestep_for_errs_early,:,:], kx=1, ky=1)
spl_l = RectBivariateSpline(Rarr[:,0], Zarr[0,:], dens.values[timestep_for_errs_late,:,:], kx=1, ky=1)

# %%
alpha0 = 2.404825557693792
xc, zc = 1.5, 0.0

x_unit = 0.00022846974366979959 #rho_s0
w_unit = 95788333.030660808     #Omega_ci
t_unit = 1/w_unit

nx = 64*int(case)
nz = nx + 4
dx = np.float64(1.0) / np.float64(nx)
dz = np.float64(1.0) / np.float64(nz)

# Centers in x; faces/nodes in z if that's your convention
x = (np.arange(nx, dtype=np.float64) + 0.5) * dx     # centered x
z = (np.arange(nz, dtype=np.float64)) * dz           # unshifted z

xhalf  = np.float64(x[len(x)//2])
zhalf  = np.float64(z[len(z)//2])

xx, zz = np.meshgrid(x,z,indexing='ij',copy=False)
a      = np.float64(1/3)
D      = np.float64(1.8) #/(x_unit*x_unit*w_unit)
t64 = np.asarray(ds["t_array"].values, dtype=np.float64) # 1D time
t_norm = t64*t_unit
#spatial = ((xx - xhalf)**2 + (zz-zhalf)**2)
spatial = j0(alpha0*np.hypot(xx - xhalf, zz - zhalf)/a)
#temp = 4.0*D*t_norm #t64/t64[-1]
a_norm = a/x_unit
temp = np.exp(-D * (alpha0 / (a))**2 * (t_norm))

#dens_true[:,:,:] = np.asarray(spatial)[np.newaxis,:,:] + np.asarray(temp)[:,np.newaxis,np.newaxis]
dens_true[:,:,:] = np.asarray(spatial)[np.newaxis,:,:]*np.asarray(temp)[:,np.newaxis,np.newaxis]

bdy_pts_xz_e = spl_e.ev(bdy_pts[:,0], bdy_pts[:,1])
bdy_pts_xz_l = spl_l.ev(bdy_pts[:,0], bdy_pts[:,1])
print("Linf bdy err if dirichlet: " + str(np.max(np.abs(bdy_pts_xz_e))))
print("L2 bdy err (early) if dirichlet?: "  + str(np.mean(np.abs(bdy_pts_xz_e))))
print("L2 bdy err (late) if dirichlet?: "  + str(np.mean(np.abs(bdy_pts_xz_l))))

#dndR = spl.ev(bdy_pts[:,0], bdy_pts[:,1], dx=1, dy=0) # ∂n/∂R at boundary points
#dndZ = spl.ev(bdy_pts[:,0], bdy_pts[:,1], dx=0, dy=1) # ∂n/∂Z at boundary points
#dn_dn = dndR * normals[:,0] + dndZ * normals[:,1]     # normal derivative
dP = np.einsum('ij,ij->i', (bdy_pts - img_pts), -normals)
dG = np.einsum('ij,ij->i', (gst_pts - bdy_pts), -normals)
dn_dn_e = (spl_e.ev(img_pts[:,0], img_pts[:,1]) - spl_e.ev(gst_pts[:,0], gst_pts[:,1])) / (dP + dG)
dn_dn_l = (spl_l.ev(img_pts[:,0], img_pts[:,1]) - spl_l.ev(gst_pts[:,0], gst_pts[:,1])) / (dP + dG)

Linf = np.max(np.abs(dn_dn_e))
L2   = np.sqrt(np.mean(dn_dn_e**2))
L2   = np.sqrt(np.mean(dn_dn_l**2))
print("Linf bdy err if neumann: " + str(np.max(np.abs(dn_dn_e))))
print("L2 bdy err (early) if neumann: " + str(np.sqrt(np.mean(dn_dn_e**2))))
print("L2 bdy err (late) if neumann: " + str(np.sqrt(np.mean(dn_dn_l**2))))
# Out:
# Linf bdy err if dirichlet: 0.0004653370920723772
# L2 bdy err (early) if dirichlet?: 0.00018794847005593966
# L2 bdy err (late) if dirichlet?: 1.4142293806465218e-06
# Linf bdy err if neumann: 0.7422670268662065
# L2 bdy err (early) if neumann: 0.7301519602618688
# L2 bdy err (late) if neumann: 0.005493990356207243

# %%
img_pts_xz = spl_e.ev(img_pts[:,0], img_pts[:,1])

i = 0
for idx in range(nx+4):
    for idz in range(nz):
        gid = int(ghost_id[idx,idz])
        if gid >= 0:
            print(gid)
            if (not (is_plasma[gid,0] and is_plasma[gid,1] and is_plasma[gid,2] and is_plasma[gid,3])):
               print("Contains multiple ghost cell corners.")
            print(img_pts[gid])
            print(img_pts_xz[gid])
# Out:
# 0
# Contains multiple ghost cell corners.
# [ 1.58342369 -0.16121567]
# 0.03394751845411123
# 1
# [ 1.57098204 -0.12214335]
# 0.02905320436626996
# 2
# [ 1.56200591 -0.08265425]
# 0.0255224517999714
# 3
# [ 1.55655222 -0.04135139]
# 0.023450926346584335
# 4
# [1.5546875e+00 2.4492936e-16]
# 0.022755567929182163
# 5
# [1.55655222 0.04135139]
# 0.023450926346584435
# 6
# [1.56200591 0.08265425]
# 0.02552245179997173
# 7
# [1.57098204 0.12214335]
# 0.029053204366270187
# 8
# Contains multiple ghost cell corners.
# [1.58342369 0.16121567]
# 0.033947518454111536
# 9
# Contains multiple ghost cell corners.
# [ 1.62500061 -0.32159589]
# 0.0336719559613174
# 10
# [ 1.59960751 -0.29005095]
# 0.023115310597849898
# 11
# Contains multiple ghost cell corners.
# [ 1.57644782 -0.25460652]
# 0.014024561349552093
# 12
# Contains multiple ghost cell corners.
# [ 1.55623969 -0.21684153]
# 0.006413961792065211
# 13
# Contains multiple ghost cell corners.
# [ 1.53923311 -0.17643991]
# 6.349482177896835e-05
# 14
# Contains multiple ghost cell corners.
# [1.53923311 0.17643991]
# 6.349482177897371e-05
# 15
# Contains multiple ghost cell corners.
# [1.55623969 0.21684153]
# 0.006413961792065
# 16
# Contains multiple ghost cell corners.
# [1.57644782 0.25460652]
# 0.014024561349552024
# 17
# [1.59960751 0.29005095]
# 0.0231153105978498
# 18
# Contains multiple ghost cell corners.
# [1.62500061 0.32159589]
# 0.03367195596131689
# 19
# [ 1.68506918 -0.43463067]
# 0.04116989873307406
# 20
# [ 1.65144609 -0.41068367]
# 0.026439304735570032
# 21
# Contains multiple ghost cell corners.
# [ 1.61935909 -0.38297428]
# 0.013123399911586882
# 22
# Contains multiple ghost cell corners.
# [ 1.58921486 -0.35170001]
# 0.001273951735655583
# 23
# Contains multiple ghost cell corners.
# [1.58921486 0.35170001]
# 0.0012739517356558764
# 24
# Contains multiple ghost cell corners.
# [1.61935909 0.38297428]
# 0.013123399911586973
# 25
# [1.65144609 0.41068367]
# 0.026439304735570053
# 26
# [1.68506918 0.43463067]
# 0.04116989873307439
# 27
# [ 1.73267638 -0.50942947]
# 0.043951602049124454
# 28
# [ 1.69498277 -0.49266496]
# 0.026446499096427135
# 29
# Contains multiple ghost cell corners.
# [ 1.65791173 -0.47167964]
# 0.010280483013476028
# 30
# Contains multiple ghost cell corners.
# [1.65791173 0.47167964]
# 0.01028048301347628
# 31
# [1.69498277 0.49266496]
# 0.02644649909642759
# 32
# [1.73267638 0.50942947]
# 0.04395160204912472
# 33
# [ 1.75339696 -0.56367828]
# 0.03369556824213499
# 34
# Contains multiple ghost cell corners.
# [ 1.71320301 -0.55083637]
# 0.014628334613370493
# 35
# Contains multiple ghost cell corners.
# [1.71320301 0.55083637]
# 0.014628334613370394
# 36
# [1.75339696 0.56367828]
# 0.03369556824213455
# 37
# [ 1.78170421 -0.61594198]
# 0.02636913238177321
# 38
# Contains multiple ghost cell corners.
# [ 1.73960041 -0.60760028]
# 0.005937446849737366
# 39
# Contains multiple ghost cell corners.
# [1.73960041 0.60760028]
# 0.005937446849737201
# 40
# [1.78170421 0.61594198]
# 0.026369132381773137
# 41
# [ 1.85922394 -0.66421356]
# 0.045019870539769274
# 42
# Contains multiple ghost cell corners.
# [ 1.81708066 -0.66483818]
# 0.021885785879948997
# 43
# Contains multiple ghost cell corners.
# [ 1.77377218 -0.66147241]
# 0.00016011817196529641
# 44
# Contains multiple ghost cell corners.
# [1.77377218 0.66147241]
# 0.00016011817196539893
# 45
# Contains multiple ghost cell corners.
# [1.81708066 0.66483818]
# 0.02188578587994906
# 46
# [1.85922394 0.66421356]
# 0.045019870539770225
# 47
# [ 1.90124184 -0.70371728]
# 0.0449886532079578
# 48
# Contains multiple ghost cell corners.
# [ 1.8587684 -0.709109 ]
# 0.02037097430019816
# 49
# Contains multiple ghost cell corners.
# [1.8587684 0.709109 ]
# 0.020370974300199164
# 50
# [1.90124184 0.70371728]
# 0.04498865320795864
# 51
# [ 1.90579416 -0.74765954]
# 0.022027845908815534
# 52
# [1.90579416 0.74765954]
# 0.022027845908816596
# 53
# Contains multiple ghost cell corners.
# [ 1.95700023 -0.77959182]
# 0.02673645464750276
# 54
# Contains multiple ghost cell corners.
# [ 1.91527919 -0.79253873]
# 0.0007185172617542625
# 55
# Contains multiple ghost cell corners.
# [1.91527919 0.79253873]
# 0.0007185172617540964
# 56
# Contains multiple ghost cell corners.
# [1.95700023 0.77959182]
# 0.026736454647502447
# 57
# [ 2.01108031 -0.80423343]
# 0.03427867596094702
# 58
# Contains multiple ghost cell corners.
# [ 1.9715761  -0.82252307]
# 0.006846197577597819
# 59
# Contains multiple ghost cell corners.
# [1.9715761  0.82252307]
# 0.006846197577597606
# 60
# [2.01108031 0.80423343]
# 0.034278675960946886
# 61
# [ 2.06661953 -0.82116015]
# 0.04471189053463208
# 62
# Contains multiple ghost cell corners.
# [ 2.03017339 -0.84452155]
# 0.015856943671388877
# 63
# Contains multiple ghost cell corners.
# [2.03017339 0.84452155]
# 0.015856943671387836
# 64
# [2.06661953 0.82116015]
# 0.04471189053463197
# 65
# [ 2.08955947 -0.85823762]
# 0.028052024822816858
# 66
# [2.08955947 0.85823762]
# 0.02805202482281755
# 67
# [ 2.14818122 -0.86365177]
# 0.043295095979476485
# 68
# Contains multiple ghost cell corners.
# [ 2.11636281 -0.89362709]
# 0.012942952362288719
# 69
# Contains multiple ghost cell corners.
# [2.11636281 0.89362709]
# 0.01294295236228965
# 70
# [2.14818122 0.86365177]
# 0.0432950959794766
# 71
# [ 2.17806324 -0.89516789]
# 0.029640370581458915
# 72
# [2.17806324 0.89516789]
# 0.029640370581459553
# 73
# [ 2.21101338 -0.92402226]
# 0.017710511865073834
# 74
# [2.21101338 0.92402226]
# 0.017710511865073948
# 75
# [ 2.27106564 -0.91279061]
# 0.03904527345823237
# 76
# Contains multiple ghost cell corners.
# [ 2.24792198 -0.9503504 ]
# 0.007604497751301623
# 77
# Contains multiple ghost cell corners.
# [2.24792198 0.9503504 ]
# 0.00760449775130169
# 78
# [2.27106564 0.91279061]
# 0.03904527345823238
# 79
# [ 2.3077178  -0.93395113]
# 0.03026353490153947
# 80
# [2.3077178  0.93395113]
# 0.030263534901539532
# 81
# [ 2.34722714 -0.95193122]
# 0.023192262704383505
# 82
# [2.34722714 0.95193122]
# 0.023192262704383505
# 83
# [ 2.38968134 -0.96635782]
# 0.01765429882301108
# 84
# [2.38968134 0.96635782]
# 0.01765429882301107
# 85
# Contains multiple ghost cell corners.
# [ 2.43318856 -0.97677443]
# 0.013804514881573093
# 86
# Contains multiple ghost cell corners.
# [2.43318856 0.97677443]
# 0.013804514881572997
# 87
# Contains multiple ghost cell corners.
# [ 2.47791949 -0.98313182]
# 0.011509340481100321
# 88
# Contains multiple ghost cell corners.
# [2.47791949 0.98313182]
# 0.011509340481100522
# 89
# Contains multiple ghost cell corners.
# [ 2.5234375  -0.98529412]
# 0.010733805255769804
# 90
# Contains multiple ghost cell corners.
# [2.5234375  0.98529412]
# 0.01073380525576978
# 91
# Contains multiple ghost cell corners.
# [ 2.56895551 -0.98313182]
# 0.011509340481100345
# 92
# Contains multiple ghost cell corners.
# [2.56895551 0.98313182]
# 0.01150934048110039
# 93
# Contains multiple ghost cell corners.
# [ 2.61368644 -0.97677443]
# 0.013804514881572574
# 94
# Contains multiple ghost cell corners.
# [2.61368644 0.97677443]
# 0.013804514881573218
# 95
# [ 2.65719366 -0.96635782]
# 0.017654298823011214
# 96
# [2.65719366 0.96635782]
# 0.017654298823011214
# 97
# [ 2.69964786 -0.95193122]
# 0.023192262704383498
# 98
# [2.69964786 0.95193122]
# 0.02319226270438382
# 99
# [ 2.7391572  -0.93395113]
# 0.030263534901539726
# 100
# [2.7391572  0.93395113]
# 0.03026353490154001
# 101
# [ 2.77580936 -0.91279061]
# 0.03904527345823282
# 102
# Contains multiple ghost cell corners.
# [ 2.79895302 -0.9503504 ]
# 0.00760449775130136
# 103
# Contains multiple ghost cell corners.
# [2.79895302 0.9503504 ]
# 0.0076044977513014915
# 104
# [2.77580936 0.91279061]
# 0.03904527345823276
# 105
# [ 2.83586162 -0.92402226]
# 0.01771051186507416
# 106
# [2.83586162 0.92402226]
# 0.01771051186507378
# 107
# [ 2.86881176 -0.89516789]
# 0.02964037058145931
# 108
# [2.86881176 0.89516789]
# 0.029640370581459456
# 109
# [ 2.89869378 -0.86365177]
# 0.043295095979476846
# 110
# Contains multiple ghost cell corners.
# [ 2.93051219 -0.89362709]
# 0.012942952362289109
# 111
# Contains multiple ghost cell corners.
# [2.93051219 0.89362709]
# 0.012942952362289414
# 112
# [2.89869378 0.86365177]
# 0.04329509597947586
# 113
# [ 2.95731553 -0.85823762]
# 0.028052024822816417
# 114
# [2.95731553 0.85823762]
# 0.028052024822816792
# 115
# [ 2.98025547 -0.82116015]
# 0.04471189053463015
# 116
# Contains multiple ghost cell corners.
# [ 3.01670161 -0.84452155]
# 0.015856943671388235
# 117
# Contains multiple ghost cell corners.
# [3.01670161 0.84452155]
# 0.015856943671387354
# 118
# [2.98025547 0.82116015]
# 0.044711890534631364
# 119
# [ 3.03579469 -0.80423343]
# 0.0342786759609456
# 120
# Contains multiple ghost cell corners.
# [ 3.0752989  -0.82252307]
# 0.0068461975775976
# 121
# Contains multiple ghost cell corners.
# [3.0752989  0.82252307]
# 0.006846197577597886
# 122
# [3.03579469 0.80423343]
# 0.03427867596094711
# 123
# Contains multiple ghost cell corners.
# [ 3.08987477 -0.77959182]
# 0.02673645464750199
# 124
# Contains multiple ghost cell corners.
# [ 3.13159581 -0.79253873]
# 0.0007185172617539872
# 125
# Contains multiple ghost cell corners.
# [3.13159581 0.79253873]
# 0.0007185172617540018
# 126
# Contains multiple ghost cell corners.
# [3.08987477 0.77959182]
# 0.026736454647503606
# 127
# [ 3.14108084 -0.74765954]
# 0.022027845908814927
# 128
# [3.14108084 0.74765954]
# 0.022027845908818667
# 129
# [ 3.14563316 -0.70371728]
# 0.04498865320795782
# 130
# Contains multiple ghost cell corners.
# [ 3.1881066 -0.709109 ]
# 0.02037097430019803
# 131
# Contains multiple ghost cell corners.
# [3.1881066 0.709109 ]
# 0.02037097430020178
# 132
# [3.14563316 0.70371728]
# 0.04498865320796096
# 133
# [ 3.18765106 -0.66421356]
# 0.04501987053976792
# 134
# Contains multiple ghost cell corners.
# [ 3.22979434 -0.66483818]
# 0.021885785879947505
# 135
# Contains multiple ghost cell corners.
# [ 3.27310282 -0.66147241]
# 0.0001601181719659091
# 136
# Contains multiple ghost cell corners.
# [3.27310282 0.66147241]
# 0.000160118171966187
# 137
# Contains multiple ghost cell corners.
# [3.22979434 0.66483818]
# 0.02188578587994996
# 138
# [3.18765106 0.66421356]
# 0.0450198705397705
# 139
# [ 3.26517079 -0.61594198]
# 0.02636913238177114
# 140
# Contains multiple ghost cell corners.
# [ 3.30727459 -0.60760028]
# 0.005937446849737349
# 141
# Contains multiple ghost cell corners.
# [3.30727459 0.60760028]
# 0.005937446849737253
# 142
# [3.26517079 0.61594198]
# 0.026369132381772506
# 143
# [ 3.29347804 -0.56367828]
# 0.033695568242133
# 144
# Contains multiple ghost cell corners.
# [ 3.33367199 -0.55083637]
# 0.014628334613370096
# 145
# Contains multiple ghost cell corners.
# [3.33367199 0.55083637]
# 0.014628334613370465
# 146
# [3.29347804 0.56367828]
# 0.033695568242133614
# 147
# [ 3.31419862 -0.50942947]
# 0.04395160204912299
# 148
# [ 3.35189223 -0.49266496]
# 0.026446499096426285
# 149
# Contains multiple ghost cell corners.
# [ 3.38896327 -0.47167964]
# 0.010280483013475127
# 150
# Contains multiple ghost cell corners.
# [3.38896327 0.47167964]
# 0.010280483013476227
# 151
# [3.35189223 0.49266496]
# 0.02644649909642674
# 152
# [3.31419862 0.50942947]
# 0.04395160204912417
# 153
# [ 3.36180582 -0.43463067]
# 0.0411698987330732
# 154
# [ 3.39542891 -0.41068367]
# 0.026439304735568603
# 155
# Contains multiple ghost cell corners.
# [ 3.42751591 -0.38297428]
# 0.013123399911586169
# 156
# Contains multiple ghost cell corners.
# [ 3.45766014 -0.35170001]
# 0.0012739517356560983
# 157
# Contains multiple ghost cell corners.
# [3.45766014 0.35170001]
# 0.0012739517356552623
# 158
# Contains multiple ghost cell corners.
# [3.42751591 0.38297428]
# 0.013123399911586635
# 159
# [3.39542891 0.41068367]
# 0.026439304735570168
# 160
# [3.36180582 0.43463067]
# 0.04116989873307371
# 161
# Contains multiple ghost cell corners.
# [ 3.42187439 -0.32159589]
# 0.03367195596131673
# 162
# [ 3.44726749 -0.29005095]
# 0.023115310597850023
# 163
# Contains multiple ghost cell corners.
# [ 3.47042718 -0.25460652]
# 0.014024561349551885
# 164
# Contains multiple ghost cell corners.
# [ 3.49063531 -0.21684153]
# 0.006413961792064911
# 165
# Contains multiple ghost cell corners.
# [ 3.50764189 -0.17643991]
# 6.349482177896885e-05
# 166
# Contains multiple ghost cell corners.
# [3.50764189 0.17643991]
# 6.349482177853044e-05
# 167
# Contains multiple ghost cell corners.
# [3.49063531 0.21684153]
# 0.006413961792065129
# 168
# Contains multiple ghost cell corners.
# [3.47042718 0.25460652]
# 0.014024561349552015
# 169
# [3.44726749 0.29005095]
# 0.023115310597849662
# 170
# Contains multiple ghost cell corners.
# [3.42187439 0.32159589]
# 0.03367195596131736
# 171
# Contains multiple ghost cell corners.
# [ 3.46345131 -0.16121567]
# 0.03394751845411151
# 172
# [ 3.47589296 -0.12214335]
# 0.02905320436626982
# 173
# [ 3.48486909 -0.08265425]
# 0.025522451799970793
# 174
# [ 3.49032278 -0.04135139]
# 0.023450926346583734
# 175
# [3.4921875 0.       ]
# 0.0227555679291826
# 176
# [3.49032278 0.04135139]
# 0.023450926346584022
# 177
# [3.48486909 0.08265425]
# 0.025522451799971008
# 178
# [3.47589296 0.12214335]
# 0.0290532043662702
# 179
# Contains multiple ghost cell corners.
# [3.46345131 0.16121567]
# 0.03394751845411105

# %%
dens0 = dens.where(mask) - np.nanmean(dens.where(mask), axis=(1,2), keepdims=True)
true0 = dens_true.where(mask) - np.nanmean(dens_true.where(mask), axis=(1,2), keepdims=True)
dens_diff0 = dens0 - true0
dens_diff = dens.where(mask) - dens_true.where(mask)

l2_err_t = np.sqrt(np.nanmean(dens_diff**2, axis=(1, 2)))
l2_err_n_t = np.sqrt(np.nanmean(dens_diff0**2, axis=(1, 2)))

print("Dirichlet Linf int err: " + str(np.max(l2_err_t)))
print("Dirichlet L2 int err (early): "   + str(l2_err_t[timestep_for_errs_early]))
print("Dirichlet L2 int err (late): "   + str(l2_err_t[timestep_for_errs_late]))

print("Neumann Linf int err: " + str(np.max(l2_err_n_t)))
print("Neumann L2 int err (early): "   + str(l2_err_n_t[timestep_for_errs_early]))
print("Neumann L2 int err (late): "   + str(l2_err_n_t[timestep_for_errs_late]))
#l2_unnorm = np.sqrt(np.nansum(dens_diff[100,:,:]**2)*dx*dz)
#l2_rel = np.sqrt(np.nansum(dens_diff[100,:,:]**2)*dx*dz) / np.sqrt(np.nansum(dens_true[100,:,:]**2)*dx*dz)
#print("L2 (RMS): "    + str(l2_err))
#print("L2 (unnorm): " + str(l2_unnorm))
#print("L2 (rel): "    + str(l2_rel))

true = dens_true.values[1:10, len(x)//2, len(z)//2] - dens_true.values[0, len(x)//2, len(z)//2]
sim = dens.values[1:10, len(x)//2, len(z)//2] - dens.values[0, len(x)//2, len(z)//2]
#print(*np.abs(sim-true), sep="\n")

init_dens_diff = dens_diff[0,:,:]
mask2 = init_dens_diff.notnull() & (init_dens_diff >= 1e-10)
nerrs = int(mask2.sum().compute())

ii, jj = np.where(mask2)

if nerrs > 0:
    print(init_dens_diff.values[ii[0],jj[0]])
    print(dens.values[0,ii[0],jj[0]])
    print(dens_true.values[0,ii[0],jj[0]])

print(nerrs)

plt.plot(t_norm, l2_err_t)
plt.xlabel("Time [s]")
plt.ylabel("L2 error (RMS)")
plt.title("Time evolution of L2 error")
plt.show()
# Out:
# Dirichlet Linf int err: 0.00016563891747206223
# Dirichlet L2 int err (early): 0.00013937400019438398
# Dirichlet L2 int err (late): 2.3275817455189446e-06
# Neumann Linf int err: 0.0001487176543081054
# Neumann L2 int err (early): 0.00012997747758525724
# Neumann L2 int err (late): 2.030097653355756e-06
# 0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dens_diff.where(mask).bout.animate2D(aspect='equal')

# %%
import numpy as np
import matplotlib.pyplot as plt

# dens: shape (nt, nx, nz)
# time: shape (nt,)
# dx, dz: scalar cell sizes (uniform grid)
# If nonuniform, use cell area weights instead of dx*dz.

area = dx * dz
# Compute L2 amplitude (norm of dens component)
amp = np.sqrt(np.nansum(dens**2, axis=(1, 2))*dx*dz)

# Take the natural log of amplitude
logA = np.log(amp)

# Choose a time window where the decay is clean (exclude t=0 if noisy)
t_fit = t_norm[5:]       # skip a few early points if needed
logA_fit = logA[5:]

# Linear fit: log(A) = a + b * t
coeffs = np.polyfit(t_fit, logA_fit, 1)
slope, intercept = coeffs[0], coeffs[1]

print(f"Measured slope = {slope:.6e}  (expected -D*alpha1^2)")

# Example for first root of J1
from scipy.special import jn_zeros
alpha1 = jn_zeros(0, 1)[0]  # ~3.8317 for J1's first root

expected_slope = -D * alpha1**2/(3*a)**2
print(f"Expected slope = {expected_slope:.6e}")
print(f"Ratio (measured/expected) = {slope / expected_slope:.3f}")

plt.figure(figsize=(6,4))
plt.plot(t_fit, logA_fit, 'o-', label='log(L2 amplitude)')
plt.plot(t_fit, intercept + slope*t_fit, 'r--', label=f'Fit slope = {slope:.3e}')
plt.plot(t_fit, np.log(amp[0]) + expected_slope*t_fit, 'k:', 
         label=f'Expected slope = {expected_slope:.3e}')
plt.xlabel('Time')
plt.ylabel('log(L2 amplitude)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
res_true = (D/(x_unit*x_unit*w_unit))*(alpha0**2/(a/x_unit)**2)*dens_true.where(mask)[0,:,:]
res_sim = ds["SNh+"][0,2:-2,:].where(mask)

res = res_sim + res_true

res_L2 = np.sqrt(np.nansum((res**2)) * dx*dz)
print("||res||_L2 =", float(res_L2)) #, "   relative =", float(rel_res))

# %%
import numpy as np

# Inputs:
# uh, uex: arrays (time, nx, nz) or (nx, nz)
# mask: boolean (nx, nz) == True inside domain
# dx, dz: scalars; area per cell
area = dx*dz
h = min(dx, dz)

# --- simple binary erosion by 1 cell (4-neighborhood) ---
def erode1(m):
    return (m &
            np.roll(m,  1, 0) & np.roll(m, -1, 0) &
            np.roll(m,  1, 1) & np.roll(m, -1, 1))

def erode(m, k):
    out = m.copy()
    for _ in range(k):
        out = erode1(out)
    return out

# choose physical thickness delta = c*h0; set c=2 or 3
c = 2.0
k = max(1, int(np.ceil(c * h / h)))  # simplifies to int(c); keep form for clarity
mask_bool = mask > 0.5
mask_int = erode(mask_bool, k)            # interior region
mask_bnd = mask_bool & ~mask_int          # boundary band (k cells thick)

# error field at time index it
def l2_on(m, e):
    return np.sqrt(np.sum((e**2) * m) * area)

def l2_split(uh, uex, it):
    e = (uh[it] - uex[it])
    L2_full = l2_on(mask_bool, e)
    L2_int  = l2_on(mask_int, e)
    L2_bnd  = l2_on(mask_bnd, e)
    return L2_full, L2_int, L2_bnd

# example:
L2_full, L2_int, L2_bnd = l2_split(dens0.values, true0.values, it=10)
print(L2_full, L2_int, L2_bnd, L2_bnd/L2_full)

# %%
print(dens.values[0,len(x)//2,len(z)//2])
print(dens.values[10,len(x)//2,len(z)//2])
print(dens_true.values[10,len(x)//2,len(z)//2])


print(dens.values[10,len(x)//2,len(z)//2] - dens_true.values[10,len(x)//2,len(z)//2])
