# %%
# set up matplotlib
# %matplotlib widget
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (8, 8)
plt.rcParams.update({"font.size": 14})

# %%
import numpy as np
from xbout import open_boutdataset
from boutdata import collect

# %%
case = "2" # 4 and 9  have n,t,p data
filepath = "test" + str(case) + "/BOUT.dmp.0.nc"
#filepath = "test" + str(case) + "/BOUT.dmp.0.nc"

ds = open_boutdataset(datapath="test" + str(case) + "/BOUT.dmp.*.nc", chunks={"t": 4})

# Use squeeze() to get rid of the y-dimension, which has length 1 as blob2d does not
# simulate the parallel dimension.
ds = ds.squeeze(drop=True)
# Out:
# Read in:
# <xbout.BoutDataset>
# Contains:
# <xarray.Dataset> Size: 26MB
# Dimensions:             (x: 132, y: 1, z: 132, t: 166)
# Coordinates:
#     dx                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     dy                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     dz                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#   * t                   (t) float64 1kB 0.0 1e-05 2e-05 ... 0.00164 0.00165
#   * x                   (x) int64 1kB 0 1 2 3 4 5 6 ... 126 127 128 129 130 131
#   * y                   (y) float64 8B 0.1963
#   * z                   (z) float64 1kB 0.003788 0.01136 ... 0.9886 0.9962
# Data variables: (12/44)
#     Bxy                 (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     G1                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     G2                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     G3                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     J                   (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     Nh+                 (t, x, y, z) float64 23MB dask.array<chunksize=(4, 132, 1, 132), meta=np.ndarray>
#     ...                  ...
#     wtime_invert        (t) float64 1kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_io            (t) float64 1kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs       (t) float64 1kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs_e     (t) float64 1kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs_i     (t) float64 1kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_rhs           (t) float64 1kB dask.array<chunksize=(4,), meta=np.ndarray>
# Attributes:
#     metadata:  {'BOUT_VERSION': 5.2, 'Bnorm': 1.0, 'Cs0': 21884.735894072473,...
#     options:   None
#     geometry:
# Metadata:
# {   'BOUT_VERSION': 5.2,
#     'Bnorm': 1.0,
#     'Cs0': 21884.735894072473,
#     'HERMES_REVISION': 'bb9053e6425e047f16ae55670f3ede40cddfc2c5',
#     'HERMES_SLOPE_LIMITER': 'MC',
#     'MXG': 2,
#     'MXSUB': 128,
#     'MYG': 1,
#     'MYPE': 0,
#     'MYSUB': 1,
#     'MZ': 132,
#     'MZG': 0,
#     'MZSUB': 132,
#     'NXPE': 1,
#     'NYPE': 1,
#     'NZPE': 1,
#     'Nnorm': 2e+18,
#     'Omega_ci': 95788333.03066081,
#     'PE_XIND': 0,
#     'PE_YIND': 0,
#     'Tnorm': 5.0,
#     'ZMAX': 1.0,
#     'ZMIN': 0.0,
#     'bout_tdim': 't',
#     'bout_xdim': 'x',
#     'bout_ydim': 'y',
#     'bout_zdim': 'z',
#     'fine_interpolation_factor': 8,
#     'has_adios2': 0,
#     'has_caliper': 0,
#     'has_cuda': 0,
#     'has_fftw': 1,
#     'has_gettext': 1,
#     'has_hypre': 0,
#     'has_lapack': 0,
#     'has_netcdf': 1,
#     'has_petsc': 1,
#     'has_pretty_function': 1,
#     'has_pvode': 1,
#     'has_raja': 0,
#     'has_scorep': 0,
#     'has_slepc': 0,
#     'has_sundials': 1,
#     'has_umpire': 0,
#     'hist_hi': 165,
#     'is_restart': 0,
#     'ixseps1': 133,
#     'ixseps2': 133,
#     'jyseps1_1': -1,
#     'jyseps1_2': 0,
#     'jyseps2_1': 0,
#     'jyseps2_2': 0,
#     'keep_xboundaries': 1,
#     'keep_yboundaries': 0,
#     'nx': 132,
#     'ny': 1,
#     'ny_inner': 0,
#     'nz': 132,
#     'openmp_threads': 1,
#     'rho_s0': 0.0002284697436697996,
#     'run_id': '5ac95352-8fe2-4e05-a314-f0b1b6d474d3',
#     'run_restart_from': 'zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz',
#     'tt': 0.0016500000000000037,
#     'use_backtrace': 1,
#     'use_check_level': 4,
#     'use_color': 1,
#     'use_metric_3d': 1,
#     'use_msgstack': 1,
#     'use_openmp': 0,
#     'use_openmp_schedule': 'static',
#     'use_output_debug': 1,
#     'use_sigfpe': 0,
#     'use_signal': 1,
#     'use_track': 1,
#     'zperiod': 1}
# /home/tirkas1/miniconda3/lib/python3.13/site-packages/xbout/load.py:646: UserWarning: The specified chunks separate the stored chunks along dimension "t" starting at index 4. This could degrade performance. Instead, consider rechunking after loading.
#   ds = xr.open_mfdataset(
# /home/tirkas1/miniconda3/lib/python3.13/site-packages/xbout/load.py:341: UserWarning: No geometry type found, no physical coordinates will be added
#   warn("No geometry type found, no physical coordinates will be added")

# %%
dx = ds["dx"].isel(z=0).values

# Get rid of existing "x" coordinate, which is just the index values.
#ds = ds.drop("x")

# Create a new coordinate, which is length in units of rho_s
ds = ds.assign_coords(x=np.arange(ds.sizes["x"])*dx)

# %%
ds_initial = ds.isel(t=0)

# %%
for key,val in ds_initial.items():
    print(key)
# Out:
# Bxy
# G1
# G2
# G3
# J
# Nh+
# R
# Z
# cvode_last_order
# cvode_last_step
# cvode_nfevals
# cvode_nliters
# cvode_nniters
# cvode_nonlin_fails
# cvode_npevals
# cvode_nsteps
# cvode_num_fails
# cvode_stab_lims
# g11
# g12
# g13
# g22
# g23
# g33
# g_11
# g_12
# g_13
# g_22
# g_23
# g_33
# iteration
# t_array
# ncalls
# ncalls_e
# ncalls_i
# wall_time
# wtime
# wtime_comms
# wtime_invert
# wtime_io
# wtime_per_rhs
# wtime_per_rhs_e
# wtime_per_rhs_i
# wtime_rhs

# %%
ds["ddt(Nh+)"][:,2:-2,:].bout.animate2D(aspect="equal")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.13/site-packages/xarray/core/dataset.py in ?(self, name)
#    1154             variable = self._variables[name]
#    1155         except KeyError:
# -> 1156             _, name, variable = _get_virtual_variable(self._variables, name, self.sizes)
#    1157
#
# KeyError: 'ddt(Nh+)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.13/site-packages/xarray/core/dataset.py:1261, in Dataset.__getitem__(self, key)
#    1260 try:
# -> 1261     return self._construct_dataarray(key)
#    1262 except KeyError as e:
#
# File ~/miniconda3/lib/python3.13/site-packages/xarray/core/dataset.py:1156, in Dataset._construct_dataarray(self, name)
#    1155 except KeyError:
# -> 1156     _, name, variable = _get_virtual_variable(self._variables, name, self.sizes)
#    1158 needed_dims = set(variable.dims)
#
# File ~/miniconda3/lib/python3.13/site-packages/xarray/core/dataset_utils.py:79, in _get_virtual_variable(variables, key, dim_sizes)
#      78 if len(split_key) != 2:
# ---> 79     raise KeyError(key)
#      81 ref_name, var_name = split_key
#
# KeyError: 'ddt(Nh+)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_209138/1316210257.py in ?()
# ----> 1 ds["ddt(Nh+)"][:,2:-2,:].bout.animate2D(aspect="equal")
#
# ~/miniconda3/lib/python3.13/site-packages/xarray/core/dataset.py in ?(self, key)
#    1270
#    1271                 # If someone attempts `ds['foo' , 'bar']` instead of `ds[['foo', 'bar']]`
#    1272                 if isinstance(key, tuple):
#    1273                     message += f"\nHint: use a list to select multiple variables, for example `ds[{list(key)}]`"
# -> 1274                 raise KeyError(message) from e
#    1275
#    1276         if utils.iterable_of_hashable(key):
#    1277             return self._copy_listed(key)
#
# KeyError: "No variable named 'ddt(Nh+)'. Variables on the dataset include ['Bxy', 'G1', 'G2', 'G3', 'J', ..., 'wtime_per_rhs_i', 'wtime_rhs', 't', 'z', 'x']"

# %%
ds["SNh+"][:,2:-2,:].bout.animate2D(aspect="equal")

# %%
dens = ds["Nh+"][:,2:-2,:]
dens = dens.clip(min=0)
dens.bout.animate2D(aspect="equal")
# Out:
# Nh+ data passed has 3 dimensions - will use animatplot.blocks.Pcolormesh()
# warning: adding timeline slider to gridspec failed, adding in independent axes. tight_layout() will ignore the slider.
# warning: adding play/pause button to gridspec failed, adding in independent axes. tight_layout() will ignore the button.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
