# %%
# set up matplotlib
# %matplotlib widget
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (8, 8)
plt.rcParams.update({"font.size": 14})

# %%
import numpy as np
import xarray as xr
from scipy.special import j0
from scipy.interpolate import RectBivariateSpline
from xbout import open_boutdataset

# %%
case = "3_2" # Case 1 is for anomalous density diffusion only.
filepath = "mms" + str(case) + "/BOUT.dmp.0.nc"
#filepath = "test" + str(case) + "/BOUT.dmp.0.nc"

ds = open_boutdataset(datapath="mms" + str(case) + "/BOUT.dmp.*.nc", chunks={"t": 4})
dsn = xr.open_dataset("circle_midres.fci.nc")

# Use squeeze() to get rid of the y-dimension, which has length 1 usually unless turbulent.
ds = ds.squeeze(drop=True)
dsn = dsn.squeeze(drop=True)

for key,val in ds.items():
    print(key)
# Out:
# Read in:
# <xbout.BoutDataset>
# Contains:
# <xarray.Dataset> Size: 666MB
# Dimensions:             (x: 260, y: 1, z: 260, t: 201)
# Coordinates:
#     dx                  (x, y, z) float64 541kB dask.array<chunksize=(260, 1, 260), meta=np.ndarray>
#     dy                  (x, y, z) float64 541kB dask.array<chunksize=(260, 1, 260), meta=np.ndarray>
#     dz                  (x, y, z) float64 541kB dask.array<chunksize=(260, 1, 260), meta=np.ndarray>
#   * t                   (t) float64 2kB 0.0 1e+04 2e+04 ... 1.99e+06 2e+06
#   * x                   (x) int64 2kB 0 1 2 3 4 5 6 ... 254 255 256 257 258 259
#   * y                   (y) float64 8B 0.1963
#   * z                   (z) float64 2kB 0.001923 0.005769 ... 0.9942 0.9981
# Data variables: (12/52)
#     Bxy                 (x, y, z) float64 541kB dask.array<chunksize=(260, 1, 260), meta=np.ndarray>
#     G1                  (x, y, z) float64 541kB dask.array<chunksize=(260, 1, 260), meta=np.ndarray>
#     G2                  (x, y, z) float64 541kB dask.array<chunksize=(260, 1, 260), meta=np.ndarray>
#     G3                  (x, y, z) float64 541kB dask.array<chunksize=(260, 1, 260), meta=np.ndarray>
#     J                   (x, y, z) float64 541kB dask.array<chunksize=(260, 1, 260), meta=np.ndarray>
#     Nh+                 (t, x, y, z) float64 109MB dask.array<chunksize=(4, 260, 1, 260), meta=np.ndarray>
#     ...                  ...
#     wtime_invert        (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_io            (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs       (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs_e     (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs_i     (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_rhs           (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
# Attributes:
#     metadata:  {'BOUT_VERSION': 5.2, 'Bnorm': 1.0, 'Cs0': 21884.735894072473,...
#     options:   None
#     geometry:
# Metadata:
# {   'BOUT_VERSION': 5.2,
#     'Bnorm': 1.0,
#     'Cs0': 21884.735894072473,
#     'HERMES_REVISION': 'bb9053e6425e047f16ae55670f3ede40cddfc2c5',
#     'HERMES_SLOPE_LIMITER': 'MC',
#     'MXG': 2,
#     'MXSUB': 256,
#     'MYG': 1,
#     'MYPE': 0,
#     'MYSUB': 1,
#     'MZ': 260,
#     'MZG': 0,
#     'MZSUB': 260,
#     'NXPE': 1,
#     'NYPE': 1,
#     'NZPE': 1,
#     'Nnorm': 2e+18,
#     'Omega_ci': 95788333.03066081,
#     'PE_XIND': 0,
#     'PE_YIND': 0,
#     'Tnorm': 5.0,
#     'ZMAX': 1.0,
#     'ZMIN': 0.0,
#     'bout_tdim': 't',
#     'bout_xdim': 'x',
#     'bout_ydim': 'y',
#     'bout_zdim': 'z',
#     'fine_interpolation_factor': 8,
#     'has_adios2': 0,
#     'has_caliper': 0,
#     'has_cuda': 0,
#     'has_fftw': 1,
#     'has_gettext': 0,
#     'has_hypre': 0,
#     'has_lapack': 0,
#     'has_netcdf': 1,
#     'has_petsc': 1,
#     'has_pretty_function': 1,
#     'has_pvode': 1,
#     'has_raja': 0,
#     'has_scorep': 0,
#     'has_slepc': 0,
#     'has_sundials': 1,
#     'has_umpire': 0,
#     'hist_hi': 200,
#     'is_restart': 0,
#     'ixseps1': 261,
#     'ixseps2': 261,
#     'jyseps1_1': -1,
#     'jyseps1_2': 0,
#     'jyseps2_1': 0,
#     'jyseps2_2': 0,
#     'keep_xboundaries': 1,
#     'keep_yboundaries': 0,
#     'nx': 260,
#     'ny': 1,
#     'ny_inner': 0,
#     'nz': 260,
#     'openmp_threads': 1,
#     'rho_s0': 0.0002284697436697996,
#     'run_id': '3b423315-883a-404c-b87e-df753199fb95',
#     'run_restart_from': 'zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz',
#     'tt': 2000000.0,
#     'use_backtrace': 1,
#     'use_check_level': 2,
#     'use_color': 1,
#     'use_metric_3d': 1,
#     'use_msgstack': 1,
#     'use_openmp': 0,
#     'use_openmp_schedule': 'static',
#     'use_output_debug': 0,
#     'use_sigfpe': 0,
#     'use_signal': 1,
#     'use_track': 1,
#     'zperiod': 1}
#
# Bxy
# G1
# G2
# G3
# J
# Nh+
# R
# SNh+
# Sh+_anom
# Sh+_src
# Z
# anomalous_Chi_h+
# anomalous_D_h+
# anomalous_nu_h+
# cvode_last_order
# cvode_last_step
# cvode_nfevals
# cvode_nliters
# cvode_nniters
# cvode_nonlin_fails
# cvode_npevals
# cvode_nsteps
# cvode_num_fails
# cvode_stab_lims
# ddt(Nh+)
# g11
# g12
# g13
# g22
# g23
# g33
# g_11
# g_12
# g_13
# g_22
# g_23
# g_33
# iteration
# pfh+_tot_xlow
# t_array
# ncalls
# ncalls_e
# ncalls_i
# wall_time
# wtime
# wtime_comms
# wtime_invert
# wtime_io
# wtime_per_rhs
# wtime_per_rhs_e
# wtime_per_rhs_i
# wtime_rhs
# /home/tirkas1/miniconda3/lib/python3.13/site-packages/xbout/load.py:341: UserWarning: No geometry type found, no physical coordinates will be added
#   warn("No geometry type found, no physical coordinates will be added")

# %%
dx = ds["dx"].isel(z=0).values

# Get rid of existing "x" coordinate, which is just the index values.
#ds = ds.drop("x")

# Create a new coordinate, which is length in units of rho_s
ds = ds.assign_coords(x=np.arange(ds.sizes["x"])*dx)

#Store just initial values as well.
ds_initial = ds.isel(t=0)

# %%
#For Dirichlet BCs.
dens = ds["Nh+"][:,2:-2,:]
dens_true = dens.copy()

mask = dsn["in_mask"][2:-2,:]
ghost_id = dsn["ghost_id"].values
bdy_pts = dsn["bndry_pts"].values
img_pts = dsn["image_pts"].values
is_plasma = dsn["is_plasma"].values
Rarr = dsn["R"].values[2:-2,:]
Zarr = dsn["Z"].values

spl = RectBivariateSpline(Rarr[:,0], Zarr[0,:], dens.values[100,:,:], kx=1, ky=1)

# %%
alpha0 = 2.404825557693792
xc, zc = 1.5, 0.0

x_unit = 0.00022846974366979959 #rho_s0
w_unit = 95788333.030660808    #Omega_ci
t_unit = 1/w_unit

nx = 256
nz = nx + 4
dx = np.float64(1.0) / np.float64(nx)
dz = np.float64(1.0) / np.float64(nz)

# Centers in x; faces/nodes in z if that's your convention
x = (np.arange(nx, dtype=np.float64) + 0.5) * dx     # centered x
z = (np.arange(nz, dtype=np.float64)) * dz           # unshifted z

xhalf  = np.float64(x[len(x)//2])
zhalf  = np.float64(z[len(z)//2])

xx, zz = np.meshgrid(x,z,indexing='ij',copy=False)
a      = np.float64(0.333333333333)
D      = np.float64(0.2)#/(x_unit*x_unit*w_unit)
t64 = np.asarray(ds["t_array"].values, dtype=np.float64) # 1D time
t_norm = t64*t_unit
#spatial = ((xx - xhalf)**2 + (zz-zhalf)**2)
spatial = j0(alpha0*np.hypot(xx - xhalf, zz - zhalf)/a)
#temp = 4.0*D*t_norm #t64/t64[-1]
a_norm = a/x_unit
temp = np.exp(-D * (alpha0 / a)**2 * (t_norm))

#dens_true[:,:,:] = np.asarray(spatial)[np.newaxis,:,:] + np.asarray(temp)[:,np.newaxis,np.newaxis]
dens_true[:,:,:] = np.asarray(spatial)[np.newaxis,:,:]*np.asarray(temp)[:,np.newaxis,np.newaxis]

bdy_pts_xz = spl.ev(bdy_pts[:,0], bdy_pts[:,1])
print(np.max(np.abs(bdy_pts_xz)))
# Out:
# 5.64406110792105e-05

# %%
img_pts_xz = spl.ev(img_pts[:,0], img_pts[:,1])

i = 0
for idx in range(nx+4):
    for idz in range(nz):
        gid = int(ghost_id[idx,idz])
        if gid >= 0:
            print(gid)
            if (not (is_plasma[gid,0] and is_plasma[gid,1] and is_plasma[gid,2] and is_plasma[gid,3])):
               print("Contains multiple ghost cell corners.")
            print(img_pts[gid])
            print(img_pts_xz[gid])
# Out:
# 0
# [ 1.17206155 -0.03003092]
# 0.013546478511968238
# 1
# [ 1.17141416 -0.02633541]
# 0.012420068698733421
# 2
# [ 1.17085087 -0.02261804]
# 0.011450115946856129
# 3
# [ 1.17037242 -0.01888196]
# 0.010631199144928584
# 4
# [ 1.16997945 -0.01513032]
# 0.009960986537496401
# 5
# [ 1.16967245 -0.0113663 ]
# 0.009438364095673384
# 6
# [ 1.16945182 -0.00759309]
# 0.009063010490662491
# 7
# [ 1.16931784 -0.00381391]
# 0.008834712605199175
# 8
# [1.16927083e+00 8.16431199e-17]
# 0.008752738536176476
# 9
# [1.16931784 0.00381391]
# 0.00883471260519936
# 10
# [1.16945182 0.00759309]
# 0.009063010490662576
# 11
# [1.16967245 0.0113663 ]
# 0.009438364095673326
# 12
# [1.16997945 0.01513032]
# 0.009960986537496705
# 13
# [1.17037242 0.01888196]
# 0.010631199144929427
# 14
# [1.17085087 0.02261804]
# 0.011450115946855353
# 15
# [1.17141416 0.02633541]
# 0.01242006869873234
# 16
# [1.17206155 0.03003092]
# 0.013546478511967946
# 17
# [ 1.17653928 -0.0599971 ]
# 0.014690268892502772
# 18
# [ 1.17519921 -0.05639195]
# 0.012362691447080597
# 19
# [ 1.17396154 -0.05284415]
# 0.01022050630667555
# 20
# [ 1.17280172 -0.04925276]
# 0.008218642628918145
# 21
# Contains multiple ghost cell corners.
# [ 1.17172132 -0.04562072]
# 0.006360526555153964
# 22
# Contains multiple ghost cell corners.
# [ 1.17072179 -0.04195097]
# 0.00466732904437391
# 23
# Contains multiple ghost cell corners.
# [ 1.16980448 -0.03824655]
# 0.003111609054216949
# 24
# Contains multiple ghost cell corners.
# [ 1.16897061 -0.0345105 ]
# 0.0016975328495928772
# 25
# Contains multiple ghost cell corners.
# [ 1.16822129 -0.03074592]
# 0.00042745804778893993
# 26
# Contains multiple ghost cell corners.
# [1.16822129 0.03074592]
# 0.0004274580477897671
# 27
# Contains multiple ghost cell corners.
# [1.16897061 0.0345105 ]
# 0.0016975328495926877
# 28
# Contains multiple ghost cell corners.
# [1.16980448 0.03824655]
# 0.003111609054216295
# 29
# Contains multiple ghost cell corners.
# [1.17072179 0.04195097]
# 0.004667329044374432
# 30
# Contains multiple ghost cell corners.
# [1.17172132 0.04562072]
# 0.00636052655515397
# 31
# [1.17280172 0.04925276]
# 0.008218642628918823
# 32
# [1.17396154 0.05284415]
# 0.01022050630667607
# 33
# [1.17519921 0.05639195]
# 0.012362691447080841
# 34
# [1.17653928 0.0599971 ]
# 0.014690268892503938
# 35
# [ 1.18079704 -0.07859247]
# 0.015514127752424348
# 36
# [ 1.17906991 -0.07526097]
# 0.012440422696161697
# 37
# [ 1.1774123  -0.07186912]
# 0.009534279113704743
# 38
# [ 1.17582639 -0.06841955]
# 0.006762955228757509
# 39
# Contains multiple ghost cell corners.
# [ 1.17431103 -0.0648845 ]
# 0.004177371580143781
# 40
# Contains multiple ghost cell corners.
# [ 1.17288609 -0.06134378]
# 0.00173217194790962
# 41
# Contains multiple ghost cell corners.
# [1.17288609 0.06134378]
# 0.0017321719479096458
# 42
# Contains multiple ghost cell corners.
# [1.17431103 0.0648845 ]
# 0.004177371580143877
# 43
# [1.17582639 0.06841955]
# 0.0067629552287585305
# 44
# [1.1774123  0.07186912]
# 0.00953427911370628
# 45
# [1.17906991 0.07526097]
# 0.012440422696162813
# 46
# [1.18079704 0.07859247]
# 0.015514127752425208
# 47
# Contains multiple ghost cell corners.
# [ 1.18304678 -0.09024897]
# 0.01274074936171204
# 48
# [ 1.1810758  -0.08703126]
# 0.009234484184195813
# 49
# Contains multiple ghost cell corners.
# [ 1.17916927 -0.0837446 ]
# 0.0058725687113595805
# 50
# Contains multiple ghost cell corners.
# [ 1.1773297  -0.08039145]
# 0.002677508735761416
# 51
# Contains multiple ghost cell corners.
# [1.1773297  0.08039145]
# 0.00267750873576114
# 52
# Contains multiple ghost cell corners.
# [1.17916927 0.0837446 ]
# 0.005872568711358239
# 53
# [1.1810758  0.08703126]
# 0.009234484184196002
# 54
# Contains multiple ghost cell corners.
# [1.18304678 0.09024897]
# 0.012740749361713473
# 55
# [ 1.18841355 -0.1047501 ]
# 0.01555623742948603
# 56
# [ 1.18615435 -0.10175372]
# 0.011453344089641961
# 57
# [ 1.18395065 -0.09867817]
# 0.007495510683081438
# 58
# Contains multiple ghost cell corners.
# [ 1.18180533 -0.09552557]
# 0.003712951047894557
# 59
# Contains multiple ghost cell corners.
# [ 1.17972118 -0.09229815]
# 5.889801138910152e-05
# 60
# Contains multiple ghost cell corners.
# [1.17972118 0.09229815]
# 5.889801138884877e-05
# 61
# Contains multiple ghost cell corners.
# [1.18180533 0.09552557]
# 0.0037129510478948686
# 62
# [1.18395065 0.09867817]
# 0.0074955106830828355
# 63
# [1.18615435 0.10175372]
# 0.011453344089643085
# 64
# [1.18841355 0.1047501 ]
# 0.01555623742948721
# 65
# [ 1.19256784 -0.11583219]
# 0.01622026944899102
# 66
# [ 1.1900976  -0.11301238]
# 0.011667344630532473
# 67
# [ 1.18767554 -0.11010616]
# 0.007259917906523636
# 68
# Contains multiple ghost cell corners.
# [ 1.18530482 -0.10711538]
# 0.003031286209426571
# 69
# Contains multiple ghost cell corners.
# [1.18530482 0.10711538]
# 0.0030312862094266824
# 70
# [1.18767554 0.11010616]
# 0.0072599179065241225
# 71
# [1.1900976  0.11301238]
# 0.011667344630533318
# 72
# [1.19256784 0.11583219]
# 0.016220269448991954
# 73
# Contains multiple ghost cell corners.
# [ 1.19484407 -0.12393372]
# 0.013382645098111863
# 74
# [ 1.19222111 -0.12122243]
# 0.008533635554162642
# 75
# Contains multiple ghost cell corners.
# [ 1.18964153 -0.11841975]
# 0.0038428522094385636
# 76
# Contains multiple ghost cell corners.
# [1.18964153 0.11841975]
# 0.0038428522094391634
# 77
# [1.19222111 0.12122243]
# 0.008533635554163475
# 78
# Contains multiple ghost cell corners.
# [1.19484407 0.12393372]
# 0.013382645098111948
# 79
# [ 1.20035137 -0.13443059]
# 0.016589988910211385
# 80
# [ 1.19754788 -0.13193795]
# 0.011293686142092835
# 81
# Contains multiple ghost cell corners.
# [ 1.19477899 -0.12934789]
# 0.006144119797286094
# 82
# Contains multiple ghost cell corners.
# [ 1.19204825 -0.12666175]
# 0.0011642243783990252
# 83
# Contains multiple ghost cell corners.
# [1.19204825 0.12666175]
# 0.0011642243783987639
# 84
# Contains multiple ghost cell corners.
# [1.19477899 0.12934789]
# 0.006144119797285248
# 85
# [1.19754788 0.13193795]
# 0.011293686142093941
# 86
# [1.20035137 0.13443059]
# 0.0165899889102119
# 87
# [ 1.2036067  -0.14216852]
# 0.015553481876320035
# 88
# [ 1.20067085 -0.1398135 ]
# 0.009956172034929121
# 89
# Contains multiple ghost cell corners.
# [ 1.19776381 -0.1373569 ]
# 0.004508973564778083
# 90
# Contains multiple ghost cell corners.
# [1.19776381 0.1373569 ]
# 0.004508973564778523
# 91
# [1.20067085 0.1398135 ]
# 0.009956172034930443
# 92
# [1.2036067  0.14216852]
# 0.015553481876319532
# 93
# [ 1.20726143 -0.14973577]
# 0.015265213411375354
# 94
# [ 1.20420231 -0.14752969]
# 0.009367959583196282
# 95
# Contains multiple ghost cell corners.
# [ 1.20116585 -0.14521828]
# 0.0036227920749636582
# 96
# Contains multiple ghost cell corners.
# [1.20116585 0.14521828]
# 0.003622792074964763
# 97
# [1.20420231 0.14752969]
# 0.009367959583198079
# 98
# [1.20726143 0.14973577]
# 0.015265213411374587
# 99
# [ 1.21130177 -0.15710317]
# 0.015722553619748898
# 100
# [ 1.20812939 -0.15505675]
# 0.009526377666068907
# 101
# Contains multiple ghost cell corners.
# [ 1.20497315 -0.15290161]
# 0.003479211910224411
# 102
# Contains multiple ghost cell corners.
# [1.20497315 0.15290161]
# 0.0034792119102244347
# 103
# [1.20812939 0.15505675]
# 0.009526377666070035
# 104
# [1.21130177 0.15710317]
# 0.01572255361974995
# 105
# [ 1.21571185 -0.16424267]
# 0.016928239969609443
# 106
# [ 1.21243707 -0.16236592]
# 0.01042992628039409
# 107
# Contains multiple ghost cell corners.
# [ 1.20916263 -0.16034826]
# 0.004091882431910564
# 108
# Contains multiple ghost cell corners.
# [1.20916263 0.16034826]
# 0.0040918824319131596
# 109
# [1.21243707 0.16236592]
# 0.01042992628039648
# 110
# [1.21571185 0.16424267]
# 0.016928239969611958
# 111
# Contains multiple ghost cell corners.
# [ 1.21710827 -0.16942958]
# 0.012087603599088677
# 112
# Contains multiple ghost cell corners.
# [ 1.21373877 -0.16757503]
# 0.005460289706000968
# 113
# Contains multiple ghost cell corners.
# [1.21373877 0.16757503]
# 0.005460289705999844
# 114
# Contains multiple ghost cell corners.
# [1.21710827 0.16942958]
# 0.012087603599088673
# 115
# [ 1.222071   -0.17613025]
# 0.014487227360467205
# 116
# Contains multiple ghost cell corners.
# [ 1.21866749 -0.17453446]
# 0.007577835366665705
# 117
# Contains multiple ghost cell corners.
# [ 1.21526083 -0.17282345]
# 0.0008197870806776055
# 118
# Contains multiple ghost cell corners.
# [1.21526083 0.17282345]
# 0.0008197870806779197
# 119
# Contains multiple ghost cell corners.
# [1.21866749 0.17453446]
# 0.00757783536666673
# 120
# [1.222071   0.17613025]
# 0.014487227360470286
# 121
# [ 1.22740101 -0.18260402]
# 0.017656126765943334
# 122
# [ 1.22392805 -0.1812013 ]
# 0.010452165169660986
# 123
# Contains multiple ghost cell corners.
# [ 1.22044432 -0.17968169]
# 0.0033782208726052198
# 124
# Contains multiple ghost cell corners.
# [1.22044432 0.17968169]
# 0.003378220872604942
# 125
# [1.22392805 0.1812013 ]
# 0.010452165169661194
# 126
# [1.22740101 0.18260402]
# 0.017656126765942318
# 127
# [ 1.22949787 -0.18755181]
# 0.014076656953333818
# 128
# Contains multiple ghost cell corners.
# [ 1.22595055 -0.186231  ]
# 0.006684358743914242
# 129
# Contains multiple ghost cell corners.
# [1.22595055 0.186231  ]
# 0.006684358743914855
# 130
# [1.22949787 0.18755181]
# 0.014076656953332878
# 131
# Contains multiple ghost cell corners.
# [ 1.23175588 -0.19244838]
# 0.010770552218033167
# 132
# Contains multiple ghost cell corners.
# [ 1.22813686 -0.19121329]
# 0.0032149771535823803
# 133
# Contains multiple ghost cell corners.
# [1.22813686 0.19121329]
# 0.0032149771535821747
# 134
# Contains multiple ghost cell corners.
# [1.23175588 0.19244838]
# 0.010770552218032166
# 135
# [ 1.23783502 -0.19831258]
# 0.01556854319695545
# 136
# Contains multiple ghost cell corners.
# [ 1.23414105 -0.19724135]
# 0.007715963536489016
# 137
# Contains multiple ghost cell corners.
# [ 1.23050644 -0.19612625]
# 7.84682762802186e-05
# 138
# Contains multiple ghost cell corners.
# [1.23050644 0.19612625]
# 7.846827627846828e-05
# 139
# Contains multiple ghost cell corners.
# [1.23414105 0.19724135]
# 0.007715963536487995
# 140
# [1.23783502 0.19831258]
# 0.015568543196957055
# 141
# [ 1.24041907 -0.20291551]
# 0.012996335595792725
# 142
# Contains multiple ghost cell corners.
# [ 1.23675201 -0.20201447]
# 0.005042096092923731
# 143
# Contains multiple ghost cell corners.
# [1.23675201 0.20201447]
# 0.005042096092923036
# 144
# [1.24041907 0.20291551]
# 0.012996335595790939
# 145
# [ 1.24324079 -0.20751895]
# 0.010779022427671281
# 146
# Contains multiple ghost cell corners.
# [ 1.2395165  -0.20671606]
# 0.0026442520336779868
# 147
# Contains multiple ghost cell corners.
# [1.2395165  0.20671606]
# 0.002644252033678005
# 148
# [1.24324079 0.20751895]
# 0.010779022427671116
# 149
# [ 1.24994376 -0.21262274]
# 0.01723715956078468
# 150
# [ 1.24620986 -0.21204203]
# 0.00881257719267225
# 151
# Contains multiple ghost cell corners.
# [ 1.24243176 -0.2113405 ]
# 0.0005270079491832035
# 152
# Contains multiple ghost cell corners.
# [1.24243176 0.2113405 ]
# 0.0005270079491822396
# 153
# [1.24620986 0.21204203]
# 0.008812577192670633
# 154
# [1.24994376 0.21262274]
# 0.01723715956078808
# 155
# [ 1.25310331 -0.21695502]
# 0.01572680178406471
# 156
# Contains multiple ghost cell corners.
# [ 1.24929215 -0.2164374 ]
# 0.007127055703368882
# 157
# Contains multiple ghost cell corners.
# [1.24929215 0.2164374 ]
# 0.00712705570336855
# 158
# [1.25310331 0.21695502]
# 0.015726801784067705
# 159
# [ 1.25633385 -0.22111122]
# 0.014507129269805352
# 160
# Contains multiple ghost cell corners.
# [ 1.25257742 -0.22076953]
# 0.005813359594661883
# 161
# Contains multiple ghost cell corners.
# [1.25257742 0.22076953]
# 0.005813359594659799
# 162
# [1.25633385 0.22111122]
# 0.014507129269806648
# 163
# [ 1.25979181 -0.22523416]
# 0.013648860549147374
# 164
# Contains multiple ghost cell corners.
# [ 1.25599871 -0.22500307]
# 0.004770121750832579
# 165
# Contains multiple ghost cell corners.
# [1.25599871 0.22500307]
# 0.004770121750831282
# 166
# [1.25979181 0.22523416]
# 0.01364886054914719
# 167
# [ 1.26337802 -0.22925108]
# 0.013053912234090446
# 168
# Contains multiple ghost cell corners.
# [ 1.25953447 -0.22910952]
# 0.004009815018233004
# 169
# Contains multiple ghost cell corners.
# [1.25953447 0.22910952]
# 0.004009815018232992
# 170
# [1.26337802 0.22925108]
# 0.013053912234090278
# 171
# [ 1.26702516 -0.2330896 ]
# 0.012732603393983676
# 172
# Contains multiple ghost cell corners.
# [ 1.26324259 -0.23311013]
# 0.003597932953618636
# 173
# Contains multiple ghost cell corners.
# [1.26324259 0.23311013]
# 0.0035979329536176444
# 174
# [1.26702516 0.2330896 ]
# 0.012732603393983313
# 175
# [ 1.27087788 -0.23685778]
# 0.01278413370584778
# 176
# Contains multiple ghost cell corners.
# [ 1.2670731  -0.23699556]
# 0.0034603972647358244
# 177
# Contains multiple ghost cell corners.
# [1.2670731  0.23699556]
# 0.0034603972647361905
# 178
# [1.27087788 0.23685778]
# 0.012784133705847332
# 179
# [ 1.27484425 -0.24050442]
# 0.013097505591917812
# 180
# Contains multiple ghost cell corners.
# [ 1.27100534 -0.24074026]
# 0.0036075555666263597
# 181
# Contains multiple ghost cell corners.
# [1.27100534 0.24074026]
# 0.0036075555666263753
# 182
# [1.27484425 0.24050442]
# 0.013097505591917045
# 183
# [ 1.27885653 -0.24396742]
# 0.013676326919804522
# 184
# Contains multiple ghost cell corners.
# [ 1.27508774 -0.24435538]
# 0.00410023349991234
# 185
# Contains multiple ghost cell corners.
# [1.27508774 0.24435538]
# 0.004100233499912668
# 186
# [1.27885653 0.24396742]
# 0.013676326919804093
# 187
# [ 1.28304205 -0.24732162]
# 0.014635167788908249
# 188
# Contains multiple ghost cell corners.
# [ 1.27927684 -0.24784069]
# 0.0048677094738363205
# 189
# Contains multiple ghost cell corners.
# [1.27927684 0.24784069]
# 0.004867709473835654
# 190
# [1.28304205 0.24732162]
# 0.014635167788908013
# 191
# [ 1.28733497 -0.25055   ]
# 0.01585787092723702
# 192
# Contains multiple ghost cell corners.
# [ 1.28353765 -0.25116099]
# 0.005916676942579482
# 193
# Contains multiple ghost cell corners.
# [1.28353765 0.25116099]
# 0.005916676942578948
# 194
# [1.28733497 0.25055   ]
# 0.0158578709272367
# 195
# [ 1.29171998 -0.25363987]
# 0.01734943265146137
# 196
# Contains multiple ghost cell corners.
# [ 1.2879388  -0.25434387]
# 0.007319038848953848
# 197
# Contains multiple ghost cell corners.
# [1.2879388  0.25434387]
# 0.007319038848953828
# 198
# [1.29171998 0.25363987]
# 0.017349432651461105
# 199
# [ 1.29242914 -0.25738448]
# 0.009001306866103835
# 200
# [1.29242914 0.25738448]
# 0.009001306866105965
# 201
# [ 1.29694131 -0.26022934]
# 0.010965614480995046
# 202
# Contains multiple ghost cell corners.
# [ 1.29326128 -0.26116833]
# 0.0007918000529829521
# 203
# Contains multiple ghost cell corners.
# [1.29326128 0.26116833]
# 0.0007918000529820328
# 204
# [1.29694131 0.26022934]
# 0.010965614480996633
# 205
# [ 1.30159969 -0.26294129]
# 0.013286854954317712
# 206
# Contains multiple ghost cell corners.
# [ 1.29793688 -0.26400659]
# 0.0029200820700543756
# 207
# Contains multiple ghost cell corners.
# [1.29793688 0.26400659]
# 0.0029200820700543825
# 208
# [1.30159969 0.26294129]
# 0.013286854954318628
# 209
# [ 1.30632825 -0.26550095]
# 0.01587050723528747
# 210
# Contains multiple ghost cell corners.
# [ 1.30266168 -0.26666251]
# 0.005340636752236167
# 211
# Contains multiple ghost cell corners.
# [1.30266168 0.26666251]
# 0.005340636752236583
# 212
# [1.30632825 0.26550095]
# 0.015870507235288184
# 213
# [ 1.30748436 -0.26915701]
# 0.00810726665055862
# 214
# [1.30748436 0.26915701]
# 0.00810726665055806
# 215
# Contains multiple ghost cell corners.
# [ 1.31236796 -0.27149365]
# 0.011161070673328085
# 216
# Contains multiple ghost cell corners.
# [ 1.30876281 -0.27283373]
# 0.0004970459886079194
# 217
# Contains multiple ghost cell corners.
# [1.30876281 0.27283373]
# 0.0004970459886070033
# 218
# Contains multiple ghost cell corners.
# [1.31236796 0.27149365]
# 0.011161070673327505
# 219
# [ 1.31722031 -0.27361008]
# 0.014469350089196233
# 220
# Contains multiple ghost cell corners.
# [ 1.31373544 -0.27509845]
# 0.0037015991861070133
# 221
# Contains multiple ghost cell corners.
# [1.31373544 0.27509845]
# 0.003701599186105878
# 222
# [1.31722031 0.27361008]
# 0.014469350089194815
# 223
# Contains multiple ghost cell corners.
# [ 1.31875934 -0.27720037]
# 0.007184254387768603
# 224
# Contains multiple ghost cell corners.
# [1.31875934 0.27720037]
# 0.007184254387768782
# 225
# Contains multiple ghost cell corners.
# [ 1.32376696 -0.27908542]
# 0.010996697209826007
# 226
# Contains multiple ghost cell corners.
# [ 1.32033167 -0.28073936]
# 5.96439075875119e-05
# 227
# Contains multiple ghost cell corners.
# [1.32033167 0.28073936]
# 5.9643907586650485e-05
# 228
# Contains multiple ghost cell corners.
# [1.32376696 0.27908542]
# 0.010996697209827256
# 229
# [ 1.32886501 -0.28081649]
# 0.015118688558833856
# 230
# Contains multiple ghost cell corners.
# [ 1.3254803  -0.28259587]
# 0.003994376920051066
# 231
# Contains multiple ghost cell corners.
# [1.3254803  0.28259587]
# 0.003994376920051858
# 232
# [1.32886501 0.28081649]
# 0.015118688558832081
# 233
# [ 1.33062348 -0.28423447]
# 0.008263643774408408
# 234
# [1.33062348 0.28423447]
# 0.008263643774412435
# 235
# Contains multiple ghost cell corners.
# [ 1.33582167 -0.28571137]
# 0.012854087743958
# 236
# Contains multiple ghost cell corners.
# [ 1.3324987  -0.28764805]
# 0.0015733096690033388
# 237
# Contains multiple ghost cell corners.
# [1.3324987  0.28764805]
# 0.0015733096690020822
# 238
# Contains multiple ghost cell corners.
# [1.33582167 0.28571137]
# 0.012854087743956575
# 239
# [ 1.3410393  -0.28701765]
# 0.017691542489752094
# 240
# Contains multiple ghost cell corners.
# [ 1.33776486 -0.2890353 ]
# 0.006293216015773151
# 241
# Contains multiple ghost cell corners.
# [1.33776486 0.2890353 ]
# 0.006293216015774289
# 242
# [1.3410393  0.28701765]
# 0.017691542489753024
# 243
# [ 1.3430461 -0.2902501]
# 0.011321601100558958
# 244
# [1.3430461 0.2902501]
# 0.011321601100560671
# 245
# [ 1.34833605 -0.29129201]
# 0.01662237803306814
# 246
# Contains multiple ghost cell corners.
# [ 1.34516455 -0.2934679 ]
# 0.005090635401354632
# 247
# Contains multiple ghost cell corners.
# [1.34516455 0.2934679 ]
# 0.005090635401355531
# 248
# [1.34833605 0.29129201]
# 0.016622378033070647
# 249
# [ 1.35051117 -0.29441386]
# 0.010565077336322958
# 250
# [1.35051117 0.29441386]
# 0.010565077336325793
# 251
# [ 1.35585558 -0.29518535]
# 0.01631993416835793
# 252
# Contains multiple ghost cell corners.
# [ 1.35279467 -0.29751424]
# 0.004653636972955301
# 253
# Contains multiple ghost cell corners.
# [1.35279467 0.29751424]
# 0.004653636972956824
# 254
# [1.35585558 0.29518535]
# 0.016319934168360747
# 255
# [ 1.3581885  -0.29818584]
# 0.010572219764214772
# 256
# [1.3581885  0.29818584]
# 0.010572219764217758
# 257
# [ 1.363461   -0.29862503]
# 0.016804973520353803
# 258
# Contains multiple ghost cell corners.
# [ 1.3606261  -0.30115837]
# 0.004972893636765198
# 259
# Contains multiple ghost cell corners.
# [1.3606261  0.30115837]
# 0.00497289363676781
# 260
# [1.363461   0.29862503]
# 0.016804973520354642
# 261
# [ 1.36604856 -0.30155135]
# 0.011341540813977253
# 262
# [1.36604856 0.30155135]
# 0.011341540813978609
# 263
# Contains multiple ghost cell corners.
# [ 1.36862865 -0.30438653]
# 0.006051530188951694
# 264
# Contains multiple ghost cell corners.
# [1.36862865 0.30438653]
# 0.006051530188953011
# 265
# Contains multiple ghost cell corners.
# [ 1.37397534 -0.30445913]
# 0.01288314647122872
# 266
# Contains multiple ghost cell corners.
# [ 1.37130798 -0.30718395]
# 0.0009274142358327045
# 267
# Contains multiple ghost cell corners.
# [1.37130798 0.30718395]
# 0.0009274142358341432
# 268
# Contains multiple ghost cell corners.
# [1.37397534 0.30445913]
# 0.012883146471231118
# 269
# [ 1.37677117 -0.30718716]
# 0.007891775660099465
# 270
# [1.37677117 0.30718716]
# 0.00789177566010288
# 271
# [ 1.38209544 -0.30696343]
# 0.015207424927668568
# 272
# Contains multiple ghost cell corners.
# [ 1.37957612 -0.30983311]
# 0.0030771873517347987
# 273
# Contains multiple ghost cell corners.
# [1.37957612 0.30983311]
# 0.0030771873517358482
# 274
# [1.38209544 0.30696343]
# 0.015207424927672023
# 275
# [ 1.38495035 -0.30952337]
# 0.010499167153728537
# 276
# [1.38495035 0.30952337]
# 0.010499167153731725
# 277
# Contains multiple ghost cell corners.
# [ 1.38793928 -0.31203833]
# 0.005976249409517076
# 278
# Contains multiple ghost cell corners.
# [1.38793928 0.31203833]
# 0.005976249409518786
# 279
# [ 1.39325575 -0.31142844]
# 0.013885767811061326
# 280
# Contains multiple ghost cell corners.
# [ 1.39094455 -0.31447395]
# 0.00162257005170318
# 281
# Contains multiple ghost cell corners.
# [1.39094455 0.31447395]
# 0.0016225700517037327
# 282
# [1.39325575 0.31142844]
# 0.013885767811063748
# 283
# [ 1.39634759 -0.31378802]
# 0.009651191461681065
# 284
# [1.39634759 0.31378802]
# 0.009651191461683124
# 285
# Contains multiple ghost cell corners.
# [ 1.39946341 -0.3160601 ]
# 0.005593041582745473
# 286
# Contains multiple ghost cell corners.
# [1.39946341 0.3160601 ]
# 0.005593041582746411
# 287
# [ 1.40472258 -0.31505817]
# 0.01410573108919687
# 288
# Contains multiple ghost cell corners.
# [ 1.40264249 -0.31826727]
# 0.0016962860302166438
# 289
# Contains multiple ghost cell corners.
# [1.40264249 0.31826727]
# 0.0016962860302167301
# 290
# [1.40472258 0.31505817]
# 0.014105731089199727
# 291
# [ 1.4079969  -0.31718834]
# 0.010335142226090251
# 292
# [1.4079969  0.31718834]
# 0.01033514222609303
# 293
# [ 1.41124973 -0.31921787]
# 0.006725656802921001
# 294
# [1.41124973 0.31921787]
# 0.006725656802924437
# 295
# [ 1.41640112 -0.31782404]
# 0.015860291560940244
# 296
# Contains multiple ghost cell corners.
# [ 1.41457449 -0.32118166]
# 0.0032979632160987714
# 297
# Contains multiple ghost cell corners.
# [1.41457449 0.32118166]
# 0.0032979632160997116
# 298
# [1.41640112 0.31782404]
# 0.015860291560941757
# 299
# [ 1.41982326 -0.31970757]
# 0.012537993235568696
# 300
# [1.41982326 0.31970757]
# 0.012537993235570208
# 301
# [ 1.42320112 -0.32148761]
# 0.009407911670557434
# 302
# [1.42320112 0.32148761]
# 0.009407911670559727
# 303
# Contains multiple ghost cell corners.
# [ 1.42664216 -0.32319639]
# 0.006415078932736771
# 304
# Contains multiple ghost cell corners.
# [1.42664216 0.32319639]
# 0.006415078932737743
# 305
# Contains multiple ghost cell corners.
# [ 1.43014369 -0.32483164]
# 0.0035993686641994298
# 306
# Contains multiple ghost cell corners.
# [1.43014369 0.32483164]
# 0.0035993686642001284
# 307
# [ 1.43521831 -0.3228561 ]
# 0.013613132563638828
# 308
# Contains multiple ghost cell corners.
# [ 1.43370295 -0.32639115]
# 0.0009141827601734791
# 309
# Contains multiple ghost cell corners.
# [1.43370295 0.32639115]
# 0.000914182760174282
# 310
# [1.43521831 0.3228561 ]
# 0.01361313256364139
# 311
# [ 1.43874527 -0.32430169]
# 0.011088580006739053
# 312
# [1.43874527 0.32430169]
# 0.011088580006742297
# 313
# [ 1.44232338 -0.32566965]
# 0.008713514835088058
# 314
# [1.44232338 0.32566965]
# 0.008713514835091562
# 315
# Contains multiple ghost cell corners.
# [ 1.44594972 -0.32695814]
# 0.006482789526127423
# 316
# Contains multiple ghost cell corners.
# [1.44594972 0.32695814]
# 0.006482789526128638
# 317
# Contains multiple ghost cell corners.
# [ 1.44962133 -0.32816543]
# 0.004429613016912159
# 318
# Contains multiple ghost cell corners.
# [1.44962133 0.32816543]
# 0.004429613016913096
# 319
# Contains multiple ghost cell corners.
# [ 1.45333517 -0.32928991]
# 0.0025157113478267105
# 320
# Contains multiple ghost cell corners.
# [1.45333517 0.32928991]
# 0.0025157113478274386
# 321
# [ 1.45806841 -0.32661093]
# 0.01361122808427639
# 322
# Contains multiple ghost cell corners.
# [ 1.45708815 -0.33033007]
# 0.0007459720468050828
# 323
# Contains multiple ghost cell corners.
# [1.45708815 0.33033007]
# 0.000745972046804417
# 324
# [1.45806841 0.32661093]
# 0.01361122808427861
# 325
# [ 1.46176584 -0.32754245]
# 0.01199193791556804
# 326
# [1.46176584 0.32754245]
# 0.011991937915570766
# 327
# [ 1.46549557 -0.32838926]
# 0.010535049232262787
# 328
# [1.46549557 0.32838926]
# 0.010535049232266475
# 329
# [ 1.46925443 -0.32915023]
# 0.009231860831136073
# 330
# [1.46925443 0.32915023]
# 0.009231860831141183
# 331
# [ 1.47303923 -0.32982434]
# 0.008080370379040427
# 332
# [1.47303923 0.32982434]
# 0.008080370379046058
# 333
# [ 1.47684673 -0.33041069]
# 0.007079674693563473
# 334
# [1.47684673 0.33041069]
# 0.007079674693567796
# 335
# Contains multiple ghost cell corners.
# [ 1.48067366 -0.33090852]
# 0.006234166388313454
# 336
# Contains multiple ghost cell corners.
# [1.48067366 0.33090852]
# 0.006234166388314517
# 337
# Contains multiple ghost cell corners.
# [ 1.48451675 -0.33131717]
# 0.005548320008867352
# 338
# Contains multiple ghost cell corners.
# [1.48451675 0.33131717]
# 0.005548320008867854
# 339
# Contains multiple ghost cell corners.
# [ 1.48837268 -0.33163612]
# 0.005012263083457361
# 340
# Contains multiple ghost cell corners.
# [1.48837268 0.33163612]
# 0.0050122630834579796
# 341
# Contains multiple ghost cell corners.
# [ 1.49223813 -0.33186497]
# 0.004627464177736485
# 342
# Contains multiple ghost cell corners.
# [1.49223813 0.33186497]
# 0.004627464177736773
# 343
# Contains multiple ghost cell corners.
# [ 1.49610978 -0.33200344]
# 0.0043945002191648624
# 344
# Contains multiple ghost cell corners.
# [1.49610978 0.33200344]
# 0.004394500219165094
# 345
# Contains multiple ghost cell corners.
# [ 1.5        -0.33205128]
# 0.004313390081361435
# 346
# Contains multiple ghost cell corners.
# [1.5        0.33205128]
# 0.004313390081361335
# 347
# Contains multiple ghost cell corners.
# [ 1.50389022 -0.33200344]
# 0.004394500219164764
# 348
# Contains multiple ghost cell corners.
# [1.50389022 0.33200344]
# 0.004394500219164963
# 349
# Contains multiple ghost cell corners.
# [ 1.50776187 -0.33186497]
# 0.004627464177736239
# 350
# Contains multiple ghost cell corners.
# [1.50776187 0.33186497]
# 0.004627464177736475
# 351
# Contains multiple ghost cell corners.
# [ 1.51162732 -0.33163612]
# 0.005012263083457355
# 352
# Contains multiple ghost cell corners.
# [1.51162732 0.33163612]
# 0.005012263083458139
# 353
# Contains multiple ghost cell corners.
# [ 1.51548325 -0.33131717]
# 0.005548320008867452
# 354
# Contains multiple ghost cell corners.
# [1.51548325 0.33131717]
# 0.0055483200088679505
# 355
# Contains multiple ghost cell corners.
# [ 1.51932634 -0.33090852]
# 0.006234166388314239
# 356
# Contains multiple ghost cell corners.
# [1.51932634 0.33090852]
# 0.0062341663883142655
# 357
# [ 1.52315327 -0.33041069]
# 0.007079674693563844
# 358
# [1.52315327 0.33041069]
# 0.007079674693567706
# 359
# [ 1.52696077 -0.32982434]
# 0.008080370379040837
# 360
# [1.52696077 0.32982434]
# 0.008080370379046135
# 361
# [ 1.53074557 -0.32915023]
# 0.009231860831136099
# 362
# [1.53074557 0.32915023]
# 0.009231860831141076
# 363
# [ 1.53450443 -0.32838926]
# 0.010535049232261848
# 364
# [1.53450443 0.32838926]
# 0.010535049232266164
# 365
# [ 1.53823416 -0.32754245]
# 0.011991937915566743
# 366
# [1.53823416 0.32754245]
# 0.011991937915570709
# 367
# [ 1.54193159 -0.32661093]
# 0.013611228084277104
# 368
# Contains multiple ghost cell corners.
# [ 1.54291185 -0.33033007]
# 0.0007459720468050491
# 369
# Contains multiple ghost cell corners.
# [1.54291185 0.33033007]
# 0.0007459720468055625
# 370
# [1.54193159 0.32661093]
# 0.013611228084278552
# 371
# Contains multiple ghost cell corners.
# [ 1.54666483 -0.32928991]
# 0.00251571134782706
# 372
# Contains multiple ghost cell corners.
# [1.54666483 0.32928991]
# 0.0025157113478272985
# 373
# Contains multiple ghost cell corners.
# [ 1.55037867 -0.32816543]
# 0.004429613016912008
# 374
# Contains multiple ghost cell corners.
# [1.55037867 0.32816543]
# 0.0044296130169127375
# 375
# Contains multiple ghost cell corners.
# [ 1.55405028 -0.32695814]
# 0.006482789526127634
# 376
# Contains multiple ghost cell corners.
# [1.55405028 0.32695814]
# 0.006482789526129229
# 377
# [ 1.55767662 -0.32566965]
# 0.008713514835088008
# 378
# [1.55767662 0.32566965]
# 0.008713514835092084
# 379
# [ 1.56125473 -0.32430169]
# 0.011088580006739027
# 380
# [1.56125473 0.32430169]
# 0.011088580006742626
# 381
# [ 1.56478169 -0.3228561 ]
# 0.01361313256363928
# 382
# Contains multiple ghost cell corners.
# [ 1.56629705 -0.32639115]
# 0.0009141827601736143
# 383
# Contains multiple ghost cell corners.
# [1.56629705 0.32639115]
# 0.0009141827601740908
# 384
# [1.56478169 0.3228561 ]
# 0.013613132563642244
# 385
# Contains multiple ghost cell corners.
# [ 1.56985631 -0.32483164]
# 0.003599368664199398
# 386
# Contains multiple ghost cell corners.
# [1.56985631 0.32483164]
# 0.0035993686641993196
# 387
# Contains multiple ghost cell corners.
# [ 1.57335784 -0.32319639]
# 0.00641507893273583
# 388
# Contains multiple ghost cell corners.
# [1.57335784 0.32319639]
# 0.006415078932737048
# 389
# [ 1.57679888 -0.32148761]
# 0.009407911670555843
# 390
# [1.57679888 0.32148761]
# 0.00940791167055965
# 391
# [ 1.58017674 -0.31970757]
# 0.012537993235566567
# 392
# [1.58017674 0.31970757]
# 0.012537993235569584
# 393
# [ 1.58359888 -0.31782404]
# 0.015860291560939474
# 394
# Contains multiple ghost cell corners.
# [ 1.58542551 -0.32118166]
# 0.003297963216099184
# 395
# Contains multiple ghost cell corners.
# [1.58542551 0.32118166]
# 0.0032979632161005317
# 396
# [1.58359888 0.31782404]
# 0.015860291560941542
# 397
# [ 1.58875027 -0.31921787]
# 0.006725656802921175
# 398
# [1.58875027 0.31921787]
# 0.006725656802925511
# 399
# [ 1.5920031  -0.31718834]
# 0.010335142226090128
# 400
# [1.5920031  0.31718834]
# 0.010335142226093566
# 401
# [ 1.59527742 -0.31505817]
# 0.014105731089197847
# 402
# Contains multiple ghost cell corners.
# [ 1.59735751 -0.31826727]
# 0.0016962860302178117
# 403
# Contains multiple ghost cell corners.
# [1.59735751 0.31826727]
# 0.0016962860302175517
# 404
# [1.59527742 0.31505817]
# 0.014105731089199712
# 405
# Contains multiple ghost cell corners.
# [ 1.60053659 -0.3160601 ]
# 0.005593041582745962
# 406
# Contains multiple ghost cell corners.
# [1.60053659 0.3160601 ]
# 0.005593041582746148
# 407
# [ 1.60365241 -0.31378802]
# 0.009651191461681507
# 408
# [1.60365241 0.31378802]
# 0.009651191461682643
# 409
# [ 1.60674425 -0.31142844]
# 0.013885767811062663
# 410
# Contains multiple ghost cell corners.
# [ 1.60905545 -0.31447395]
# 0.001622570051703058
# 411
# Contains multiple ghost cell corners.
# [1.60905545 0.31447395]
# 0.001622570051702256
# 412
# [1.60674425 0.31142844]
# 0.013885767811061815
# 413
# Contains multiple ghost cell corners.
# [ 1.61206072 -0.31203833]
# 0.0059762494095185375
# 414
# Contains multiple ghost cell corners.
# [1.61206072 0.31203833]
# 0.005976249409518026
# 415
# [ 1.61504965 -0.30952337]
# 0.010499167153729715
# 416
# [1.61504965 0.30952337]
# 0.010499167153730917
# 417
# [ 1.61790456 -0.30696343]
# 0.015207424927671078
# 418
# Contains multiple ghost cell corners.
# [ 1.62042388 -0.30983311]
# 0.003077187351735681
# 419
# Contains multiple ghost cell corners.
# [1.62042388 0.30983311]
# 0.0030771873517348785
# 420
# [1.61790456 0.30696343]
# 0.015207424927672037
# 421
# [ 1.62322883 -0.30718716]
# 0.007891775660100056
# 422
# [1.62322883 0.30718716]
# 0.007891775660102584
# 423
# Contains multiple ghost cell corners.
# [ 1.62602466 -0.30445913]
# 0.012883146471229373
# 424
# Contains multiple ghost cell corners.
# [ 1.62869202 -0.30718395]
# 0.0009274142358330188
# 425
# Contains multiple ghost cell corners.
# [1.62869202 0.30718395]
# 0.0009274142358343186
# 426
# Contains multiple ghost cell corners.
# [1.62602466 0.30445913]
# 0.012883146471231803
# 427
# Contains multiple ghost cell corners.
# [ 1.63137135 -0.30438653]
# 0.0060515301889514685
# 428
# Contains multiple ghost cell corners.
# [1.63137135 0.30438653]
# 0.006051530188952522
# 429
# [ 1.63395144 -0.30155135]
# 0.011341540813976807
# 430
# [1.63395144 0.30155135]
# 0.011341540813979712
# 431
# [ 1.636539   -0.29862503]
# 0.01680497352035242
# 432
# Contains multiple ghost cell corners.
# [ 1.6393739  -0.30115837]
# 0.004972893636765995
# 433
# Contains multiple ghost cell corners.
# [1.6393739  0.30115837]
# 0.004972893636768063
# 434
# [1.636539   0.29862503]
# 0.016804973520356592
# 435
# [ 1.6418115  -0.29818584]
# 0.010572219764215561
# 436
# [1.6418115  0.29818584]
# 0.010572219764217489
# 437
# [ 1.64414442 -0.29518535]
# 0.016319934168356896
# 438
# Contains multiple ghost cell corners.
# [ 1.64720533 -0.29751424]
# 0.004653636972955318
# 439
# Contains multiple ghost cell corners.
# [1.64720533 0.29751424]
# 0.004653636972956459
# 440
# [1.64414442 0.29518535]
# 0.01631993416836168
# 441
# [ 1.64948883 -0.29441386]
# 0.010565077336324237
# 442
# [1.64948883 0.29441386]
# 0.010565077336324197
# 443
# [ 1.65166395 -0.29129201]
# 0.01662237803307063
# 444
# Contains multiple ghost cell corners.
# [ 1.65483545 -0.2934679 ]
# 0.00509063540135389
# 445
# Contains multiple ghost cell corners.
# [1.65483545 0.2934679 ]
# 0.005090635401355901
# 446
# [1.65166395 0.29129201]
# 0.01662237803307032
# 447
# [ 1.6569539 -0.2902501]
# 0.011321601100558232
# 448
# [1.6569539 0.2902501]
# 0.011321601100561178
# 449
# [ 1.6589607  -0.28701765]
# 0.01769154248975202
# 450
# Contains multiple ghost cell corners.
# [ 1.66223514 -0.2890353 ]
# 0.006293216015773104
# 451
# Contains multiple ghost cell corners.
# [1.66223514 0.2890353 ]
# 0.006293216015777412
# 452
# [1.6589607  0.28701765]
# 0.017691542489753437
# 453
# Contains multiple ghost cell corners.
# [ 1.66417833 -0.28571137]
# 0.012854087743955335
# 454
# Contains multiple ghost cell corners.
# [ 1.6675013  -0.28764805]
# 0.0015733096690024382
# 455
# Contains multiple ghost cell corners.
# [1.6675013  0.28764805]
# 0.0015733096690032618
# 456
# Contains multiple ghost cell corners.
# [1.66417833 0.28571137]
# 0.01285408774395821
# 457
# [ 1.66937652 -0.28423447]
# 0.008263643774409503
# 458
# [1.66937652 0.28423447]
# 0.008263643774410977
# 459
# [ 1.67113499 -0.28081649]
# 0.015118688558832555
# 460
# Contains multiple ghost cell corners.
# [ 1.6745197  -0.28259587]
# 0.0039943769200508706
# 461
# Contains multiple ghost cell corners.
# [1.6745197  0.28259587]
# 0.003994376920050153
# 462
# [1.67113499 0.28081649]
# 0.015118688558833396
# 463
# Contains multiple ghost cell corners.
# [ 1.67623304 -0.27908542]
# 0.010996697209826734
# 464
# Contains multiple ghost cell corners.
# [ 1.67966833 -0.28073936]
# 5.964390758665918e-05
# 465
# Contains multiple ghost cell corners.
# [1.67966833 0.28073936]
# 5.964390758665506e-05
# 466
# Contains multiple ghost cell corners.
# [1.67623304 0.27908542]
# 0.0109966972098268
# 467
# Contains multiple ghost cell corners.
# [ 1.68124066 -0.27720037]
# 0.0071842543877683445
# 468
# Contains multiple ghost cell corners.
# [1.68124066 0.27720037]
# 0.007184254387766055
# 469
# [ 1.68277969 -0.27361008]
# 0.014469350089198368
# 470
# Contains multiple ghost cell corners.
# [ 1.68626456 -0.27509845]
# 0.0037015991861060636
# 471
# Contains multiple ghost cell corners.
# [1.68626456 0.27509845]
# 0.0037015991861045804
# 472
# [1.68277969 0.27361008]
# 0.014469350089199544
# 473
# Contains multiple ghost cell corners.
# [ 1.68763204 -0.27149365]
# 0.011161070673326574
# 474
# Contains multiple ghost cell corners.
# [ 1.69123719 -0.27283373]
# 0.0004970459886090444
# 475
# Contains multiple ghost cell corners.
# [1.69123719 0.27283373]
# 0.0004970459886080962
# 476
# Contains multiple ghost cell corners.
# [1.68763204 0.27149365]
# 0.011161070673324773
# 477
# [ 1.69251564 -0.26915701]
# 0.008107266650558003
# 478
# [1.69251564 0.26915701]
# 0.008107266650561747
# 479
# [ 1.69367175 -0.26550095]
# 0.015870507235288274
# 480
# Contains multiple ghost cell corners.
# [ 1.69733832 -0.26666251]
# 0.005340636752234755
# 481
# Contains multiple ghost cell corners.
# [1.69733832 0.26666251]
# 0.005340636752235981
# 482
# [1.69367175 0.26550095]
# 0.015870507235286806
# 483
# [ 1.69840031 -0.26294129]
# 0.013286854954316602
# 484
# Contains multiple ghost cell corners.
# [ 1.70206312 -0.26400659]
# 0.0029200820700544783
# 485
# Contains multiple ghost cell corners.
# [1.70206312 0.26400659]
# 0.002920082070054747
# 486
# [1.69840031 0.26294129]
# 0.013286854954315593
# 487
# [ 1.70305869 -0.26022934]
# 0.010965614480995641
# 488
# Contains multiple ghost cell corners.
# [ 1.70673872 -0.26116833]
# 0.0007918000529826051
# 489
# Contains multiple ghost cell corners.
# [1.70673872 0.26116833]
# 0.0007918000529825252
# 490
# [1.70305869 0.26022934]
# 0.010965614480997624
# 491
# [ 1.70757086 -0.25738448]
# 0.00900130686610507
# 492
# [1.70757086 0.25738448]
# 0.009001306866105434
# 493
# [ 1.70828002 -0.25363987]
# 0.017349432651460966
# 494
# Contains multiple ghost cell corners.
# [ 1.7120612  -0.25434387]
# 0.007319038848956028
# 495
# Contains multiple ghost cell corners.
# [1.7120612  0.25434387]
# 0.007319038848954703
# 496
# [1.70828002 0.25363987]
# 0.017349432651461265
# 497
# [ 1.71266503 -0.25055   ]
# 0.015857870927234095
# 498
# Contains multiple ghost cell corners.
# [ 1.71646235 -0.25116099]
# 0.005916676942580697
# 499
# Contains multiple ghost cell corners.
# [1.71646235 0.25116099]
# 0.005916676942581833
# 500
# [1.71266503 0.25055   ]
# 0.015857870927236346
# 501
# [ 1.71695795 -0.24732162]
# 0.01463516778890786
# 502
# Contains multiple ghost cell corners.
# [ 1.72072316 -0.24784069]
# 0.004867709473837091
# 503
# Contains multiple ghost cell corners.
# [1.72072316 0.24784069]
# 0.004867709473837454
# 504
# [1.71695795 0.24732162]
# 0.014635167788909442
# 505
# [ 1.72114347 -0.24396742]
# 0.013676326919804938
# 506
# Contains multiple ghost cell corners.
# [ 1.72491226 -0.24435538]
# 0.004100233499911975
# 507
# Contains multiple ghost cell corners.
# [1.72491226 0.24435538]
# 0.0041002334999119296
# 508
# [1.72114347 0.24396742]
# 0.01367632691980691
# 509
# [ 1.72515575 -0.24050442]
# 0.01309750559191684
# 510
# Contains multiple ghost cell corners.
# [ 1.72899466 -0.24074026]
# 0.0036075555666257135
# 511
# Contains multiple ghost cell corners.
# [1.72899466 0.24074026]
# 0.0036075555666255955
# 512
# [1.72515575 0.24050442]
# 0.01309750559191814
# 513
# [ 1.72912212 -0.23685778]
# 0.012784133705847321
# 514
# Contains multiple ghost cell corners.
# [ 1.7329269  -0.23699556]
# 0.0034603972647368328
# 515
# Contains multiple ghost cell corners.
# [1.7329269  0.23699556]
# 0.0034603972647363323
# 516
# [1.72912212 0.23685778]
# 0.012784133705847078
# 517
# [ 1.73297484 -0.2330896 ]
# 0.012732603393983443
# 518
# Contains multiple ghost cell corners.
# [ 1.73675741 -0.23311013]
# 0.0035979329536184263
# 519
# Contains multiple ghost cell corners.
# [1.73675741 0.23311013]
# 0.0035979329536177914
# 520
# [1.73297484 0.2330896 ]
# 0.012732603393983959
# 521
# [ 1.73662198 -0.22925108]
# 0.013053912234090229
# 522
# Contains multiple ghost cell corners.
# [ 1.74046553 -0.22910952]
# 0.004009815018232854
# 523
# Contains multiple ghost cell corners.
# [1.74046553 0.22910952]
# 0.004009815018231982
# 524
# [1.73662198 0.22925108]
# 0.013053912234089896
# 525
# [ 1.74020819 -0.22523416]
# 0.013648860549147908
# 526
# Contains multiple ghost cell corners.
# [ 1.74400129 -0.22500307]
# 0.0047701217508311685
# 527
# Contains multiple ghost cell corners.
# [1.74400129 0.22500307]
# 0.004770121750830059
# 528
# [1.74020819 0.22523416]
# 0.013648860549147723
# 529
# [ 1.74366615 -0.22111122]
# 0.0145071292698065
# 530
# Contains multiple ghost cell corners.
# [ 1.74742258 -0.22076953]
# 0.005813359594660526
# 531
# Contains multiple ghost cell corners.
# [1.74742258 0.22076953]
# 0.0058133595946609955
# 532
# [1.74366615 0.22111122]
# 0.014507129269807262
# 533
# [ 1.74689669 -0.21695502]
# 0.01572680178406828
# 534
# Contains multiple ghost cell corners.
# [ 1.75070785 -0.2164374 ]
# 0.007127055703367609
# 535
# Contains multiple ghost cell corners.
# [1.75070785 0.2164374 ]
# 0.00712705570336785
# 536
# [1.74689669 0.21695502]
# 0.015726801784065405
# 537
# [ 1.75005624 -0.21262274]
# 0.017237159560786967
# 538
# [ 1.75379014 -0.21204203]
# 0.008812577192670302
# 539
# Contains multiple ghost cell corners.
# [ 1.75756824 -0.2113405 ]
# 0.0005270079491827675
# 540
# Contains multiple ghost cell corners.
# [1.75756824 0.2113405 ]
# 0.0005270079491829901
# 541
# [1.75379014 0.21204203]
# 0.008812577192672005
# 542
# [1.75005624 0.21262274]
# 0.01723715956078397
# 543
# [ 1.75675921 -0.20751895]
# 0.01077902242767169
# 544
# Contains multiple ghost cell corners.
# [ 1.7604835  -0.20671606]
# 0.0026442520336783324
# 545
# Contains multiple ghost cell corners.
# [1.7604835  0.20671606]
# 0.002644252033678436
# 546
# [1.75675921 0.20751895]
# 0.010779022427671354
# 547
# [ 1.75958093 -0.20291551]
# 0.012996335595791038
# 548
# Contains multiple ghost cell corners.
# [ 1.76324799 -0.20201447]
# 0.005042096092922605
# 549
# Contains multiple ghost cell corners.
# [1.76324799 0.20201447]
# 0.005042096092924989
# 550
# [1.75958093 0.20291551]
# 0.012996335595793558
# 551
# [ 1.76216498 -0.19831258]
# 0.015568543196960907
# 552
# Contains multiple ghost cell corners.
# [ 1.76585895 -0.19724135]
# 0.00771596353648598
# 553
# Contains multiple ghost cell corners.
# [ 1.76949356 -0.19612625]
# 7.846827627660638e-05
# 554
# Contains multiple ghost cell corners.
# [1.76949356 0.19612625]
# 7.846827628005884e-05
# 555
# Contains multiple ghost cell corners.
# [1.76585895 0.19724135]
# 0.007715963536487778
# 556
# [1.76216498 0.19831258]
# 0.015568543196955964
# 557
# Contains multiple ghost cell corners.
# [ 1.76824412 -0.19244838]
# 0.01077055221803122
# 558
# Contains multiple ghost cell corners.
# [ 1.77186314 -0.19121329]
# 0.0032149771535825767
# 559
# Contains multiple ghost cell corners.
# [1.77186314 0.19121329]
# 0.0032149771535821326
# 560
# Contains multiple ghost cell corners.
# [1.76824412 0.19244838]
# 0.010770552218030843
# 561
# [ 1.77050213 -0.18755181]
# 0.014076656953334273
# 562
# Contains multiple ghost cell corners.
# [ 1.77404945 -0.186231  ]
# 0.006684358743915453
# 563
# Contains multiple ghost cell corners.
# [1.77404945 0.186231  ]
# 0.006684358743912676
# 564
# [1.77050213 0.18755181]
# 0.014076656953334129
# 565
# [ 1.77259899 -0.18260402]
# 0.017656126765944285
# 566
# [ 1.77607195 -0.1812013 ]
# 0.010452165169661696
# 567
# Contains multiple ghost cell corners.
# [ 1.77955568 -0.17968169]
# 0.00337822087260557
# 568
# Contains multiple ghost cell corners.
# [1.77955568 0.17968169]
# 0.0033782208726050806
# 569
# [1.77607195 0.1812013 ]
# 0.010452165169659518
# 570
# [1.77259899 0.18260402]
# 0.017656126765940906
# 571
# [ 1.777929   -0.17613025]
# 0.014487227360470898
# 572
# Contains multiple ghost cell corners.
# [ 1.78133251 -0.17453446]
# 0.007577835366663828
# 573
# Contains multiple ghost cell corners.
# [ 1.78473917 -0.17282345]
# 0.0008197870806762332
# 574
# Contains multiple ghost cell corners.
# [1.78473917 0.17282345]
# 0.0008197870806777032
# 575
# Contains multiple ghost cell corners.
# [1.78133251 0.17453446]
# 0.007577835366666524
# 576
# [1.777929   0.17613025]
# 0.014487227360468495
# 577
# Contains multiple ghost cell corners.
# [ 1.78289173 -0.16942958]
# 0.012087603599089674
# 578
# Contains multiple ghost cell corners.
# [ 1.78626123 -0.16757503]
# 0.005460289706000052
# 579
# Contains multiple ghost cell corners.
# [1.78626123 0.16757503]
# 0.005460289705999975
# 580
# Contains multiple ghost cell corners.
# [1.78289173 0.16942958]
# 0.012087603599088576
# 581
# [ 1.78428815 -0.16424267]
# 0.01692823996960996
# 582
# [ 1.78756293 -0.16236592]
# 0.01042992628039692
# 583
# Contains multiple ghost cell corners.
# [ 1.79083737 -0.16034826]
# 0.004091882431912104
# 584
# Contains multiple ghost cell corners.
# [1.79083737 0.16034826]
# 0.004091882431910576
# 585
# [1.78756293 0.16236592]
# 0.010429926280395225
# 586
# [1.78428815 0.16424267]
# 0.016928239969610084
# 587
# [ 1.78869823 -0.15710317]
# 0.015722553619750466
# 588
# [ 1.79187061 -0.15505675]
# 0.009526377666070599
# 589
# Contains multiple ghost cell corners.
# [ 1.79502685 -0.15290161]
# 0.003479211910225281
# 590
# Contains multiple ghost cell corners.
# [1.79502685 0.15290161]
# 0.0034792119102250068
# 591
# [1.79187061 0.15505675]
# 0.009526377666070392
# 592
# [1.78869823 0.15710317]
# 0.015722553619748846
# 593
# [ 1.79273857 -0.14973577]
# 0.015265213411377465
# 594
# [ 1.79579769 -0.14752969]
# 0.009367959583199185
# 595
# Contains multiple ghost cell corners.
# [ 1.79883415 -0.14521828]
# 0.003622792074965377
# 596
# Contains multiple ghost cell corners.
# [1.79883415 0.14521828]
# 0.003622792074964099
# 597
# [1.79579769 0.14752969]
# 0.009367959583196011
# 598
# [1.79273857 0.14973577]
# 0.015265213411373539
# 599
# [ 1.7963933  -0.14216852]
# 0.01555348187632044
# 600
# [ 1.79932915 -0.1398135 ]
# 0.009956172034928882
# 601
# Contains multiple ghost cell corners.
# [ 1.80223619 -0.1373569 ]
# 0.004508973564779025
# 602
# Contains multiple ghost cell corners.
# [1.80223619 0.1373569 ]
# 0.004508973564777458
# 603
# [1.79932915 0.1398135 ]
# 0.009956172034929031
# 604
# [1.7963933  0.14216852]
# 0.015553481876318363
# 605
# [ 1.79964863 -0.13443059]
# 0.016589988910212315
# 606
# [ 1.80245212 -0.13193795]
# 0.01129368614209315
# 607
# Contains multiple ghost cell corners.
# [ 1.80522101 -0.12934789]
# 0.006144119797285884
# 608
# Contains multiple ghost cell corners.
# [ 1.80795175 -0.12666175]
# 0.0011642243783996557
# 609
# Contains multiple ghost cell corners.
# [1.80795175 0.12666175]
# 0.0011642243783978117
# 610
# Contains multiple ghost cell corners.
# [1.80522101 0.12934789]
# 0.006144119797285754
# 611
# [1.80245212 0.13193795]
# 0.011293686142093085
# 612
# [1.79964863 0.13443059]
# 0.016589988910209227
# 613
# Contains multiple ghost cell corners.
# [ 1.80515593 -0.12393372]
# 0.013382645098111969
# 614
# [ 1.80777889 -0.12122243]
# 0.008533635554162727
# 615
# Contains multiple ghost cell corners.
# [ 1.81035847 -0.11841975]
# 0.003842852209437722
# 616
# Contains multiple ghost cell corners.
# [1.81035847 0.11841975]
# 0.003842852209438681
# 617
# [1.80777889 0.12122243]
# 0.008533635554162802
# 618
# Contains multiple ghost cell corners.
# [1.80515593 0.12393372]
# 0.01338264509811283
# 619
# [ 1.80743216 -0.11583219]
# 0.01622026944899077
# 620
# [ 1.8099024  -0.11301238]
# 0.011667344630532704
# 621
# [ 1.81232446 -0.11010616]
# 0.007259917906523725
# 622
# Contains multiple ghost cell corners.
# [ 1.81469518 -0.10711538]
# 0.003031286209426612
# 623
# Contains multiple ghost cell corners.
# [1.81469518 0.10711538]
# 0.003031286209427903
# 624
# [1.81232446 0.11010616]
# 0.007259917906526183
# 625
# [1.8099024  0.11301238]
# 0.011667344630535802
# 626
# [1.80743216 0.11583219]
# 0.01622026944899322
# 627
# [ 1.81158645 -0.1047501 ]
# 0.015556237429486612
# 628
# [ 1.81384565 -0.10175372]
# 0.011453344089642326
# 629
# [ 1.81604935 -0.09867817]
# 0.007495510683081489
# 630
# Contains multiple ghost cell corners.
# [ 1.81819467 -0.09552557]
# 0.0037129510478944804
# 631
# Contains multiple ghost cell corners.
# [ 1.82027882 -0.09229815]
# 5.889801138972804e-05
# 632
# Contains multiple ghost cell corners.
# [1.82027882 0.09229815]
# 5.889801138888868e-05
# 633
# Contains multiple ghost cell corners.
# [1.81819467 0.09552557]
# 0.0037129510478942102
# 634
# [1.81604935 0.09867817]
# 0.007495510683082225
# 635
# [1.81384565 0.10175372]
# 0.011453344089642993
# 636
# [1.81158645 0.1047501 ]
# 0.01555623742948695
# 637
# Contains multiple ghost cell corners.
# [ 1.81695322 -0.09024897]
# 0.012740749361713901
# 638
# [ 1.8189242  -0.08703126]
# 0.009234484184195871
# 639
# Contains multiple ghost cell corners.
# [ 1.82083073 -0.0837446 ]
# 0.005872568711357546
# 640
# Contains multiple ghost cell corners.
# [ 1.8226703  -0.08039145]
# 0.0026775087357602057
# 641
# Contains multiple ghost cell corners.
# [1.8226703  0.08039145]
# 0.0026775087357614725
# 642
# Contains multiple ghost cell corners.
# [1.82083073 0.0837446 ]
# 0.005872568711360053
# 643
# [1.8189242  0.08703126]
# 0.009234484184196215
# 644
# Contains multiple ghost cell corners.
# [1.81695322 0.09024897]
# 0.012740749361714097
# 645
# [ 1.81920296 -0.07859247]
# 0.015514127752424877
# 646
# [ 1.82093009 -0.07526097]
# 0.012440422696161463
# 647
# [ 1.8225877  -0.07186912]
# 0.009534279113704656
# 648
# [ 1.82417361 -0.06841955]
# 0.006762955228756915
# 649
# Contains multiple ghost cell corners.
# [ 1.82568897 -0.0648845 ]
# 0.004177371580143958
# 650
# Contains multiple ghost cell corners.
# [ 1.82711391 -0.06134378]
# 0.001732171947909971
# 651
# Contains multiple ghost cell corners.
# [1.82711391 0.06134378]
# 0.0017321719479094476
# 652
# Contains multiple ghost cell corners.
# [1.82568897 0.0648845 ]
# 0.0041773715801435305
# 653
# [1.82417361 0.06841955]
# 0.006762955228757986
# 654
# [1.8225877  0.07186912]
# 0.009534279113705768
# 655
# [1.82093009 0.07526097]
# 0.012440422696162575
# 656
# [1.81920296 0.07859247]
# 0.015514127752424512
# 657
# [ 1.82346072 -0.0599971 ]
# 0.014690268892503217
# 658
# [ 1.82480079 -0.05639195]
# 0.012362691447081409
# 659
# [ 1.82603846 -0.05284415]
# 0.010220506306675566
# 660
# [ 1.82719828 -0.04925276]
# 0.008218642628918317
# 661
# Contains multiple ghost cell corners.
# [ 1.82827868 -0.04562072]
# 0.006360526555153213
# 662
# Contains multiple ghost cell corners.
# [ 1.82927821 -0.04195097]
# 0.004667329044373836
# 663
# Contains multiple ghost cell corners.
# [ 1.83019552 -0.03824655]
# 0.003111609054217342
# 664
# Contains multiple ghost cell corners.
# [ 1.83102939 -0.0345105 ]
# 0.0016975328495922493
# 665
# Contains multiple ghost cell corners.
# [ 1.83177871 -0.03074592]
# 0.0004274580477889607
# 666
# Contains multiple ghost cell corners.
# [1.83177871 0.03074592]
# 0.00042745804778904705
# 667
# Contains multiple ghost cell corners.
# [1.83102939 0.0345105 ]
# 0.0016975328495923453
# 668
# Contains multiple ghost cell corners.
# [1.83019552 0.03824655]
# 0.0031116090542173693
# 669
# Contains multiple ghost cell corners.
# [1.82927821 0.04195097]
# 0.004667329044372935
# 670
# Contains multiple ghost cell corners.
# [1.82827868 0.04562072]
# 0.006360526555153194
# 671
# [1.82719828 0.04925276]
# 0.008218642628919259
# 672
# [1.82603846 0.05284415]
# 0.010220506306676378
# 673
# [1.82480079 0.05639195]
# 0.012362691447080743
# 674
# [1.82346072 0.0599971 ]
# 0.014690268892503697
# 675
# [ 1.82793845 -0.03003092]
# 0.013546478511968421
# 676
# [ 1.82858584 -0.02633541]
# 0.01242006869873277
# 677
# [ 1.82914913 -0.02261804]
# 0.011450115946855743
# 678
# [ 1.82962758 -0.01888196]
# 0.010631199144928407
# 679
# [ 1.83002055 -0.01513032]
# 0.00996098653749608
# 680
# [ 1.83032755 -0.0113663 ]
# 0.009438364095672709
# 681
# [ 1.83054818 -0.00759309]
# 0.009063010490662247
# 682
# [ 1.83068216 -0.00381391]
# 0.008834712605198768
# 683
# [1.83072917 0.        ]
# 0.008752738536176067
# 684
# [1.83068216 0.00381391]
# 0.008834712605198844
# 685
# [1.83054818 0.00759309]
# 0.00906301049066206
# 686
# [1.83032755 0.0113663 ]
# 0.009438364095672627
# 687
# [1.83002055 0.01513032]
# 0.009960986537496965
# 688
# [1.82962758 0.01888196]
# 0.010631199144929736
# 689
# [1.82914913 0.02261804]
# 0.011450115946854803
# 690
# [1.82858584 0.02633541]
# 0.012420068698731713
# 691
# [1.82793845 0.03003092]
# 0.013546478511968996

# %%
dens_diff = np.abs(dens.where(mask) - dens_true.where(mask))

l2_err = np.sqrt(np.nanmean(dens_diff[100,:,:]**2))
l2_unnorm = np.sqrt(np.nansum(dens_diff[100,:,:]**2)*dx*dz)
l2_rel = np.sqrt(np.nansum(dens_diff[100,:,:]**2)*dx*dz) / np.sqrt(np.nansum(dens_true[100,:,:]**2)*dx*dz)
print("L2 (RMS): "    + str(l2_err))
print("L2 (unnorm): " + str(l2_unnorm))
print("L2 (rel): "    + str(l2_rel))

true = dens_true.values[1:10, len(x)//2, len(z)//2] - dens_true.values[0, len(x)//2, len(z)//2]
sim = dens.values[1:10, len(x)//2, len(z)//2] - dens.values[0, len(x)//2, len(z)//2]
#print(*np.abs(sim-true), sep="\n")

init_dens_diff = dens_diff[0,:,:]
mask2 = init_dens_diff.notnull() & (init_dens_diff >= 1e-10)
nerrs = int(mask2.sum().compute())

ii, jj = np.where(mask2)

if nerrs > 0:
    print(init_dens_diff.values[ii[0],jj[0]])
    print(dens.values[0,ii[0],jj[0]])
    print(dens_true.values[0,ii[0],jj[0]])

print(nerrs)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 dens_diff = np.abs(dens.where(mask) - dens_true.where(mask))
# ----> 3 l2_err = np.sqrt(np.nanmean(dens_diff[1600,:,:]**2))
#       4 l2_unnorm = np.sqrt(np.nansum(dens_diff[1600,:,:]**2)*dx*dz)
#       5 l2_rel = np.sqrt(np.nansum(dens_diff[1600,:,:]**2)*dx*dz) / np.sqrt(np.nansum(dens_true[1600,:,:]**2)*dx*dz)
#
# File ~/miniconda3/lib/python3.13/site-packages/xarray/core/dataarray.py:887, in DataArray.__getitem__(self, key)
#     884     return self._getitem_coord(key)
#     885 else:
#     886     # xarray-style array indexing
# --> 887     return self.isel(indexers=self._item_key_to_dict(key))
#
# File ~/miniconda3/lib/python3.13/site-packages/xarray/core/dataarray.py:1529, in DataArray.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1524     return self._from_temp_dataset(ds)
#    1526 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    1527 # lists, or zero or one-dimensional np.ndarray's
# -> 1529 variable = self._variable.isel(indexers, missing_dims=missing_dims)
#    1530 indexes, index_variables = isel_indexes(self.xindexes, indexers)
#    1532 coords = {}
#
# File ~/miniconda3/lib/python3.13/site-packages/xarray/core/variable.py:1045, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1042 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1044 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1045 return self[key]
#
# File ~/miniconda3/lib/python3.13/site-packages/xarray/core/variable.py:791, in Variable.__getitem__(self, key)
#     788 dims, indexer, new_order = self._broadcast_indexes(key)
#     789 indexable = as_indexable(self._data)
# --> 791 data = indexing.apply_indexer(indexable, indexer)
#     793 if new_order:
#     794     data = duck_array_ops.moveaxis(data, range(len(new_order)), new_order)
#
# File ~/miniconda3/lib/python3.13/site-packages/xarray/core/indexing.py:1038, in apply_indexer(indexable, indexer)
#    1036     return indexable.oindex[indexer]
#    1037 else:
# -> 1038     return indexable[indexer]
#
# File ~/miniconda3/lib/python3.13/site-packages/xarray/core/indexing.py:1729, in DaskIndexingAdapter.__getitem__(self, indexer)
#    1727 def __getitem__(self, indexer: ExplicitIndexer):
#    1728     self._check_and_raise_if_non_basic_indexer(indexer)
# -> 1729     return self.array[indexer.tuple]
#
# File ~/miniconda3/lib/python3.13/site-packages/dask/array/core.py:2023, in Array.__getitem__(self, index)
#    2015     index = (index,)
#    2017 from dask.array.slicing import (
#    2018     normalize_index,
#    2019     slice_with_bool_dask_array,
#    2020     slice_with_int_dask_array,
#    2021 )
# -> 2023 index2 = normalize_index(index, self.shape)
#    2024 dependencies = {self.name}
#    2025 for i in index2:
#
# File ~/miniconda3/lib/python3.13/site-packages/dask/array/slicing.py:861, in normalize_index(idx, shape)
#     859 for axis, (i, d) in enumerate(zip(idx, none_shape)):
#     860     if d is not None:
# --> 861         check_index(axis, i, d)
#     862 idx = tuple(map(sanitize_index, idx))
#     863 idx = tuple(map(normalize_slice, idx, none_shape))
#
# File ~/miniconda3/lib/python3.13/site-packages/dask/array/slicing.py:933, in check_index(axis, ind, dimension)
#     930     return
#     932 elif ind >= dimension or ind < -dimension:
# --> 933     raise IndexError(
#     934         f"Index {ind} is out of bounds for axis {axis} with size {dimension}"
#     935     )
#
# IndexError: Index 1600 is out of bounds for axis 0 with size 201

# %%
dens_diff.bout.animate2D(aspect='equal')
# Out:
# Nh+ data passed has 3 dimensions - will use animatplot.blocks.Pcolormesh()
# warning: adding timeline slider to gridspec failed, adding in independent axes. tight_layout() will ignore the slider.
# warning: adding play/pause button to gridspec failed, adding in independent axes. tight_layout() will ignore the button.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#For Neumann BCs.
dens = ds["Nh+"]

# Physical coordinates matching dens' interior points
# If your file stores 2D grids:
R = ds["R"]
Z = ds["Z"]

# circle center in physical coords.
rc, zc = 1.5, 0

dx_phys = np.mean(np.diff(np.unique(R[:,0])))     # grid spacing in x
dz_phys = np.mean(np.diff(np.unique(Z[0,:])))     # grid spacing in z

# Cartesian gradients for every time slice
# axis=(1,2) tells np.gradient to differentiate along i,j only (not time)
dndx, dndz = np.gradient(dens, R[:, 0] , Z[0,:], axis=(1,2))

# Radial unit vectors (broadcast over time)
RX = R - rc
RZ = Z - zc
r  = np.hypot(RX, RZ)

nx = np.where(r > 0, RX/r, 0.0)
nz = np.where(r > 0, RZ/r, 0.0)

# Project gradient onto radial direction
dn_dr = dndx*nx + dndz*nz                  # shape (Nt, Ny, Nx)

# %%
dens[:,:,:] = dn_dr[:,:,:]
dens = dens.where(dsn["in_mask"])
#dens = dens.clip(min=0)
dens.bout.animate2D(aspect="equal")
