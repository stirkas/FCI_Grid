# %%
# set up matplotlib
# %matplotlib widget
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (8, 8)
plt.rcParams.update({"font.size": 14})

# %%
import numpy as np
from xbout import open_boutdataset
from boutdata import collect

# %%
case = "4" # 4 and 9  have n,t,p data
filepath = "test" + str(case) + "/BOUT.dmp.0.nc"
#filepath = "test" + str(case) + "/BOUT.dmp.0.nc"

ds = open_boutdataset(datapath="test" + str(case) + "/BOUT.dmp.*.nc", chunks={"t": 4})

# Use squeeze() to get rid of the y-dimension, which has length 1 as blob2d does not
# simulate the parallel dimension.
ds = ds.squeeze(drop=True)
# Out:
# Read in:
# <xbout.BoutDataset>
# Contains:
# <xarray.Dataset> Size: 122MB
# Dimensions:             (x: 260, y: 1, z: 264, t: 201)
# Coordinates:
#     dx                  (x, y, z) float64 549kB dask.array<chunksize=(260, 1, 264), meta=np.ndarray>
#     dy                  (x, y, z) float64 549kB dask.array<chunksize=(260, 1, 264), meta=np.ndarray>
#     dz                  (x, y, z) float64 549kB dask.array<chunksize=(260, 1, 264), meta=np.ndarray>
#   * t                   (t) float64 2kB 0.0 5e+05 1e+06 ... 9.95e+07 1e+08
#   * x                   (x) int64 2kB 0 1 2 3 4 5 6 ... 254 255 256 257 258 259
#   * y                   (y) float64 8B 0.1963
#   * z                   (z) float64 2kB 0.001931 0.005792 ... 1.014 1.017
# Data variables: (12/44)
#     Bxy                 (x, y, z) float64 549kB dask.array<chunksize=(260, 1, 264), meta=np.ndarray>
#     G1                  (x, y, z) float64 549kB dask.array<chunksize=(260, 1, 264), meta=np.ndarray>
#     G2                  (x, y, z) float64 549kB dask.array<chunksize=(260, 1, 264), meta=np.ndarray>
#     G3                  (x, y, z) float64 549kB dask.array<chunksize=(260, 1, 264), meta=np.ndarray>
#     J                   (x, y, z) float64 549kB dask.array<chunksize=(260, 1, 264), meta=np.ndarray>
#     Nh+                 (t, x, y, z) float64 110MB dask.array<chunksize=(4, 260, 1, 264), meta=np.ndarray>
#     ...                  ...
#     wtime_invert        (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_io            (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs       (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs_e     (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs_i     (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_rhs           (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
# Attributes:
#     metadata:  {'BOUT_VERSION': 5.2, 'Bnorm': 1.0, 'Cs0': 21884.735894072473,...
#     options:   None
#     geometry:
# Metadata:
# {   'BOUT_VERSION': 5.2,
#     'Bnorm': 1.0,
#     'Cs0': 21884.735894072473,
#     'HERMES_REVISION': 'bb9053e6425e047f16ae55670f3ede40cddfc2c5',
#     'HERMES_SLOPE_LIMITER': 'MC',
#     'MXG': 2,
#     'MXSUB': 256,
#     'MYG': 1,
#     'MYPE': 0,
#     'MYSUB': 1,
#     'MZ': 264,
#     'MZG': 0,
#     'MZSUB': 264,
#     'NXPE': 1,
#     'NYPE': 1,
#     'NZPE': 1,
#     'Nnorm': 2e+18,
#     'Omega_ci': 95788333.03066081,
#     'PE_XIND': 0,
#     'PE_YIND': 0,
#     'Tnorm': 5.0,
#     'ZMAX': 1.0,
#     'ZMIN': 0.0,
#     'bout_tdim': 't',
#     'bout_xdim': 'x',
#     'bout_ydim': 'y',
#     'bout_zdim': 'z',
#     'fine_interpolation_factor': 8,
#     'has_adios2': 0,
#     'has_caliper': 0,
#     'has_cuda': 0,
#     'has_fftw': 1,
#     'has_gettext': 1,
#     'has_hypre': 0,
#     'has_lapack': 0,
#     'has_netcdf': 1,
#     'has_petsc': 1,
#     'has_pretty_function': 1,
#     'has_pvode': 1,
#     'has_raja': 0,
#     'has_scorep': 0,
#     'has_slepc': 0,
#     'has_sundials': 1,
#     'has_umpire': 0,
#     'hist_hi': 200,
#     'is_restart': 0,
#     'ixseps1': 261,
#     'ixseps2': 261,
#     'jyseps1_1': -1,
#     'jyseps1_2': 0,
#     'jyseps2_1': 0,
#     'jyseps2_2': 0,
#     'keep_xboundaries': 1,
#     'keep_yboundaries': 0,
#     'nx': 260,
#     'ny': 1,
#     'ny_inner': 0,
#     'nz': 264,
#     'openmp_threads': 1,
#     'rho_s0': 0.0002284697436697996,
#     'run_id': 'cbb00943-4905-4da9-9819-68b15f95e96d',
#     'run_restart_from': 'zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz',
#     'tt': 100000000.0,
#     'use_backtrace': 1,
#     'use_check_level': 4,
#     'use_color': 1,
#     'use_metric_3d': 1,
#     'use_msgstack': 1,
#     'use_openmp': 0,
#     'use_openmp_schedule': 'static',
#     'use_output_debug': 1,
#     'use_sigfpe': 0,
#     'use_signal': 1,
#     'use_track': 1,
#     'zperiod': 1}
# /home/tirkas1/miniconda3/lib/python3.13/site-packages/xbout/load.py:646: UserWarning: The specified chunks separate the stored chunks along dimension "t" starting at index 4. This could degrade performance. Instead, consider rechunking after loading.
#   ds = xr.open_mfdataset(
# /home/tirkas1/miniconda3/lib/python3.13/site-packages/xbout/load.py:341: UserWarning: No geometry type found, no physical coordinates will be added
#   warn("No geometry type found, no physical coordinates will be added")

# %%
dx = ds["dx"].isel(z=0).values

# Get rid of existing "x" coordinate, which is just the index values.
#ds = ds.drop("x")

# Create a new coordinate, which is length in units of rho_s
ds = ds.assign_coords(x=np.arange(ds.sizes["x"])*dx)

# %%
ds_initial = ds.isel(t=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ds_initial = ds.isel(t=0)
#
# File ~/miniconda3/lib/python3.13/site-packages/xarray/core/dataset.py:2763, in Dataset.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2759     return self._isel_fancy(indexers, drop=drop, missing_dims=missing_dims)
#    2761 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    2762 # lists, or zero or one-dimensional np.ndarray's
# -> 2763 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    2765 variables = {}
#    2766 dims: dict[Hashable, int] = {}
#
# File ~/miniconda3/lib/python3.13/site-packages/xarray/core/utils.py:853, in drop_dims_from_indexers(indexers, dims, missing_dims)
#     851     invalid = indexers.keys() - set(dims)
#     852     if invalid:
# --> 853         raise ValueError(
#     854             f"Dimensions {invalid} do not exist. Expected one or more of {dims}"
#     855         )
#     857     return indexers
#     859 elif missing_dims == "warn":
#     860     # don't modify input
#
# ValueError: Dimensions {'t'} do not exist. Expected one or more of FrozenMappingWarningOnValuesAccess({'x': 68, 'z': 68})

# %%
for key,val in ds_initial.items():
    print(key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 for key,val in ds_initial.items():
#       2     print(key)
#
# NameError: name 'ds_initial' is not defined

# %%
#dtn = collect("ddt(Nh+)", path='04')
#dtn.shape

ds["Bxy"].shape

plt.figure()
ax = plt.subplot(111)
ax.set_aspect("equal")

#ds["ddt(Ne)"][5:,2:-2,0,:].bout.animate2D(aspect="equal")

# %%
plt.figure()
#ax = plt.subplot(131)
#ax.set_aspect("equal")

#if case == 4:
#    yval = 3 #For size 8 array
#elif case == 9:
#    yval = 7 #Fors size 16 array

yval = 3

n = ds_initial["Nh+"]
#t = ds_initial["Te"][:,:]
#p = ds_initial["Pe"][:,:]

n.plot(x="x", y="z")
#ax = plt.subplot(132)
#ax.set_aspect("equal")
#t.plot(x="x", y="z")
#ax = plt.subplot(133)
#ax.set_aspect("equal")
#p.plot(x="x", y="z")

# %%
plt.figure()
ds.isel(t=0, z=9)["Pe"].plot()
ds.isel(t=10, z=9)["Pe"].plot()
ds.isel(t=30, z=9)["Pe"].plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 plt.figure()
# ----> 2 ds.isel(t=0, z=9)["Pe"].plot()
#       3 ds.isel(t=10, z=9)["Pe"].plot()
#       4 ds.isel(t=30, z=9)["Pe"].plot()
#
# File ~/miniconda3/lib/python3.13/site-packages/xarray/core/dataset.py:2763, in Dataset.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2759     return self._isel_fancy(indexers, drop=drop, missing_dims=missing_dims)
#    2761 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    2762 # lists, or zero or one-dimensional np.ndarray's
# -> 2763 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    2765 variables = {}
#    2766 dims: dict[Hashable, int] = {}
#
# File ~/miniconda3/lib/python3.13/site-packages/xarray/core/utils.py:853, in drop_dims_from_indexers(indexers, dims, missing_dims)
#     851     invalid = indexers.keys() - set(dims)
#     852     if invalid:
# --> 853         raise ValueError(
#     854             f"Dimensions {invalid} do not exist. Expected one or more of {dims}"
#     855         )
#     857     return indexers
#     859 elif missing_dims == "warn":
#     860     # don't modify input
#
# ValueError: Dimensions {'t'} do not exist. Expected one or more of FrozenMappingWarningOnValuesAccess({'x': 68, 'z': 68})
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ds["ddt(Nh+)"][:,2:-2,:].bout.animate2D(aspect="equal")

# %%
ds["SNh+"][:,2:-2,:].bout.animate2D(aspect="equal")

# %%
dens = ds["Nh+"][:,2:-2,:]
dens = dens.clip(min=0)
dens.bout.animate2D(aspect="equal")
# Out:
# Nh+ data passed has 3 dimensions - will use animatplot.blocks.Pcolormesh()
# warning: adding timeline slider to gridspec failed, adding in independent axes. tight_layout() will ignore the slider.
# warning: adding play/pause button to gridspec failed, adding in independent axes. tight_layout() will ignore the button.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
