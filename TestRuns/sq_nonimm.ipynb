# %%
# set up matplotlib
# %matplotlib widget
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (8, 8)
plt.rcParams.update({"font.size": 14})

# %%
import numpy as np
import xarray as xr
from scipy.special import j0
from scipy.interpolate import RectBivariateSpline
from xbout import open_boutdataset

# %%
case = "1" # Case 1 is for anomalous density diffusion only.
filepath = "sq_nonimm/BOUT.dmp.*.nc"
#filepath = "test" + str(case) + "/BOUT.dmp.0.nc"

ds = open_boutdataset(datapath=filepath, chunks={"t": 4})
dsn = xr.open_dataset("sq_nonimm_lowestres.fci.nc")

# Use squeeze() to get rid of the y-dimension, which has length 1 usually unless turbulent.
ds = ds.squeeze(drop=True)
dsn = dsn.squeeze(drop=True)

for key,val in ds.items():
    print(key)
# Out:
# Read in:
# <xbout.BoutDataset>
# Contains:
# <xarray.Dataset> Size: 46MB
# Dimensions:             (x: 68, y: 1, z: 68, t: 201)
# Coordinates:
#     dx                  (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#     dy                  (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#     dz                  (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#   * t                   (t) float64 2kB 0.0 5e+05 1e+06 ... 9.95e+07 1e+08
#   * x                   (x) int64 544B 0 1 2 3 4 5 6 7 ... 61 62 63 64 65 66 67
#   * y                   (y) float64 8B 0.1963
#   * z                   (z) float64 544B 0.007353 0.02206 ... 0.9779 0.9926
# Data variables: (12/52)
#     Bxy                 (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#     G1                  (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#     G2                  (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#     G3                  (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#     J                   (x, y, z) float64 37kB dask.array<chunksize=(68, 1, 68), meta=np.ndarray>
#     Nh+                 (t, x, y, z) float64 7MB dask.array<chunksize=(4, 68, 1, 68), meta=np.ndarray>
#     ...                  ...
#     wtime_invert        (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_io            (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs       (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs_e     (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs_i     (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_rhs           (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
# Attributes:
#     metadata:  {'BOUT_VERSION': 5.2, 'Bnorm': 1.0, 'Cs0': 21884.735894072473,...
#     options:   None
#     geometry:
# Metadata:
# {   'BOUT_VERSION': 5.2,
#     'Bnorm': 1.0,
#     'Cs0': 21884.735894072473,
#     'HERMES_REVISION': 'bb9053e6425e047f16ae55670f3ede40cddfc2c5',
#     'HERMES_SLOPE_LIMITER': 'MC',
#     'MXG': 2,
#     'MXSUB': 64,
#     'MYG': 1,
#     'MYPE': 0,
#     'MYSUB': 1,
#     'MZ': 68,
#     'MZG': 0,
#     'MZSUB': 68,
#     'NXPE': 1,
#     'NYPE': 1,
#     'NZPE': 1,
#     'Nnorm': 2e+18,
#     'Omega_ci': 95788333.03066081,
#     'PE_XIND': 0,
#     'PE_YIND': 0,
#     'Tnorm': 5.0,
#     'ZMAX': 1.0,
#     'ZMIN': 0.0,
#     'bout_tdim': 't',
#     'bout_xdim': 'x',
#     'bout_ydim': 'y',
#     'bout_zdim': 'z',
#     'fine_interpolation_factor': 8,
#     'has_adios2': 0,
#     'has_caliper': 0,
#     'has_cuda': 0,
#     'has_fftw': 1,
#     'has_gettext': 0,
#     'has_hypre': 0,
#     'has_lapack': 0,
#     'has_netcdf': 1,
#     'has_petsc': 1,
#     'has_pretty_function': 1,
#     'has_pvode': 1,
#     'has_raja': 0,
#     'has_scorep': 0,
#     'has_slepc': 0,
#     'has_sundials': 1,
#     'has_umpire': 0,
#     'hist_hi': 200,
#     'is_restart': 0,
#     'ixseps1': 69,
#     'ixseps2': 69,
#     'jyseps1_1': -1,
#     'jyseps1_2': 0,
#     'jyseps2_1': 0,
#     'jyseps2_2': 0,
#     'keep_xboundaries': 1,
#     'keep_yboundaries': 0,
#     'nx': 68,
#     'ny': 1,
#     'ny_inner': 0,
#     'nz': 68,
#     'openmp_threads': 1,
#     'rho_s0': 0.0002284697436697996,
#     'run_id': '19d899c5-70ba-4f90-b1e9-7b695d2651df',
#     'run_restart_from': 'zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz',
#     'tt': 100000000.0,
#     'use_backtrace': 1,
#     'use_check_level': 2,
#     'use_color': 1,
#     'use_metric_3d': 1,
#     'use_msgstack': 1,
#     'use_openmp': 0,
#     'use_openmp_schedule': 'static',
#     'use_output_debug': 0,
#     'use_sigfpe': 0,
#     'use_signal': 1,
#     'use_track': 1,
#     'zperiod': 1}
#
# Bxy
# G1
# G2
# G3
# J
# Nh+
# R
# SNh+
# Sh+_anom
# Sh+_src
# Z
# anomalous_Chi_h+
# anomalous_D_h+
# anomalous_nu_h+
# cvode_last_order
# cvode_last_step
# cvode_nfevals
# cvode_nliters
# cvode_nniters
# cvode_nonlin_fails
# cvode_npevals
# cvode_nsteps
# cvode_num_fails
# cvode_stab_lims
# ddt(Nh+)
# g11
# g12
# g13
# g22
# g23
# g33
# g_11
# g_12
# g_13
# g_22
# g_23
# g_33
# iteration
# pfh+_tot_xlow
# t_array
# ncalls
# ncalls_e
# ncalls_i
# wall_time
# wtime
# wtime_comms
# wtime_invert
# wtime_io
# wtime_per_rhs
# wtime_per_rhs_e
# wtime_per_rhs_i
# wtime_rhs
# /home/tirkas1/miniconda3/lib/python3.13/site-packages/xbout/load.py:341: UserWarning: No geometry type found, no physical coordinates will be added
#   warn("No geometry type found, no physical coordinates will be added")

# %%
dx = ds["dx"].isel(z=0).values

# Get rid of existing "x" coordinate, which is just the index values.
#ds = ds.drop("x")

# Create a new coordinate, which is length in units of rho_s
ds = ds.assign_coords(x=np.arange(ds.sizes["x"])*dx)

#Store just initial values as well.
ds_initial = ds.isel(t=0)

# %%
dens = ds["Nh+"]
src = ds["SNh+"]
dens_true = dens.copy()
src_true = src.copy()

mask = np.zeros_like(dens.values)
mask[:,2:-2,:] = 1.0

#mask = dsn["in_mask"]
#ghost_id = dsn["ghost_id"].values
#gst_pts = dsn["ghost_pts"].values
#bdy_pts = dsn["bndry_pts"].values
#img_pts = dsn["image_pts"].values
#normals = dsn["normals"].values
#is_plasma = dsn["is_plasma"].values
Rarr = dsn["R"].values
Zarr = dsn["Z"].values

timestep_for_errs_early = 10
timestep_for_errs_late = 100
spl_e = RectBivariateSpline(Rarr[:,0], Zarr[0,:], dens.values[timestep_for_errs_early,:,:], kx=1, ky=1)
spl_l = RectBivariateSpline(Rarr[:,0], Zarr[0,:], dens.values[timestep_for_errs_late,:,:], kx=1, ky=1)

# %%
M0 = dens[0,2:-2,:].sum().values
M1 = dens[10,2:-2,:].sum().values
M2 = dens[100,2:-2,:].sum().values
M3 = dens[-1,2:-2,:].sum().values
print(M0)
print(M1)
print(M2)
print(M3)
print("ΔM =", M3 - M0)
print("relative change =", (M3 - M0)/M0)
assert np.isclose(M3, M0, rtol=1e-10, atol=1e-14)
# Out:
# 4352.0
# 4352.0
# 4352.0000000000055
# 4352.000000000006
# ΔM = 6.366462912410498e-12
# relative change = 1.4628821030355003e-15

# %%
w_unit = 95788333.030660808    #Omega_ci
t_unit = 1/w_unit

nx = 64*int(case)
nz = nx + 4
dx = np.float64(1.0) / np.float64(nx)
dz = np.float64(1.0) / np.float64(nz)

m = 1.0
n = 1.0
# Centers in x; faces/nodes in z if that's your convention
x = (np.arange(nx, dtype=np.float64) + 0.5) * dx     # centered x
z = (np.arange(nz, dtype=np.float64)) * dz           # unshifted z

ghosts_lo_x = x[0]  - dx*np.arange(2, 0, -1)
ghosts_hi_x = x[-1] + dx*np.arange(1, 2+1)
x = np.concatenate((ghosts_lo_x, x, ghosts_hi_x))
xx,zz = np.meshgrid(x,z,indexing='ij')

#Use physical grid values to map R,Z boundary to x,z (i.e. ignore ghosts)
R_min, R_max = dsn["R"].values[2,0], dsn["R"].values[-3,0]
Z_min, Z_max = dsn["Z"].values[0,0], dsn["Z"].values[0,-1]
Lb, Rb = R_min, R_max  #1.75, 3.25
Bb, Tb = Z_min, Z_max #-0.77205882, 0.77205882
xL = x[2] + (Lb - R_min) * (x[-3] - x[2]) / (R_max - R_min)
xR = x[2] + (Rb - R_min) * (x[-3] - x[2]) / (R_max - R_min)
zB = z[0] + (Bb - Z_min) * (z[-1] - z[0]) / (Z_max - Z_min)
zT = z[0] + (Tb - Z_min) * (z[-1] - z[0]) / (Z_max - Z_min)

Lx = xR - xL
Lz = zT - zB
xi   = (x - xL)/ Lx
zeta = (z - zB)/ Lz
lbda = (m*np.pi/(Rb-Lb))**2 + (n*np.pi/(Tb-Bb))**2

xxi, zzeta = np.meshgrid(xi,zeta,indexing='ij',copy=False)
D      = 1.0
t64 = np.asarray(ds["t_array"].values, dtype=np.float64) # 1D time
t_norm = t64*t_unit
#spatial = np.cos(m*np.pi*xx)*np.cos(n*np.pi*zz)
#temp = np.exp(-lbda*D*(t_norm))

print(xL)
print(zB)
print(Lx)
print(Lz)

n0 = dens.values[0, 30,30]      # at t = 0
n1 = dens.values[1, 30,30]      # at t_index k (known step, but we ignore it for this calc)

ratio = (n1 - 1.0) / (n0 - 1.0)
t_eff = -np.log(ratio) / (0.2 * lbda)
print("Effective time from simulation at that point:", t_eff)
#t_norm = np.arange(201)*t_eff
# pick a grid point where the cosine mode is not zero
# the actual simulation timestep in physical units:
dt = t_norm[1] - t_norm[0]      # or however you compute Δt
ratio = (n1 - 1.0) / (n0 - 1.0)
lambda_eff = -np.log(ratio) / (D * dt)
print("Effective lambda from simulation at that point:", lambda_eff)
print("Analytic lambda:", lbda)
print("Percent error:", 100 * (lambda_eff - lbda)/lbda)

print("Simulation timestep output: ", t_norm[1])
spatial = np.cos(m * np.pi * xxi) * np.cos(n * np.pi * zzeta)
temp = np.exp(-D * lbda * t_norm)

#dens_true[:,:,:] = 1 + np.asarray(np.cos(np.pi*xxi)*np.cos(np.pi*zzeta))[np.newaxis,:,:]*np.asarray(temp)[:,np.newaxis,np.newaxis]
dens_true[:,:,:] = 1.0 + np.asarray(spatial)[np.newaxis,:,:]*np.asarray(temp)[:,np.newaxis,np.newaxis]
# Out:
# 0.0078125
# 0.0
# 0.984375
# 0.9852941176470588
# Effective time from simulation at that point: 0.026094116818689672
# Effective lambda from simulation at that point: 2.260872984222487
# Analytic lambda: 2.261314436245164
# Percent error: -0.0195219212154324
# Simulation timestep output:  0.005219842377254392

# %%
M0 = dens_true[0,2:-2,:].sum().values
M1 = dens_true[10,2:-2,:].sum().values
M2 = dens_true[100,2:-2,:].sum().values
M3 = dens_true[-1,2:-2,:].sum().values
print(M0)
print(M1)
print(M2)
print(M3)
print("ΔM =", M3 - M0)
print("relative change =", (M3 - M0)/M0)
assert np.isclose(M3, M0, rtol=1e-10, atol=1e-14)
# Out:
# 4352.0
# 4352.0
# 4352.0
# 4352.0
# ΔM = 0.0
# relative change = 0.0

# %%
print(dens.values[0,30,30])
print(dens_true.values[0,30,30])

print(dens.values[1,30,30])
print(dens_true.values[1,30,30])

print(dens.values[10,30,30])
print(dens_true.values[10,30,30])
# Out:
# 1.0283701811518184
# 1.0283701811518184
# 1.0280373411307686
# 1.0280372765241184
# 1.0252121395386717
# 1.025211533916459

# %%
# Number of valid cells
N_valid = np.sum(mask)
#l2 err
dens_diff = np.abs(dens.where(mask)-dens_true.where(mask))
l2_err_t = np.sqrt(np.sum((dens_diff**2), axis=(1, 2)) / N_valid)

init_dens_diff = dens_diff[0,:,:]
mask2 = init_dens_diff.notnull() & (init_dens_diff >= 1e-10)
nerrs = int(mask2.sum().compute())

ii, jj = np.where(mask2)

if nerrs > 0:
    print(init_dens_diff.values[ii[0],jj[0]])
    print(dens.values[0,ii[0],jj[0]])
    print(dens_true.values[0,ii[0],jj[0]])

print(nerrs)

plt.close('all')      # optional, but guarantees a clean slate for the whole kernel
print(np.max(l2_err_t.values))
fig, ax = plt.subplots()  # new figure/axes each run
ax.plot(t_norm, l2_err_t)
ax.set_xlabel("Time [s]")
ax.set_ylabel("L2 error (RMS)")
ax.set_title("Time evolution of L2 error")
plt.show()
# Out:
# 0
# 0.0004122238155993253
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dens_diff.where(mask).bout.animate2D(aspect='equal')
#dens_diff.where(mask).bout.animate2D(aspect='equal')
# Out:
# Nh+ data passed has 3 dimensions - will use animatplot.blocks.Pcolormesh()
# warning: adding timeline slider to gridspec failed, adding in independent axes. tight_layout() will ignore the slider.
# warning: adding play/pause button to gridspec failed, adding in independent axes. tight_layout() will ignore the button.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#src_true[:,:,:] = -D * lbda * np.asarray(spatial)[np.newaxis,:,:]*np.asarray(temp)[:,np.newaxis,np.newaxis]
#src_diff = src.where(mask)-src_true.where(mask)
src[:,2:-2,:].bout.animate2D(aspect='equal')

# %%
no_mask = ~(mask.astype(bool))
src[2:-2,:].where(no_mask).bout.animate2D(aspect='equal')
#src.bout.animate2D(aspect='equal')
