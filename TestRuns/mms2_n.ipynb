# %%
# set up matplotlib
# %matplotlib widget
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (8, 8)
plt.rcParams.update({"font.size": 14})

# %%
import numpy as np
import xarray as xr
from scipy.special import j0
from scipy.interpolate import RectBivariateSpline
from xbout import open_boutdataset

# %%
case = "2" # Case 1 is for anomalous density diffusion only.
filepath = "mms" + str(case) + "_n/BOUT.dmp.*.nc"
#filepath = "test" + str(case) + "/BOUT.dmp.0.nc"

ds = open_boutdataset(datapath=filepath, chunks={"t": 4})
dsn = xr.open_dataset("circle_lowres.fci.nc")

# Use squeeze() to get rid of the y-dimension, which has length 1 usually unless turbulent.
ds = ds.squeeze(drop=True)
dsn = dsn.squeeze(drop=True)

for key,val in ds.items():
    print(key)
# Out:
# Read in:
# <xbout.BoutDataset>
# Contains:
# <xarray.Dataset> Size: 172MB
# Dimensions:             (x: 132, y: 1, z: 132, t: 201)
# Coordinates:
#     dx                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     dy                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     dz                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#   * t                   (t) float64 2kB 0.0 5e+05 1e+06 ... 9.95e+07 1e+08
#   * x                   (x) int64 1kB 0 1 2 3 4 5 6 ... 126 127 128 129 130 131
#   * y                   (y) float64 8B 0.1963
#   * z                   (z) float64 1kB 0.003788 0.01136 ... 0.9886 0.9962
# Data variables: (12/52)
#     Bxy                 (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     G1                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     G2                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     G3                  (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     J                   (x, y, z) float64 139kB dask.array<chunksize=(132, 1, 132), meta=np.ndarray>
#     Nh+                 (t, x, y, z) float64 28MB dask.array<chunksize=(4, 132, 1, 132), meta=np.ndarray>
#     ...                  ...
#     wtime_invert        (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_io            (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs       (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs_e     (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_per_rhs_i     (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
#     wtime_rhs           (t) float64 2kB dask.array<chunksize=(4,), meta=np.ndarray>
# Attributes:
#     metadata:  {'BOUT_VERSION': 5.2, 'Bnorm': 1.0, 'Cs0': 21884.735894072473,...
#     options:   None
#     geometry:
# Metadata:
# {   'BOUT_VERSION': 5.2,
#     'Bnorm': 1.0,
#     'Cs0': 21884.735894072473,
#     'HERMES_REVISION': 'bb9053e6425e047f16ae55670f3ede40cddfc2c5',
#     'HERMES_SLOPE_LIMITER': 'MC',
#     'MXG': 2,
#     'MXSUB': 128,
#     'MYG': 1,
#     'MYPE': 0,
#     'MYSUB': 1,
#     'MZ': 132,
#     'MZG': 0,
#     'MZSUB': 132,
#     'NXPE': 1,
#     'NYPE': 1,
#     'NZPE': 1,
#     'Nnorm': 2e+18,
#     'Omega_ci': 95788333.03066081,
#     'PE_XIND': 0,
#     'PE_YIND': 0,
#     'Tnorm': 5.0,
#     'ZMAX': 1.0,
#     'ZMIN': 0.0,
#     'bout_tdim': 't',
#     'bout_xdim': 'x',
#     'bout_ydim': 'y',
#     'bout_zdim': 'z',
#     'fine_interpolation_factor': 8,
#     'has_adios2': 0,
#     'has_caliper': 0,
#     'has_cuda': 0,
#     'has_fftw': 1,
#     'has_gettext': 0,
#     'has_hypre': 0,
#     'has_lapack': 0,
#     'has_netcdf': 1,
#     'has_petsc': 1,
#     'has_pretty_function': 1,
#     'has_pvode': 1,
#     'has_raja': 0,
#     'has_scorep': 0,
#     'has_slepc': 0,
#     'has_sundials': 1,
#     'has_umpire': 0,
#     'hist_hi': 200,
#     'is_restart': 0,
#     'ixseps1': 133,
#     'ixseps2': 133,
#     'jyseps1_1': -1,
#     'jyseps1_2': 0,
#     'jyseps2_1': 0,
#     'jyseps2_2': 0,
#     'keep_xboundaries': 1,
#     'keep_yboundaries': 0,
#     'nx': 132,
#     'ny': 1,
#     'ny_inner': 0,
#     'nz': 132,
#     'openmp_threads': 1,
#     'rho_s0': 0.0002284697436697996,
#     'run_id': '05c475a5-c417-48e6-ac65-d5d9e1b1fe79',
#     'run_restart_from': 'zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz',
#     'tt': 100000000.0,
#     'use_backtrace': 1,
#     'use_check_level': 2,
#     'use_color': 1,
#     'use_metric_3d': 1,
#     'use_msgstack': 1,
#     'use_openmp': 0,
#     'use_openmp_schedule': 'static',
#     'use_output_debug': 0,
#     'use_sigfpe': 0,
#     'use_signal': 1,
#     'use_track': 1,
#     'zperiod': 1}
#
# Bxy
# G1
# G2
# G3
# J
# Nh+
# R
# SNh+
# Sh+_anom
# Sh+_src
# Z
# anomalous_Chi_h+
# anomalous_D_h+
# anomalous_nu_h+
# cvode_last_order
# cvode_last_step
# cvode_nfevals
# cvode_nliters
# cvode_nniters
# cvode_nonlin_fails
# cvode_npevals
# cvode_nsteps
# cvode_num_fails
# cvode_stab_lims
# ddt(Nh+)
# g11
# g12
# g13
# g22
# g23
# g33
# g_11
# g_12
# g_13
# g_22
# g_23
# g_33
# iteration
# pfh+_tot_xlow
# t_array
# ncalls
# ncalls_e
# ncalls_i
# wall_time
# wtime
# wtime_comms
# wtime_invert
# wtime_io
# wtime_per_rhs
# wtime_per_rhs_e
# wtime_per_rhs_i
# wtime_rhs
# /home/tirkas1/miniconda3/lib/python3.13/site-packages/xbout/load.py:341: UserWarning: No geometry type found, no physical coordinates will be added
#   warn("No geometry type found, no physical coordinates will be added")

# %%
dx = ds["dx"].isel(z=0).values

# Get rid of existing "x" coordinate, which is just the index values.
#ds = ds.drop("x")

# Create a new coordinate, which is length in units of rho_s
ds = ds.assign_coords(x=np.arange(ds.sizes["x"])*dx)

#Store just initial values as well.
ds_initial = ds.isel(t=0)

# %%
dens = ds["Nh+"][:,2:-2,:]
dens_true = dens.copy()

mask = dsn["in_mask"][2:-2,:]
ghost_id = dsn["ghost_id"].values
gst_pts = dsn["ghost_pts"].values
bdy_pts = dsn["bndry_pts"].values
img_pts = dsn["image_pts"].values
normals = dsn["normals"].values
is_plasma = dsn["is_plasma"].values
Rarr = dsn["R"].values[2:-2,:]
Zarr = dsn["Z"].values

timestep_for_errs_early = 10
timestep_for_errs_late = 100
spl_e = RectBivariateSpline(Rarr[:,0], Zarr[0,:], dens.values[timestep_for_errs_early,:,:], kx=1, ky=1)
spl_l = RectBivariateSpline(Rarr[:,0], Zarr[0,:], dens.values[timestep_for_errs_late,:,:], kx=1, ky=1)

# %%
beta0 = 3.8317059702075125
xc, zc = 1.5, 0.0

x_unit = 0.00022846974366979959 #rho_s0
w_unit = 95788333.030660808    #Omega_ci
t_unit = 1/w_unit

nx = 64*int(case)
nz = nx + 4
dx = np.float64(1.0) / np.float64(nx)
dz = np.float64(1.0) / np.float64(nz)

# Centers in x; faces/nodes in z if that's your convention
x = (np.arange(nx, dtype=np.float64) + 0.5) * dx     # centered x
z = (np.arange(nz, dtype=np.float64)) * dz           # unshifted z

xhalf  = np.float64(x[len(x)//2])
zhalf  = np.float64(z[len(z)//2])

print("x//2:: " + str(xhalf))

xx, zz = np.meshgrid(x,z,indexing='ij',copy=False)
a      = np.float64(0.333333333333)
D      = 0.07877942415093483 #np.float64(0.2) #/(x_unit*x_unit*w_unit)
t64 = np.asarray(ds["t_array"].values, dtype=np.float64) # 1D time
t_norm = t64*t_unit
#spatial = ((xx - xhalf)**2 + (zz-zhalf)**2)
spatial = j0(beta0*np.hypot(xx - xhalf, zz - zhalf)/a)
#temp = 4.0*D*t_norm #t64/t64[-1]
a_norm = a/x_unit
temp = np.exp(-D * (beta0 / a)**2 * (t_norm))

#dens_true[:,:,:] = np.asarray(spatial)[np.newaxis,:,:] + np.asarray(temp)[:,np.newaxis,np.newaxis]
dens_true[:,:,:] = np.asarray(spatial)[np.newaxis,:,:]*np.asarray(temp)[:,np.newaxis,np.newaxis]

bdy_pts_xz_e = spl_e.ev(bdy_pts[:,0], bdy_pts[:,1])
bdy_pts_xz_l = spl_l.ev(bdy_pts[:,0], bdy_pts[:,1])
print("Linf bdy err if dirichlet: " + str(np.max(np.abs(bdy_pts_xz_e))))
print("L2 bdy err (early) if dirichlet?: "  + str(np.mean(np.abs(bdy_pts_xz_e))))
print("L2 bdy err (late) if dirichlet?: "  + str(np.mean(np.abs(bdy_pts_xz_l))))

#dndR = spl.ev(bdy_pts[:,0], bdy_pts[:,1], dx=1, dy=0) # ∂n/∂R at boundary points
#dndZ = spl.ev(bdy_pts[:,0], bdy_pts[:,1], dx=0, dy=1) # ∂n/∂Z at boundary points
#dn_dn = dndR * normals[:,0] + dndZ * normals[:,1]     # normal derivative
dP = np.einsum('ij,ij->i', (bdy_pts - img_pts), -normals)
dG = np.einsum('ij,ij->i', (gst_pts - bdy_pts), -normals)
dn_dn_e = (spl_e.ev(img_pts[:,0], img_pts[:,1]) - spl_e.ev(gst_pts[:,0], gst_pts[:,1])) / (dP + dG)
dn_dn_l = (spl_l.ev(img_pts[:,0], img_pts[:,1]) - spl_l.ev(gst_pts[:,0], gst_pts[:,1])) / (dP + dG)

Linf = np.max(np.abs(dn_dn_e))
L2   = np.sqrt(np.mean(dn_dn_e**2))
L2   = np.sqrt(np.mean(dn_dn_l**2))
print("Linf bdy err if neumann: " + str(np.max(np.abs(dn_dn_e))))
print("L2 bdy err (early) if neumann: " + str(np.sqrt(np.mean(dn_dn_e**2))))
print("L2 bdy err (late) if neumann: " + str(np.sqrt(np.mean(dn_dn_l**2))))
# Out:
# x//2:: 0.50390625
# Linf bdy err if dirichlet: 0.2306833619602807
# L2 bdy err (early) if dirichlet?: 0.22967990179511846
# L2 bdy err (late) if dirichlet?: 0.001633390387889618
# Linf bdy err if neumann: 0.0029665063567952538
# L2 bdy err (early) if neumann: 0.0005152830201433388
# L2 bdy err (late) if neumann: 3.746120168191269e-06

# %%
img_pts_xz = spl_e.ev(img_pts[:,0], img_pts[:,1])

i = 0
for idx in range(nx+4):
    for idz in range(nz):
        gid = int(ghost_id[idx,idz])
        if gid >= 0:
            print(gid)
            if (not (is_plasma[gid,0] and is_plasma[gid,1] and is_plasma[gid,2] and is_plasma[gid,3])):
               print("Contains multiple ghost cell corners.")
            print(img_pts[gid])
            print(img_pts_xz[gid])
# Out:
# 0
# [ 1.1798759  -0.05776212]
# -0.22928546688791948
# 1
# [ 1.17744074 -0.05096186]
# -0.22955053342016066
# 2
# [ 1.17530107 -0.04399834]
# -0.229892648475282
# 3
# [ 1.17347038 -0.036777  ]
# -0.2302620449761716
# 4
# [ 1.17197622 -0.0295726 ]
# -0.23060019125515752
# 5
# Contains multiple ghost cell corners.
# [ 1.17080382 -0.02227157]
# -0.23055572009882966
# 6
# Contains multiple ghost cell corners.
# [ 1.16995945 -0.01489808]
# -0.2304567609185318
# 7
# Contains multiple ghost cell corners.
# [ 1.16944753 -0.00747662]
# -0.23037887337211804
# 8
# Contains multiple ghost cell corners.
# [1.16927083e+00 8.16431199e-17]
# -0.23034934168136623
# 9
# Contains multiple ghost cell corners.
# [1.16944753 0.00747662]
# -0.23037887337211763
# 10
# Contains multiple ghost cell corners.
# [1.16995945 0.01489808]
# -0.23045676091853162
# 11
# Contains multiple ghost cell corners.
# [1.17080382 0.02227157]
# -0.23055572009882994
# 12
# [1.17197622 0.0295726 ]
# -0.23060019125515818
# 13
# [1.17347038 0.036777  ]
# -0.23026204497617245
# 14
# [1.17530107 0.04399834]
# -0.22989264847528273
# 15
# [1.17744074 0.05096186]
# -0.22955053342016113
# 16
# [1.1798759  0.05776212]
# -0.22928546688792004
# 17
# [ 1.18962511 -0.09321913]
# -0.2289540808550785
# 18
# [ 1.1856387  -0.08700909]
# -0.2294677123739085
# 19
# [ 1.18197324 -0.0807379 ]
# -0.22975773277742306
# 20
# Contains multiple ghost cell corners.
# [ 1.1785587  -0.07421356]
# -0.22994073173601123
# 21
# Contains multiple ghost cell corners.
# [ 1.17541311 -0.06745545]
# -0.2296069767447533
# 22
# Contains multiple ghost cell corners.
# [ 1.17255294 -0.06048414]
# -0.22948160221013905
# 23
# Contains multiple ghost cell corners.
# [1.17255294 0.06048414]
# -0.22948160221014008
# 24
# Contains multiple ghost cell corners.
# [1.17541311 0.06745545]
# -0.2296069767447545
# 25
# Contains multiple ghost cell corners.
# [1.1785587  0.07421356]
# -0.22994073173601248
# 26
# [1.18197324 0.0807379 ]
# -0.22975773277742403
# 27
# [1.1856387  0.08700909]
# -0.22946771237390903
# 28
# [1.18962511 0.09321913]
# -0.2289540808550787
# 29
# [ 1.19680664 -0.11472893]
# -0.2289141879366277
# 30
# [ 1.19203619 -0.10930322]
# -0.22945394972858701
# 31
# Contains multiple ghost cell corners.
# [ 1.18742554 -0.10345153]
# -0.23002341546847838
# 32
# Contains multiple ghost cell corners.
# [ 1.18309348 -0.09742879]
# -0.22983528064652237
# 33
# Contains multiple ghost cell corners.
# [1.18309348 0.09742879]
# -0.229835280646523
# 34
# Contains multiple ghost cell corners.
# [1.18742554 0.10345153]
# -0.23002341546847888
# 35
# [1.19203619 0.10930322]
# -0.22945394972858787
# 36
# [1.19680664 0.11472893]
# -0.2289141879366288
# 37
# Contains multiple ghost cell corners.
# [ 1.20148734 -0.13026589]
# -0.22909967144652757
# 38
# [ 1.19614641 -0.12526842]
# -0.22963065012325318
# 39
# Contains multiple ghost cell corners.
# [ 1.19095192 -0.11985618]
# -0.22970296218183417
# 40
# Contains multiple ghost cell corners.
# [1.19095192 0.11985618]
# -0.22970296218183542
# 41
# [1.19614641 0.12526842]
# -0.22963065012325373
# 42
# Contains multiple ghost cell corners.
# [1.20148734 0.13026589]
# -0.22909967144652768
# 43
# [ 1.21370244 -0.14940588]
# -0.2284422277792198
# 44
# [ 1.20777341 -0.1453384 ]
# -0.229254501581831
# 45
# Contains multiple ghost cell corners.
# [ 1.20191938 -0.14086404]
# -0.2296853046103461
# 46
# Contains multiple ghost cell corners.
# [ 1.19619219 -0.13596722]
# -0.2295143851254164
# 47
# Contains multiple ghost cell corners.
# [1.19619219 0.13596722]
# -0.22951438512541486
# 48
# Contains multiple ghost cell corners.
# [1.20191938 0.14086404]
# -0.22968530461034595
# 49
# [1.20777341 0.1453384 ]
# -0.22925450158183172
# 50
# [1.21370244 0.14940588]
# -0.22844222777922119
# 51
# Contains multiple ghost cell corners.
# [ 1.21557773 -0.15971286]
# -0.22914506367462106
# 52
# Contains multiple ghost cell corners.
# [ 1.20925017 -0.15576846]
# -0.22968659152601242
# 53
# Contains multiple ghost cell corners.
# [1.20925017 0.15576846]
# -0.2296865915260139
# 54
# Contains multiple ghost cell corners.
# [1.21557773 0.15971286]
# -0.22914506367462262
# 55
# [ 1.22477994 -0.17317109]
# -0.22907340633506973
# 56
# Contains multiple ghost cell corners.
# [ 1.21809435 -0.16989286]
# -0.2296291379117928
# 57
# Contains multiple ghost cell corners.
# [ 1.21152959 -0.16632644]
# -0.22953674985410097
# 58
# Contains multiple ghost cell corners.
# [1.21152959 0.16632644]
# -0.2295367498541023
# 59
# Contains multiple ghost cell corners.
# [1.21809435 0.16989286]
# -0.22962913791179412
# 60
# [1.22477994 0.17317109]
# -0.22907340633507106
# 61
# [ 1.23522876 -0.18551466]
# -0.2287663352244763
# 62
# [ 1.22826675 -0.18295024]
# -0.22959711023557822
# 63
# Contains multiple ghost cell corners.
# [ 1.22139799 -0.18011851]
# -0.22972013134936112
# 64
# Contains multiple ghost cell corners.
# [1.22139799 0.18011851]
# -0.22972013134936303
# 65
# [1.22826675 0.18295024]
# -0.22959711023557924
# 66
# [1.23522876 0.18551466]
# -0.22876633522447742
# 67
# [ 1.23959461 -0.19475566]
# -0.22919203949379324
# 68
# Contains multiple ghost cell corners.
# [ 1.23252735 -0.19271378]
# -0.22987340546869212
# 69
# Contains multiple ghost cell corners.
# [1.23252735 0.19271378]
# -0.22987340546869328
# 70
# [1.23959461 0.19475566]
# -0.22919203949379463
# 71
# [ 1.24472813 -0.20393884]
# -0.22954066710630383
# 72
# Contains multiple ghost cell corners.
# [ 1.23742822 -0.2021927 ]
# -0.22984982570443083
# 73
# Contains multiple ghost cell corners.
# [1.23742822 0.2021927 ]
# -0.2298498257044326
# 74
# [1.24472813 0.20393884]
# -0.22954066710630555
# 75
# [ 1.25778665 -0.21364898]
# -0.2290787871823236
# 76
# [ 1.25040404 -0.2126968 ]
# -0.2300184586269201
# 77
# Contains multiple ghost cell corners.
# [ 1.24300159 -0.2114447 ]
# -0.229945631216001
# 78
# Contains multiple ghost cell corners.
# [1.24300159 0.2114447 ]
# -0.22994563121600342
# 79
# [1.25040404 0.2126968 ]
# -0.23001845862692097
# 80
# [1.25778665 0.21364898]
# -0.22907878718232452
# 81
# [ 1.26410293 -0.2215854 ]
# -0.22930892903631742
# 82
# Contains multiple ghost cell corners.
# [ 1.25668221 -0.22114122]
# -0.23031216886516762
# 83
# Contains multiple ghost cell corners.
# [1.25668221 0.22114122]
# -0.23031216886516898
# 84
# [1.26410293 0.2215854 ]
# -0.22930892903631891
# 85
# [ 1.27093963 -0.22913502]
# -0.22943015857103627
# 86
# Contains multiple ghost cell corners.
# [ 1.26361096 -0.22925966]
# -0.23040248048374312
# 87
# Contains multiple ghost cell corners.
# [1.26361096 0.22925966]
# -0.2304024804837451
# 88
# [1.27093963 0.22913502]
# -0.2294301585710382
# 89
# [ 1.27844363 -0.23636967]
# -0.22944289745828106
# 90
# Contains multiple ghost cell corners.
# [ 1.27099435 -0.23685349]
# -0.23043249516602893
# 91
# Contains multiple ghost cell corners.
# [1.27099435 0.23685349]
# -0.23043249516603018
# 92
# [1.27844363 0.23636967]
# -0.22944289745828228
# 93
# [ 1.28621202 -0.24294897]
# -0.22936124529838048
# 94
# Contains multiple ghost cell corners.
# [ 1.27885653 -0.24396742]
# -0.23043032067414373
# 95
# Contains multiple ghost cell corners.
# [1.27885653 0.24396742]
# -0.23043032067414387
# 96
# [1.28621202 0.24294897]
# -0.2293612452983809
# 97
# [ 1.29455699 -0.24913828]
# -0.22903838097277593
# 98
# Contains multiple ghost cell corners.
# [ 1.2872199  -0.25056851]
# -0.23036179741842405
# 99
# Contains multiple ghost cell corners.
# [1.2872199  0.25056851]
# -0.23036179741842366
# 100
# [1.29455699 0.24913828]
# -0.2290383809727757
# 101
# [ 1.29587399 -0.25653296]
# -0.23001328929144105
# 102
# [1.29587399 0.25653296]
# -0.23001328929144027
# 103
# [ 1.30495784 -0.26196745]
# -0.22959284921789094
# 104
# Contains multiple ghost cell corners.
# [ 1.29771148 -0.264066  ]
# -0.23001097078932478
# 105
# Contains multiple ghost cell corners.
# [1.29771148 0.264066  ]
# -0.23001097078932448
# 106
# [1.30495784 0.26196745]
# -0.22959284921788953
# 107
# [ 1.31417511 -0.26665453]
# -0.22927889181273697
# 108
# Contains multiple ghost cell corners.
# [ 1.30715372 -0.26927075]
# -0.22993566670938348
# 109
# Contains multiple ghost cell corners.
# [1.30715372 0.26927075]
# -0.2299356667093833
# 110
# [1.31417511 0.26665453]
# -0.22927889181273556
# 111
# [ 1.3237548  -0.27080897]
# -0.22871327829313343
# 112
# Contains multiple ghost cell corners.
# [ 1.31687375 -0.27384341]
# -0.22996734200304794
# 113
# Contains multiple ghost cell corners.
# [1.31687375 0.27384341]
# -0.22996734200304636
# 114
# [1.3237548  0.27080897]
# -0.22871327829313243
# 115
# [ 1.32669969 -0.27765404]
# -0.22957234070468613
# 116
# [1.32669969 0.27765404]
# -0.22957234070468527
# 117
# [ 1.33657352 -0.28075191]
# -0.22911379516503222
# 118
# Contains multiple ghost cell corners.
# [ 1.33011295 -0.28451546]
# -0.22977640088465173
# 119
# Contains multiple ghost cell corners.
# [1.33011295 0.28451546]
# -0.22977640088464985
# 120
# [1.33657352 0.28075191]
# -0.22911379516503014
# 121
# [ 1.34044395 -0.28738449]
# -0.22959744865902243
# 122
# [1.34044395 0.28738449]
# -0.22959744865901927
# 123
# Contains multiple ghost cell corners.
# [ 1.35067883 -0.28947287]
# -0.22897776494481
# 124
# Contains multiple ghost cell corners.
# [ 1.34458791 -0.29386351]
# -0.229470311211762
# 125
# Contains multiple ghost cell corners.
# [1.34458791 0.29386351]
# -0.2294703112117584
# 126
# Contains multiple ghost cell corners.
# [1.35067883 0.28947287]
# -0.22897776494480676
# 127
# Contains multiple ghost cell corners.
# [ 1.3552063  -0.29567935]
# -0.22945829056312073
# 128
# Contains multiple ghost cell corners.
# [1.3552063  0.29567935]
# -0.22945829056311762
# 129
# Contains multiple ghost cell corners.
# [ 1.36564379 -0.29669492]
# -0.22883524439567335
# 130
# Contains multiple ghost cell corners.
# [ 1.36000184 -0.30168364]
# -0.22927303063339807
# 131
# Contains multiple ghost cell corners.
# [1.36000184 0.30168364]
# -0.22927303063339632
# 132
# Contains multiple ghost cell corners.
# [1.36564379 0.29669492]
# -0.22883524439567174
# 133
# [ 1.37066541 -0.30235323]
# -0.22930006178623913
# 134
# [1.37066541 0.30235323]
# -0.22930006178623877
# 135
# [ 1.38123567 -0.30230723]
# -0.22863818656991683
# 136
# Contains multiple ghost cell corners.
# [ 1.37612    -0.30785451]
# -0.22924426194750933
# 137
# Contains multiple ghost cell corners.
# [1.37612    0.30785451]
# -0.2292442619475093
# 138
# [1.38123567 0.30230723]
# -0.22863818656991602
# 139
# [ 1.38675127 -0.30738304]
# -0.22899745012989914
# 140
# [1.38675127 0.30738304]
# -0.22899745012989753
# 141
# Contains multiple ghost cell corners.
# [ 1.3926206  -0.31226323]
# -0.22925007767754693
# 142
# Contains multiple ghost cell corners.
# [1.3926206  0.31226323]
# -0.22925007767754396
# 143
# Contains multiple ghost cell corners.
# [ 1.40311386 -0.31067544]
# -0.22870077831109614
# 144
# Contains multiple ghost cell corners.
# [ 1.39884894 -0.31691023]
# -0.22902402533840593
# 145
# Contains multiple ghost cell corners.
# [1.39884894 0.31691023]
# -0.22902402533840252
# 146
# Contains multiple ghost cell corners.
# [1.40311386 0.31067544]
# -0.22870077831109312
# 147
# [ 1.40933036 -0.31488651]
# -0.2289309075259442
# 148
# [1.40933036 0.31488651]
# -0.22893090752594186
# 149
# Contains multiple ghost cell corners.
# [ 1.4159243  -0.31886565]
# -0.22931509544492526
# 150
# Contains multiple ghost cell corners.
# [1.4159243  0.31886565]
# -0.22931509544492396
# 151
# [ 1.42594335 -0.31572231]
# -0.22825370077511312
# 152
# Contains multiple ghost cell corners.
# [ 1.42266437 -0.32252215]
# -0.22910022872642655
# 153
# Contains multiple ghost cell corners.
# [1.42266437 0.32252215]
# -0.229100228726425
# 154
# [1.42594335 0.31572231]
# -0.2282537007751128
# 155
# [ 1.43263825 -0.31896037]
# -0.2287213350951136
# 156
# [1.43263825 0.31896037]
# -0.22872133509511322
# 157
# [ 1.43969736 -0.3219209 ]
# -0.2287852314509107
# 158
# [1.43969736 0.3219209 ]
# -0.22878523145090998
# 159
# [ 1.44678385 -0.32453351]
# -0.22891665491448498
# 160
# [1.44678385 0.32453351]
# -0.22891665491448437
# 161
# Contains multiple ghost cell corners.
# [ 1.45404932 -0.32682726]
# -0.2287817312521787
# 162
# Contains multiple ghost cell corners.
# [1.45404932 0.32682726]
# -0.22878173125217832
# 163
# Contains multiple ghost cell corners.
# [ 1.46146961 -0.32878981]
# -0.22829014026942812
# 164
# Contains multiple ghost cell corners.
# [1.46146961 0.32878981]
# -0.22829014026942773
# 165
# Contains multiple ghost cell corners.
# [ 1.46901977 -0.33041062]
# -0.22779329051245503
# 166
# Contains multiple ghost cell corners.
# [1.46901977 0.33041062]
# -0.22779329051245487
# 167
# Contains multiple ghost cell corners.
# [ 1.47667419 -0.33168108]
# -0.22736381891782925
# 168
# Contains multiple ghost cell corners.
# [1.47667419 0.33168108]
# -0.2273638189178296
# 169
# Contains multiple ghost cell corners.
# [ 1.48440675 -0.33259449]
# -0.22705313873769173
# 170
# Contains multiple ghost cell corners.
# [1.48440675 0.33259449]
# -0.22705313873769264
# 171
# [ 1.49246979 -0.32557553]
# -0.22685719220323544
# 172
# Contains multiple ghost cell corners.
# [ 1.49219095 -0.33314616]
# -0.22691135631054446
# 173
# Contains multiple ghost cell corners.
# [1.49219095 0.33314616]
# -0.22691135631054626
# 174
# [1.49246979 0.32557553]
# -0.22685719220323686
# 175
# [ 1.5        -0.32575758]
# -0.2269631845401699
# 176
# Contains multiple ghost cell corners.
# [1.5        0.32575758]
# -0.22696318454017078
# 177
# [ 1.50753021 -0.32557553]
# -0.2268571922032361
# 178
# Contains multiple ghost cell corners.
# [ 1.50780905 -0.33314616]
# -0.22691135631054535
# 179
# Contains multiple ghost cell corners.
# [1.50780905 0.33314616]
# -0.22691135631054496
# 180
# [1.50753021 0.32557553]
# -0.22685719220323622
# 181
# Contains multiple ghost cell corners.
# [ 1.51559325 -0.33259449]
# -0.22705313873769223
# 182
# Contains multiple ghost cell corners.
# [1.51559325 0.33259449]
# -0.22705313873769237
# 183
# Contains multiple ghost cell corners.
# [ 1.52332581 -0.33168108]
# -0.22736381891782884
# 184
# Contains multiple ghost cell corners.
# [1.52332581 0.33168108]
# -0.22736381891782964
# 185
# Contains multiple ghost cell corners.
# [ 1.53098023 -0.33041062]
# -0.22779329051245378
# 186
# Contains multiple ghost cell corners.
# [1.53098023 0.33041062]
# -0.22779329051245528
# 187
# Contains multiple ghost cell corners.
# [ 1.53853039 -0.32878981]
# -0.22829014026942673
# 188
# Contains multiple ghost cell corners.
# [1.53853039 0.32878981]
# -0.22829014026942887
# 189
# Contains multiple ghost cell corners.
# [ 1.54595068 -0.32682726]
# -0.22878173125217777
# 190
# Contains multiple ghost cell corners.
# [1.54595068 0.32682726]
# -0.22878173125218002
# 191
# [ 1.55321615 -0.32453351]
# -0.2289166549144842
# 192
# [1.55321615 0.32453351]
# -0.2289166549144861
# 193
# [ 1.56030264 -0.3219209 ]
# -0.2287852314509098
# 194
# [1.56030264 0.3219209 ]
# -0.22878523145091145
# 195
# [ 1.56736175 -0.31896037]
# -0.22872133509511242
# 196
# [1.56736175 0.31896037]
# -0.22872133509511458
# 197
# [ 1.57405665 -0.31572231]
# -0.22825370077511187
# 198
# Contains multiple ghost cell corners.
# [ 1.57733563 -0.32252215]
# -0.22910022872642455
# 199
# Contains multiple ghost cell corners.
# [1.57733563 0.32252215]
# -0.22910022872642738
# 200
# [1.57405665 0.31572231]
# -0.22825370077511448
# 201
# Contains multiple ghost cell corners.
# [ 1.5840757  -0.31886565]
# -0.22931509544492357
# 202
# Contains multiple ghost cell corners.
# [1.5840757  0.31886565]
# -0.2293150954449273
# 203
# [ 1.59066964 -0.31488651]
# -0.22893090752594222
# 204
# [1.59066964 0.31488651]
# -0.2289309075259457
# 205
# Contains multiple ghost cell corners.
# [ 1.59688614 -0.31067544]
# -0.2287007783110942
# 206
# Contains multiple ghost cell corners.
# [ 1.60115106 -0.31691023]
# -0.22902402533840416
# 207
# Contains multiple ghost cell corners.
# [1.60115106 0.31691023]
# -0.2290240253384076
# 208
# Contains multiple ghost cell corners.
# [1.59688614 0.31067544]
# -0.22870077831109706
# 209
# Contains multiple ghost cell corners.
# [ 1.6073794  -0.31226323]
# -0.22925007767754627
# 210
# Contains multiple ghost cell corners.
# [1.6073794  0.31226323]
# -0.22925007767754846
# 211
# [ 1.61324873 -0.30738304]
# -0.2289974501299002
# 212
# [1.61324873 0.30738304]
# -0.2289974501299014
# 213
# [ 1.61876433 -0.30230723]
# -0.2286381865699192
# 214
# Contains multiple ghost cell corners.
# [ 1.62388    -0.30785451]
# -0.22924426194751205
# 215
# Contains multiple ghost cell corners.
# [1.62388    0.30785451]
# -0.22924426194751268
# 216
# [1.61876433 0.30230723]
# -0.22863818656991952
# 217
# [ 1.62933459 -0.30235323]
# -0.22930006178624177
# 218
# [1.62933459 0.30235323]
# -0.22930006178624168
# 219
# Contains multiple ghost cell corners.
# [ 1.63435621 -0.29669492]
# -0.22883524439567426
# 220
# Contains multiple ghost cell corners.
# [ 1.63999816 -0.30168364]
# -0.22927303063339893
# 221
# Contains multiple ghost cell corners.
# [1.63999816 0.30168364]
# -0.22927303063339738
# 222
# Contains multiple ghost cell corners.
# [1.63435621 0.29669492]
# -0.22883524439567382
# 223
# Contains multiple ghost cell corners.
# [ 1.6447937  -0.29567935]
# -0.22945829056311995
# 224
# Contains multiple ghost cell corners.
# [1.6447937  0.29567935]
# -0.22945829056311837
# 225
# Contains multiple ghost cell corners.
# [ 1.64932117 -0.28947287]
# -0.22897776494480934
# 226
# Contains multiple ghost cell corners.
# [ 1.65541209 -0.29386351]
# -0.22947031121176326
# 227
# Contains multiple ghost cell corners.
# [1.65541209 0.29386351]
# -0.22947031121175857
# 228
# Contains multiple ghost cell corners.
# [1.64932117 0.28947287]
# -0.22897776494480715
# 229
# [ 1.65955605 -0.28738449]
# -0.22959744865902373
# 230
# [1.65955605 0.28738449]
# -0.2295974486590192
# 231
# [ 1.66342648 -0.28075191]
# -0.22911379516503583
# 232
# Contains multiple ghost cell corners.
# [ 1.66988705 -0.28451546]
# -0.22977640088465418
# 233
# Contains multiple ghost cell corners.
# [1.66988705 0.28451546]
# -0.2297764008846484
# 234
# [1.66342648 0.28075191]
# -0.22911379516503044
# 235
# [ 1.67330031 -0.27765404]
# -0.22957234070468918
# 236
# [1.67330031 0.27765404]
# -0.22957234070468283
# 237
# [ 1.6762452  -0.27080897]
# -0.22871327829313565
# 238
# Contains multiple ghost cell corners.
# [ 1.68312625 -0.27384341]
# -0.22996734200304955
# 239
# Contains multiple ghost cell corners.
# [1.68312625 0.27384341]
# -0.22996734200304375
# 240
# [1.6762452  0.27080897]
# -0.22871327829313032
# 241
# [ 1.68582489 -0.26665453]
# -0.2292788918127368
# 242
# Contains multiple ghost cell corners.
# [ 1.69284628 -0.26927075]
# -0.2299356667093845
# 243
# Contains multiple ghost cell corners.
# [1.69284628 0.26927075]
# -0.22993566670937954
# 244
# [1.68582489 0.26665453]
# -0.22927889181273275
# 245
# [ 1.69504216 -0.26196745]
# -0.22959284921789014
# 246
# Contains multiple ghost cell corners.
# [ 1.70228852 -0.264066  ]
# -0.23001097078932475
# 247
# Contains multiple ghost cell corners.
# [1.70228852 0.264066  ]
# -0.2300109707893227
# 248
# [1.69504216 0.26196745]
# -0.2295928492178873
# 249
# [ 1.70412601 -0.25653296]
# -0.23001328929144121
# 250
# [1.70412601 0.25653296]
# -0.2300132892914389
# 251
# [ 1.70544301 -0.24913828]
# -0.22903838097277723
# 252
# Contains multiple ghost cell corners.
# [ 1.7127801  -0.25056851]
# -0.23036179741842489
# 253
# Contains multiple ghost cell corners.
# [1.7127801  0.25056851]
# -0.2303617974184227
# 254
# [1.70544301 0.24913828]
# -0.22903838097277532
# 255
# [ 1.71378798 -0.24294897]
# -0.22936124529838198
# 256
# Contains multiple ghost cell corners.
# [ 1.72114347 -0.24396742]
# -0.23043032067414448
# 257
# Contains multiple ghost cell corners.
# [1.72114347 0.24396742]
# -0.23043032067414393
# 258
# [1.71378798 0.24294897]
# -0.22936124529838078
# 259
# [ 1.72155637 -0.23636967]
# -0.22944289745828234
# 260
# Contains multiple ghost cell corners.
# [ 1.72900565 -0.23685349]
# -0.23043249516602934
# 261
# Contains multiple ghost cell corners.
# [1.72900565 0.23685349]
# -0.23043249516602982
# 262
# [1.72155637 0.23636967]
# -0.2294428974582822
# 263
# [ 1.72906037 -0.22913502]
# -0.22943015857103743
# 264
# Contains multiple ghost cell corners.
# [ 1.73638904 -0.22925966]
# -0.2304024804837442
# 265
# Contains multiple ghost cell corners.
# [1.73638904 0.22925966]
# -0.2304024804837449
# 266
# [1.72906037 0.22913502]
# -0.2294301585710381
# 267
# [ 1.73589707 -0.2215854 ]
# -0.22930892903631792
# 268
# Contains multiple ghost cell corners.
# [ 1.74331779 -0.22114122]
# -0.2303121688651681
# 269
# Contains multiple ghost cell corners.
# [1.74331779 0.22114122]
# -0.23031216886516906
# 270
# [1.73589707 0.2215854 ]
# -0.2293089290363188
# 271
# [ 1.74221335 -0.21364898]
# -0.2290787871823242
# 272
# [ 1.74959596 -0.2126968 ]
# -0.23001845862692033
# 273
# Contains multiple ghost cell corners.
# [ 1.75699841 -0.2114447 ]
# -0.2299456312160012
# 274
# Contains multiple ghost cell corners.
# [1.75699841 0.2114447 ]
# -0.22994563121600267
# 275
# [1.74959596 0.2126968 ]
# -0.23001845862692097
# 276
# [1.74221335 0.21364898]
# -0.22907878718232497
# 277
# [ 1.75527187 -0.20393884]
# -0.22954066710630572
# 278
# Contains multiple ghost cell corners.
# [ 1.76257178 -0.2021927 ]
# -0.22984982570443324
# 279
# Contains multiple ghost cell corners.
# [1.76257178 0.2021927 ]
# -0.22984982570443196
# 280
# [1.75527187 0.20393884]
# -0.22954066710630522
# 281
# [ 1.76040539 -0.19475566]
# -0.22919203949379557
# 282
# Contains multiple ghost cell corners.
# [ 1.76747265 -0.19271378]
# -0.2298734054686942
# 283
# Contains multiple ghost cell corners.
# [1.76747265 0.19271378]
# -0.22987340546869242
# 284
# [1.76040539 0.19475566]
# -0.229192039493794
# 285
# [ 1.76477124 -0.18551466]
# -0.22876633522447753
# 286
# [ 1.77173325 -0.18295024]
# -0.22959711023557905
# 287
# Contains multiple ghost cell corners.
# [ 1.77860201 -0.18011851]
# -0.22972013134936276
# 288
# Contains multiple ghost cell corners.
# [1.77860201 0.18011851]
# -0.22972013134936003
# 289
# [1.77173325 0.18295024]
# -0.2295971102355776
# 290
# [1.76477124 0.18551466]
# -0.22876633522447623
# 291
# [ 1.77522006 -0.17317109]
# -0.22907340633507042
# 292
# Contains multiple ghost cell corners.
# [ 1.78190565 -0.16989286]
# -0.22962913791179485
# 293
# Contains multiple ghost cell corners.
# [ 1.78847041 -0.16632644]
# -0.2295367498541028
# 294
# Contains multiple ghost cell corners.
# [1.78847041 0.16632644]
# -0.22953674985410003
# 295
# Contains multiple ghost cell corners.
# [1.78190565 0.16989286]
# -0.22962913791179193
# 296
# [1.77522006 0.17317109]
# -0.229073406335069
# 297
# Contains multiple ghost cell corners.
# [ 1.78442227 -0.15971286]
# -0.22914506367462384
# 298
# Contains multiple ghost cell corners.
# [ 1.79074983 -0.15576846]
# -0.22968659152601476
# 299
# Contains multiple ghost cell corners.
# [1.79074983 0.15576846]
# -0.2296865915260112
# 300
# Contains multiple ghost cell corners.
# [1.78442227 0.15971286]
# -0.2291450636746202
# 301
# [ 1.78629756 -0.14940588]
# -0.22844222777922157
# 302
# [ 1.79222659 -0.1453384 ]
# -0.22925450158183186
# 303
# Contains multiple ghost cell corners.
# [ 1.79808062 -0.14086404]
# -0.22968530461034659
# 304
# Contains multiple ghost cell corners.
# [ 1.80380781 -0.13596722]
# -0.22951438512541655
# 305
# Contains multiple ghost cell corners.
# [1.80380781 0.13596722]
# -0.2295143851254155
# 306
# Contains multiple ghost cell corners.
# [1.79808062 0.14086404]
# -0.2296853046103447
# 307
# [1.79222659 0.1453384 ]
# -0.22925450158182967
# 308
# [1.78629756 0.14940588]
# -0.22844222777921885
# 309
# Contains multiple ghost cell corners.
# [ 1.79851266 -0.13026589]
# -0.2290996714465282
# 310
# [ 1.80385359 -0.12526842]
# -0.22963065012325456
# 311
# Contains multiple ghost cell corners.
# [ 1.80904808 -0.11985618]
# -0.22970296218183622
# 312
# Contains multiple ghost cell corners.
# [1.80904808 0.11985618]
# -0.22970296218183506
# 313
# [1.80385359 0.12526842]
# -0.22963065012325326
# 314
# Contains multiple ghost cell corners.
# [1.79851266 0.13026589]
# -0.2290996714465269
# 315
# [ 1.80319336 -0.11472893]
# -0.22891418793662927
# 316
# [ 1.80796381 -0.10930322]
# -0.22945394972858835
# 317
# Contains multiple ghost cell corners.
# [ 1.81257446 -0.10345153]
# -0.2300234154684793
# 318
# Contains multiple ghost cell corners.
# [ 1.81690652 -0.09742879]
# -0.2298352806465233
# 319
# Contains multiple ghost cell corners.
# [1.81690652 0.09742879]
# -0.2298352806465221
# 320
# Contains multiple ghost cell corners.
# [1.81257446 0.10345153]
# -0.23002341546847832
# 321
# [1.80796381 0.10930322]
# -0.22945394972858726
# 322
# [1.80319336 0.11472893]
# -0.22891418793662804
# 323
# [ 1.81037489 -0.09321913]
# -0.22895408085507896
# 324
# [ 1.8143613  -0.08700909]
# -0.22946771237390906
# 325
# [ 1.81802676 -0.0807379 ]
# -0.22975773277742392
# 326
# Contains multiple ghost cell corners.
# [ 1.8214413  -0.07421356]
# -0.22994073173601215
# 327
# Contains multiple ghost cell corners.
# [ 1.82458689 -0.06745545]
# -0.229606976744754
# 328
# Contains multiple ghost cell corners.
# [ 1.82744706 -0.06048414]
# -0.22948160221013955
# 329
# Contains multiple ghost cell corners.
# [1.82744706 0.06048414]
# -0.22948160221013933
# 330
# Contains multiple ghost cell corners.
# [1.82458689 0.06745545]
# -0.22960697674475333
# 331
# Contains multiple ghost cell corners.
# [1.8214413  0.07421356]
# -0.22994073173601126
# 332
# [1.81802676 0.0807379 ]
# -0.22975773277742312
# 333
# [1.8143613  0.08700909]
# -0.22946771237390842
# 334
# [1.81037489 0.09321913]
# -0.22895408085507818
# 335
# [ 1.8201241  -0.05776212]
# -0.22928546688791943
# 336
# [ 1.82255926 -0.05096186]
# -0.2295505334201604
# 337
# [ 1.82469893 -0.04399834]
# -0.22989264847528193
# 338
# [ 1.82652962 -0.036777  ]
# -0.23026204497617173
# 339
# [ 1.82802378 -0.0295726 ]
# -0.23060019125515757
# 340
# Contains multiple ghost cell corners.
# [ 1.82919618 -0.02227157]
# -0.23055572009882938
# 341
# Contains multiple ghost cell corners.
# [ 1.83004055 -0.01489808]
# -0.23045676091853098
# 342
# Contains multiple ghost cell corners.
# [ 1.83055247 -0.00747662]
# -0.23037887337211707
# 343
# Contains multiple ghost cell corners.
# [1.83072917 0.        ]
# -0.2303493416813655
# 344
# Contains multiple ghost cell corners.
# [1.83055247 0.00747662]
# -0.23037887337211735
# 345
# Contains multiple ghost cell corners.
# [1.83004055 0.01489808]
# -0.2304567609185313
# 346
# Contains multiple ghost cell corners.
# [1.82919618 0.02227157]
# -0.23055572009882924
# 347
# [1.82802378 0.0295726 ]
# -0.23060019125515716
# 348
# [1.82652962 0.036777  ]
# -0.2302620449761714
# 349
# [1.82469893 0.04399834]
# -0.22989264847528182
# 350
# [1.82255926 0.05096186]
# -0.22955053342016046
# 351
# [1.8201241  0.05776212]
# -0.2292854668879194

# %%
dens0 = dens.where(mask) - np.nanmean(dens.where(mask), axis=(1,2), keepdims=True)
true0 = dens_true.where(mask) - np.nanmean(dens_true.where(mask), axis=(1,2), keepdims=True)
dens_diff0 = np.abs(dens0 - true0)

int_ind = 40
#dens0 = dens.values[:,int_ind:-int_ind,int_ind:-int_ind] - np.nanmean(dens.values[:,int_ind:-int_ind,int_ind:-int_ind], axis=(1,2), keepdims=True)
#true0 = dens_true.values[:,int_ind:-int_ind,int_ind:-int_ind] - np.nanmean(dens_true.values[:,int_ind:-int_ind,int_ind:-int_ind], axis=(1,2), keepdims=True)
dens_diff0 = np.abs(dens0 - true0)

dens_diff = np.abs(dens.where(mask) - dens_true.where(mask))
l2_err_t = np.sqrt(np.nanmean(dens_diff**2, axis=(1, 2)))
l2_err_n_t = np.sqrt(np.nanmean(dens_diff0**2, axis=(1, 2)))
l2_relerr_t = l2_err_t/np.sqrt(np.nanmean(dens_true**2, axis=(1,2)))
l2_relerr_n_t = l2_err_n_t/np.sqrt(np.nanmean(true0**2, axis=(1,2)))

print("Dirichlet Linf int err: " + str(np.max(l2_err_t)))
print("Dirichlet L2 int err (early): "   + str(l2_err_t[timestep_for_errs_early]))
print("Dirichlet L2 int err (late): "   + str(l2_err_t[timestep_for_errs_late]))

print("Neumann Linf int err: " + str(np.max(l2_err_n_t)))
print("Neumann L2 int err (early): "   + str(l2_err_n_t[timestep_for_errs_early]))
print("Neumann L2 int err (late): "   + str(l2_err_n_t[timestep_for_errs_late]))

#l2_err = np.sqrt(np.nanmean(dens_diff[100,:,:]**2))
#l2_unnorm = np.sqrt(np.nansum(dens_diff[100,:,:]**2)*dx*dz)
#l2_rel = np.sqrt(np.nansum(dens_diff[100,:,:]**2)*dx*dz) / np.sqrt(np.nansum(dens_true[100,:,:]**2)*dx*dz)
#print("L2 (RMS): "    + str(l2_err))
#print("L2 (unnorm): " + str(l2_unnorm))
#print("L2 (rel): "    + str(l2_rel))
#
true = dens_true.values[1:10, len(x)//2, len(z)//2] - dens_true.values[0, len(x)//2, len(z)//2]
sim = dens.values[1:10, len(x)//2, len(z)//2] - dens.values[0, len(x)//2, len(z)//2]
#print(*np.abs(sim-true), sep="\n")

init_dens_diff = dens_diff[0,:,:]
mask2 = init_dens_diff.notnull() & (init_dens_diff >= 1e-10)
nerrs = int(mask2.sum().compute())

ii, jj = np.where(mask2)

if nerrs > 0:
    print(init_dens_diff.values[ii[0],jj[0]])
    print(dens.values[0,ii[0],jj[0]])
    print(dens_true.values[0,ii[0],jj[0]])

print(nerrs)

plt.close('all')      # optional, but guarantees a clean slate for the whole kernel
fig, ax = plt.subplots()  # new figure/axes each run
print(l2_err_n_t[-1])
ax.plot(t_norm, l2_err_n_t)
ax.set_xlabel("Time [s]")
ax.set_ylabel("L2 error (RMS)")
ax.set_title("Time evolution of L2 error")
plt.show()
# Out:
# Dirichlet Linf int err: 0.00331853275121541
# Dirichlet L2 int err (early): 0.0018900025286201513
# Dirichlet L2 int err (late): 0.003305799224537357
# Neumann Linf int err: 0.001324511233045852
# Neumann L2 int err (early): 0.0012585866729115584
# Neumann L2 int err (late): 8.365630332919627e-05
# 0
# 1.5569900791925719e-06
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Inputs:
# dens:      (time, nx, nz) numerical solution
# dens_true: (time, nx, nz) analytic/manufactured
# mask:      (nx, nz) float 0/1 or area-fractions
# dx, dz:    scalars

import numpy as np

# 1) Boolean mask, consistent everywhere
mask_bool = (mask.values > 0.5)

# 2) Weights
w_cell = dx * dz
area = np.sum(mask_bool) * w_cell

# 3) Constant to remove (one time, t=0): area-weighted mean of the initial difference
diff0 = np.where(mask_bool, dens[0] - dens_true[0], 0.0)
c0 = (np.sum(diff0) * w_cell) / area  # ⟨dens0 - true0, 1⟩ / ⟨1,1⟩

# 4) Error modulo constant, all times (no abs before squaring)
diff = np.where(mask_bool[None, ...], dens - dens_true - c0, 0.0)

# 5) RMS (consistent) over the masked domain
rms = lambda A: np.sqrt(np.sum(A*A, axis=(1,2)) * w_cell / area)

l2_err_t   = rms(diff)                               # absolute RMS error (mod const)
rms_true   = rms(np.where(mask_bool[None,...], dens_true, 0.0))
rms_true0  = rms(np.where(mask_bool[None,...], dens_true - dens_true[0] + dens_true[0], 0.0))[0]  # = RMS(true at t=0)

# Two reasonable relative errors (pick one and be consistent):
l2_relerr_fixedden = l2_err_t / max(rms_true0, 1e-300)          # fixed denom at t=0
l2_relerr_inst     = l2_err_t / np.maximum(rms_true, 1e-300)    # instantaneous denom

print(l2_err_t[10])
# Out:
# 0.0018900025280197772

# %%
import numpy as np
import matplotlib.pyplot as plt

# dens: shape (nt, nx, nz)
# time: shape (nt,)
# dx, dz: scalar cell sizes (uniform grid)
# If nonuniform, use cell area weights instead of dx*dz.

area = dx * dz
# Compute L2 amplitude (norm of mean-free component)
amp = np.sqrt(np.nansum(dens0.where(mask)**2, axis=(1, 2)) * area)

# Take the natural log of amplitude
logA = np.log(amp)

# Choose a time window where the decay is clean (exclude t=0 if noisy)
t_fit = t_norm[5:]       # skip a few early points if needed
logA_fit = logA[5:]

# Linear fit: log(A) = a + b * t
coeffs = np.polyfit(t_fit, logA_fit, 1)
slope, intercept = coeffs[0], coeffs[1]

print(f"Measured slope = {slope:.6e}  (expected -D*alpha1^2)")

# Example for first root of J1
from scipy.special import jn_zeros
alpha1 = jn_zeros(1, 1)[0]  # ~3.8317 for J1's first root

expected_slope = -D * alpha1**2/a**2
print(f"Expected slope = {expected_slope:.6e}")
print(f"Ratio (measured/expected) = {slope / expected_slope:.3f}")

plt.figure(figsize=(6,4))
plt.plot(t_fit, logA_fit, 'o-', label='log(L2 amplitude)')
plt.plot(t_fit, intercept + slope*t_fit, 'r--', label=f'Fit slope = {slope:.3e}')
plt.plot(t_fit, np.log(amp[0]) + expected_slope*t_fit, 'k:', 
         label=f'Expected slope = {expected_slope:.3e}')
plt.xlabel('Time')
plt.ylabel('log(L2 amplitude)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Measured slope = -1.047836e+01  (expected -D*alpha1^2)
# Expected slope = -1.040973e+01
# Ratio (measured/expected) = 1.007
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dens_diff0.where(mask).bout.animate2D(aspect='equal')

# %%
res_true = (D/(x_unit*x_unit*w_unit))*(beta0**2/(a/x_unit)**2)*dens_true.where(mask)[0,:,:]
res_sim = ds["SNh+"][0,2:-2,:].where(mask)

res = res_sim - res_true

print(np.shape(res))

res_L2 = np.sqrt(np.nansum((res**2)) * dx*dz)
print("||res||_L2 =", float(res_L2)) #, "   relative =", float(rel_res))

# %%
print(dens0.values[0,len(x)//2, len(z)//2])
print(dens0.values[1,len(x)//2, len(z)//2])
print(true0.values[1,len(x)//2, len(z)//2])
print((dens0 - true0).values[1,len(x)//2,len(z)//2])
# Out:
# 0.9999441932354519
# 0.9469001924682539
# 0.9470598551118108
# -0.00015966264355693482

# %%
print(dens.values[0,len(x)//2, len(z)//2])
print(dens_true.values[0,len(x)//2, len(z)//2])
print(dens.values[1,len(x)//2, len(z)//2])
print(dens_true.values[1,len(x)//2, len(z)//2])
print((dens - dens_true).values[1,len(x)//2,len(z)//2])
# Out:
# 1.0
# 1.0
# 0.9471378821935004
# 0.9471127104070788
# 2.517178642158502e-05

# %%
import numpy as np

def build_core_mask(fluid_mask):
    """
    Erode by 1 cell so a 2nd-order centered stencil fits entirely in the fluid.
    fluid_mask: (ny, nx) bool (True = fluid)
    returns    : (ny, nx) bool 'core' mask
    """
    f = np.asarray(fluid_mask, dtype=bool)
    core = f.copy()
    # require 4-neighbors to be fluid
    core[:-1,:]  &= f[1:,:]
    core[1:,:]   &= f[:-1,:]
    core[:,:-1]  &= f[:,1:]
    core[:,1:]   &= f[:,:-1]
    # strip outer ring so centered diffs are valid
    core[[0,-1],:] = False
    core[:,[0,-1]] = False
    return core

def h1_seminorm_time(u_h, u_mms, fluid_mask, dx, dy, w_frac=None):
    """
    u_h, u_mms : (nt, ny, nx)
    fluid_mask : (ny, nx) bool (True = fluid; False = solid/ghost)
    dx, dy     : scalars
    w_frac     : optional (ny, nx) fractional fluid areas ∈[0,1]
    returns    : (nt,) H1 seminorm (gradients only) over interior core
    """
    u_h   = np.asarray(u_h);   u_mms = np.asarray(u_mms)
    nt, ny, nx = u_h.shape
    assert u_mms.shape == (nt, ny, nx), "u_h and u_mms shapes must match"

    # centered diffs
    ux_h   = (u_h[:, :, 2:] - u_h[:, :, :-2]) / (2.0*dx)   # (nt, ny,   nx-2)
    ux_mms = (u_mms[:, :, 2:] - u_mms[:, :, :-2]) / (2.0*dx)
    uy_h   = (u_h[:, 2:, :] - u_h[:, :-2, :]) / (2.0*dy)   # (nt, ny-2, nx)
    uy_mms = (u_mms[:, 2:, :] - u_mms[:, :-2, :]) / (2.0*dy)

    # align to common interior footprint: (nt, ny-2, nx-2)
    ex = (ux_h - ux_mms)[:, 1:-1, :]     # drop first/last y
    ey = (uy_h - uy_mms)[:, :, 1:-1]     # drop first/last x
    grad_err_sq = ex**2 + ey**2          # (nt, ny-2, nx-2) = (nt, 254, 258)

    # core mask (same (ny,nx) grid as u), then crop to (ny-2,nx-2)
    core = build_core_mask(fluid_mask)           # (ny, nx)
    core_int = core[1:-1, 1:-1]                  # (ny-2, nx-2)

    # weights on (ny-2, nx-2)
    if w_frac is None:
        weights2d = core_int.astype(float)
    else:
        wf = np.asarray(w_frac, dtype=float)
        assert wf.shape == (ny, nx), "w_frac must be (ny, nx)"
        weights2d = core_int.astype(float) * wf[1:-1, 1:-1]

    # weighted integral over space (2-D weights broadcast over time)
    num = np.sum(grad_err_sq * weights2d, axis=(1, 2)) * dx * dy     # (nt,)
    den = np.sum(weights2d) * dx * dy + 1e-300                       # scalar

    return np.sqrt(num / den)


# Example:
# core_mask is 2D and constant in time
H1_series = h1_seminorm_time(dens, dens_true, mask, dx, dz)
H1_final  = H1_series[-1]

print(H1_series[10])

# %%
import numpy as np

def build_core_mask(fluid_mask, radius=1):
    """Binary-erosion by `radius` cells so centered stencils stay inside the fluid."""
    f = np.asarray(fluid_mask, dtype=bool)
    core = f.copy()
    for _ in range(radius):
        core[:-1,:]  &= f[1:,:]
        core[1:,:]   &= f[:-1,:]
        core[:,:-1]  &= f[:,1:]
        core[:,1:]   &= f[:,:-1]
        core[[0,-1],:] = False
        core[:,[0,-1]] = False
        f = core
    return core

def l2_interior_gaugefree_time(u_h, u_mms, fluid_mask, dx, dy, w_frac=None, radius=1):
    """
    u_h, u_mms : (nt, ny, nx) fields at the same times
    fluid_mask : (ny, nx) bool (True = fluid, False = solid/ghost)
    dx, dy     : grid spacings (uniform). For nonuniform, fold areas into w_frac.
    w_frac     : optional (ny, nx) fractional fluid areas in [0,1]; defaults to 1 on core
    radius     : erosion in cells to define the *interior* core (e.g., 1–3)
    returns    : (nt,) L2 errors on the interior core after removing best-fit constant
    """
    u_h   = np.asarray(u_h);   u_mms = np.asarray(u_mms)
    nt, ny, nx = u_h.shape
    assert u_mms.shape == (nt, ny, nx), "u_h and u_mms must match shape"

    # Interior core (same grid as fields)
    core = build_core_mask(fluid_mask, radius=radius)   # (ny, nx)

    # Weights on the core
    if w_frac is None:
        weights2d = core.astype(float)                  # 1.0 on core, 0 elsewhere
    else:
        wf = np.asarray(w_frac, dtype=float)
        assert wf.shape == (ny, nx), "w_frac must be (ny, nx)"
        weights2d = core.astype(float) * wf             # fractional areas on core

    # Best-fit constant per time over *the same* interior weights
    # C*(t) = argmin || (u_h - u_mms - C) ||_L2(core)
    w_sum_cells = np.sum(weights2d)                     # dimensionless cell-weight sum
    if w_sum_cells == 0:
        raise ValueError("Interior core is empty; increase domain or reduce radius.")
    diff = u_h - u_mms                                  # (nt, ny, nx)
    C_t  = np.sum(diff * weights2d, axis=(1,2)) / (w_sum_cells + 1e-300)  # (nt,)

    # Gauge-free error on the core
    e = diff - C_t[:, None, None]                       # (nt, ny, nx)
    e2 = (e**2) * weights2d                             # (nt, ny, nx)

    # Proper L2 with area normalization
    area_core = w_sum_cells * dx * dy                   # total physical area of core
    num = np.sum(e2, axis=(1,2)) * dx * dy             # integrate over area
    return np.sqrt(num / (area_core + 1e-300))         # (nt,)

# core away from the IB; radius=1 for 2nd-order centered diffs,
# bump to 2–3 if you still see boundary contamination.
L2_series = l2_interior_gaugefree_time(dens, dens_true, mask, dx, dz,
                                       w_frac=None, radius=1)
L2_final = L2_series[-1]

print(L2_series[10])

# %%
print(dens.values[0,len(x)//2, len(z)//2])
print(dens_true.values[0,len(x)//2, len(z)//2])
print(dens.values[1,len(x)//2, len(z)//2])
print(dens_true.values[1,len(x)//2, len(z)//2])
print((dens - dens_true).values[1,len(x)//2,len(z)//2])

# %%
print(dens0.values[0,len(x)//2, len(z)//2])
print(true0.values[0,len(x)//2, len(z)//2])
print(dens0.values[1,len(x)//2, len(z)//2])
print(true0.values[1,len(x)//2, len(z)//2])
print((dens0 - true0).values[1,len(x)//2,len(z)//2])
